# %% [markdown]
# # Building Taxi Fare Prediction using SageMaker

# %% [markdown]
# <p>This demo notebook guides through the steps in creating an AWS Sagemaker predictions service</p>
# <p>To start using Sagemaker go here: <a href="https://aws.amazon.com/sagemaker/">Sagemaker</a></p>

# %% [markdown]
# ## Read the whole data from S3

# %%
import pandas as pd
import os
from s3fs.core import S3FileSystem
import random

import boto3
import json

# %%
s3 = S3FileSystem(anon=False)
bucket = 'aws-worskhop-data'
file_list = s3.ls(bucket)
subs = 'ZIPCHUNKS'
res = [i for i in file_list if subs in i]

# %%
res
# Out:
# ['aws-worskhop-data/ZIPCHUNKSaa',
#  'aws-worskhop-data/ZIPCHUNKSab',
#  'aws-worskhop-data/ZIPCHUNKSac',
#  'aws-worskhop-data/ZIPCHUNKSad',
#  'aws-worskhop-data/ZIPCHUNKSae',
#  'aws-worskhop-data/ZIPCHUNKSaf']

# %%
string = 'aws-worskhop-data/QSS'
string2 = 'aws-worskhop-data/QSS2'

# %%
with s3.open(string2, 'wb') as f:
    f.write(s3.cat(string)+s3.cat(string))

# %%
with s3.open('aws-worskhop-data/taxinyc_train.csv.zip', 'wb') as f:
    f.write(s3.cat(res[0]) + s3.cat(res[1]) + s3.cat(res[2]) + s3.cat(res[3]) + s3.cat(res[4]) + s3.cat(res[5]))

# %%
bucket = 'aws-worskhop-data'
path = ''

filename = 'taxinyc_train.csv.zip'
s3_path = os.path.join('s3://', bucket, path, filename)

#df_all = pd.read_csv(s3_path)

df_all = pd.read_csv(s3_path, header=0, skiprows=lambda i: i>0 and random.random() > 0.01)

# %%
df_all
# Out:
#                                   key  fare_amount          pickup_datetime  \
# 0       2014-02-19 16:03:00.000000160         5.50  2014-02-19 16:03:00 UTC
# 1       2011-08-04 10:38:00.000000142         7.70  2011-08-04 10:38:00 UTC
# 2        2010-03-14 15:40:00.00000012         4.50  2010-03-14 15:40:00 UTC
# 3         2009-05-29 09:46:11.0000002         5.30  2009-05-29 09:46:11 UTC
# 4         2009-06-20 19:28:37.0000005         7.30  2009-06-20 19:28:37 UTC
# 5        2010-04-15 18:13:00.00000097         4.90  2010-04-15 18:13:00 UTC
# 6         2010-03-22 14:59:45.0000001         3.70  2010-03-22 14:59:45 UTC
# 7         2012-10-10 12:40:54.0000004         6.50  2012-10-10 12:40:54 UTC
# 8         2015-04-07 18:37:37.0000001        12.50  2015-04-07 18:37:37 UTC
# 9         2010-02-02 12:40:32.0000002         9.70  2010-02-02 12:40:32 UTC
# 10        2011-08-09 13:03:07.0000001         4.50  2011-08-09 13:03:07 UTC
# 11       2009-10-23 14:42:00.00000098         3.30  2009-10-23 14:42:00 UTC
# 12        2010-08-07 22:16:40.0000002        12.90  2010-08-07 22:16:40 UTC
# 13       2013-09-19 23:06:00.00000078        16.00  2013-09-19 23:06:00 UTC
# 14        2014-03-26 01:43:13.0000001         8.50  2014-03-26 01:43:13 UTC
# 15       2013-01-04 07:25:00.00000045        16.50  2013-01-04 07:25:00 UTC
# 16        2015-03-18 01:35:59.0000001        28.00  2015-03-18 01:35:59 UTC
# 17        2009-03-17 09:15:07.0000002        20.10  2009-03-17 09:15:07 UTC
# 274187        -73.999287        40.761448         -73.983115
# 423700        -73.956115        40.778618         -73.954307
# 164666        -74.006655        40.744028         -73.977737
# 161674        -73.986532        40.749970         -73.864886
#
#         dropoff_latitude  passenger_count
# 348967         40.754768                1
# 60154          40.750355                1
# 146255          0.000000                1
# 40695          40.776105                6
# 165875         40.767687                2
# 16632          40.794304                1
# 21771          40.775430                1
# 105104         40.769399                1
# 173367         40.702002                1
# 552485         40.725489                1
# 280596         40.823726                2
# 179431         40.754715                1
# 478557         40.738835                1
# 285221         40.762165                2
# 311522         40.706388                1
# 74074          40.764883                1
# 419075         40.669398                1
# 286663         40.778082                1
# 97326          40.772972                1
# 489306         40.761526                1
# 210694         40.739548                1
# 469485         40.782182                1
# 389392         40.738785                1
# 188013         40.731870                1
# 104980         40.749747                5
# 439133         40.762633                1
# 478161         40.763398                1
# 433432         40.733825                3
# 103062         40.781675                1
# 219198         40.754548                3
# ...                  ...              ...
# 327303         40.771110                1
# 540696         40.755105                1
# 404391         40.785860                1
# 464890         40.741542                1
# 9364           40.740762                6
# 18894          40.790086                1
# 67771          40.764512                1
# 278452         40.773452                2
# 442786         40.720290                1
# 392396         40.713052                2
# 495937         40.766582                5
# 161996         40.743640                5
# 264676         40.799397                2
# 274707         40.840340                5
# 457799         40.701917                1
# 230206         40.721128                1
# 125453         40.745703                1
# 345638         40.744708                1
# 26528          40.753224                1
# 507974         40.772552                1
# 335177         40.747462                5
# 208817         40.776245                1
# 130796         40.761486                1
# 364864         40.789160                1
# 47731          40.719937                1
# 237210         40.740997                6
# 274187         40.731542                1
# 423700         40.772972                1
# 164666         40.755560                5
# 161674         40.770316                1
#
# [100 rows x 8 columns]

# %%
df_all.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  100000.000000     100000.000000    100000.000000       99999.000000
# mean       11.394214        -72.498354        39.911511         -72.514325
# std         9.864334         10.943099         6.428966          12.422538
# min        -4.000000       -752.383332       -74.012158       -2058.735083
# 25%         6.000000        -73.992030        40.735103         -73.991392
# 50%         8.500000        -73.981717        40.752712         -73.979987
# 75%        12.500000        -73.967067        40.767133         -73.963544
# max       350.000000         40.813082       402.033332          40.810315
#
#        dropoff_latitude  passenger_count
# count      99999.000000    100000.000000
# mean          39.905212         1.691100
# std            6.219667         1.314282
# min          -74.008112         0.000000
# 25%           40.734116         1.000000
# 50%           40.753189         1.000000
# 75%           40.768088         2.000000
# max           46.028506         6.000000

# %% [markdown]
# ### Date-Time Features

# %%
df_all['ts'] = df_all['pickup_datetime'].apply(pd.Timestamp)

# %%
df_all['weekday'] = df_all['ts'].dt.weekday
df_all['day'] = df_all['ts'].dt.day
df_all['month'] = df_all['ts'].dt.month
df_all['year'] = df_all['ts'].dt.year
df_all['hour'] = df_all['ts'].dt.hour

# %%
time_features = ['day', 'month', 'weekday', 'year', 'hour']

fig = plt.figure(figsize=(20,12))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(len(time_features)):
    ax = fig.add_subplot(2, 3, i+1)
    sns.boxplot(x=time_features[i], y="fare_amount", data=df_all[df_all['year'] >= 2013], showfliers=False)

plt.show()

# %% [markdown]
# ### Geographic

# %% [markdown]
# https://www.kaggle.com/breemen/nyc-taxi-fare-data-exploration

# %%
nyc_box = (-74.1, -73.7, 40.6, 40.9)

# %%
def filter_coordinates(df, box):
    return (df.pickup_longitude >= box[0]) & (df.pickup_longitude <= box[1]) & \
           (df.pickup_latitude >= box[2]) & (df.pickup_latitude <=box[3]) & \
           (df.dropoff_longitude >= box[0]) & (df.dropoff_longitude <= box[1]) & \
           (df.dropoff_latitude >= box[2]) & (df.dropoff_latitude <= box[3])

# %%
def plot_hires(df, box, figsize=(12, 12), ax=None, c=sns.color_palette("husl", 2)):
    if ax == None:
        fig, ax = plt.subplots(1, 1, figsize=figsize)

    idx = filter_coordinates(df, box)
    ax.scatter(df[idx].pickup_longitude, df[idx].pickup_latitude, c=c[0], s=0.1, lw=0.1, alpha=0.5)
    ax.scatter(df[idx].dropoff_longitude, df[idx].dropoff_latitude, c=c[1], s=0.1, lw=0.1, alpha=0.5)

# %%
plot_hires(df_all, nyc_box)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# <p>In the scatter plot above, the two major NYC airports are easily observed, indicating that it may be informative to "tell" our algorithm whether the ride starts or ends in an airport.</p>
# <p>To do so I use the airports.csv, available <a href="http://ourairports.com/data/">here</a> in the following way:</p>
# <ul>
# <li>from this file I extract the location of 3 of the listed NYC airports</li>
# <li>I than calculate the distance of dropoff and pickup points from every record to each airport, Assuming it will provide additional information to our model.</li>
# </ul>
# <p>Further details are in the feature extraction below</p>

# %% [markdown]
# ## Ride distance

# %%
df_all['air_distance'] = (df_all.pickup_longitude - df_all.dropoff_longitude)**2 +\
                     (df_all.pickup_latitude - df_all.dropoff_latitude)**2
df_all['air_distance'] = np.sqrt(df_all['air_distance'])

# %%
df_all['price_per_distance'] = df_all['fare_amount'] / df_all['air_distance']

# %%
time_features = ['weekday', 'year', 'hour']
fig = plt.figure(figsize=(18,5))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(len(time_features)):
    ax = fig.add_subplot(1, 3, i+1)
    sns.boxplot(x=time_features[i], y="price_per_distance", data=df_all[df_all['year'] >= 2013], showfliers=False)

plt.show()

# %%
time_features = ['weekday', 'year', 'hour']
fig = plt.figure(figsize=(18,5))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(len(time_features)):
    ax = fig.add_subplot(1, 3, i+1)
    sns.boxplot(x=time_features[i], y="air_distance", data=df_all[df_all['year'] >= 2013], showfliers=False)

plt.show()

# %% [markdown]
# ## Use Athena to extract features on all data

# %% [markdown]
# <p>As mentioned, the dataset we are working with contains 55M records, making its handling too heavy for a single machine.</p>
# <p>Using a distributed computing engine like&nbsp;<a href="https://aws.amazon.com/athena/">AWS Athena</a>&nbsp;will enable you to extract features and save data efficiently.&nbsp;</p>
# <p>In order to work on the data, we upload it to S3, and than partition it using AWS Glue. Partitioning is critical to make Athena run efficiently. For examples on how to use Glue, go&nbsp;<a href="https://github.com/doitintl/aws-glue-workshop">HERE</a>.</p>

# %% [markdown]
# ### Extract features

# %% [markdown]
# <p>With the data partitioned (say, by year and month), run the following Athena query to extract the following features&nbsp;</p>
# <p>After extracting features, partition the query results using Glue (again)</p>

# %%
#!aws s3 cp s3://aws-worskhop-data/QSS QSS

# %% [markdown]
# CREATE DATABASE IF NOT EXISTS taxinyc;

# %% [markdown]
# CREATE EXTERNAL TABLE IF NOT EXISTS taxinyc.raw_data (
#                fare_amount FLOAT,
#                pickup_datetime VARCHAR(255),
#                pickup_longitude FLOAT,
#                pickup_latitude FLOAT,
#                dropoff_longitude FLOAT,
#                dropoff_latitude FLOAT,
#                passenger_count INT
#                )
#                ROW FORMAT DELIMITED
#                FIELDS TERMINATED BY ","
#                LINES TERMINATED BY "\n"
#                LOCATION 's3://aws-worskhop-data/taxi-nyc/'
#                TBLPROPERTIES (
#                'skip.header.line.count' = '1'
#                );

# %% [markdown]
# SELECT * FROM "taxinyc"."raw_data" limit 10;

# %%
# !pwd
# Out:
# /home/ec2-user/SageMaker

# %%
SQL = '''
WITH 
    dataset AS 
    (SELECT CAST (pickup_datetime AS TIMESTAMP WITH time zone) AT TIME ZONE 'America/New_York' AS est, 
                  ST_POINT(pickup_longitude,pickup_latitude) pickup_point,
                  ST_POINT(dropoff_longitude,dropoff_latitude) dropoff_point,
                  to_unixtime( CAST (pickup_datetime AS TIMESTAMP WITH time zone) AT TIME ZONE 'America/New_York') AS                     epoch,
                  24*60*60 as seconds_in_day,
                  *
      FROM train_v3),
    
    airports AS (SELECT 
                  kv['LaGuardia'] AS LaGuardia,
                  kv['Downtown Manhattan/Wall St. Heliport'] AS Manhattan,
                  kv['John F Kennedy Intl'] AS JFK
    FROM (SELECT map_agg(name, point_location) kv
        FROM 
            (SELECT name,
         ST_POINT(longitude,
         latitude) point_location
            FROM usa_airports
            WHERE city = 'New York' )
            ))
        SELECT 
        
        -- Target
         fare_amount,
         
         -- time features
         day(est) day,
         day_of_week(est) dayofweek ,
         year(est) year ,
         month(est) month ,
         day_of_month(est) dayofmonth ,
         hour(est) hour ,
         minute(est) minute ,
         
         -- cyclclical variables
         sin(2*pi()*epoch/seconds_in_day) sin_day,
         cos(2*pi()*epoch/seconds_in_day) cos_day,
         sin(2*pi()*epoch/(seconds_in_day*7)) sin_week,
         cos(2*pi()*epoch/(seconds_in_day*7)) cos_week,
         
         
         -- Distance features
         pickup_longitude - dropoff_longitude diff_longitude,
         pickup_latitude - dropoff_latitude diff_latitude,
         ST_Distance(pickup_point, dropoff_point) dist,
         
         -- Airports features
         ST_DISTANCE(airports.LaGuardia, dropoff_point) dropoff_laguardia,
         ST_DISTANCE(airports.LaGuardia, pickup_point ) pickup_laguardia,
         ST_DISTANCE(airports.JFK, dropoff_point) dropoff_JFK,
         ST_DISTANCE(airports.JFK, pickup_point) pickup_JFK,
         ST_DISTANCE(airports.Manhattan, dropoff_point) dropoff_manhattan,
         ST_DISTANCE(airports.Manhattan, pickup_point) pickup_manhattan,
         
         -- Raw features
         pickup_longitude,
         pickup_latitude,
         dropoff_longitude,
         dropoff_latitude,
         passenger_count
         
    FROM dataset, airports
'''

# %% [markdown]
# ## Split train test

# %% [markdown]
# <p>If you managed to create the dataset using Athena, you have two options on how to create train and validation sets files.&nbsp;</p>
# <ol>
# <li>Create a seperate query, using a WHERE on the year clause to split the train and validation by time (e.g. year, month)</li>
# <li>Create a single query, partition the results by time, and use aws-cli to mv the directories to different train/validation directotires</li>
# </ol>

# %%
# I used the second option
# !aws s3 mv s3://athena-tmp-results/..../dataset/year=2015 s3://aws-worskhop-data/.../dataset/train/year=2015/
# !aws s3 mv s3://athena-tmp-results/..../dataset/year=2014 s3://aws-worskhop-data/.../dataset/val/year=2014/
# Out:
# fatal error: An error occurred (403) when calling the HeadObject operation: Forbidden
# fatal error: An error occurred (403) when calling the HeadObject operation: Forbidden

# %%
# I used the second option
# !aws s3 mv s3://athena-tmp-results/..../dataset/year=2015 s3://aws-worskhop-data/.../dataset/train/year=2015/
# !aws s3 mv s3://athena-tmp-results/..../dataset/year=2014 s3://aws-worskhop-data/.../dataset/val/year=2014/

# %% [markdown]
# ## Train model

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
import sagemaker
from sagemaker import get_execution_role
import boto3
from datetime import datetime

# %%
path_train = os.path.join('taxinyc-query-results','train2')
path_val = os.path.join('taxinyc-query-results','validate2')

# %%
container = get_image_uri(boto3.Session().region_name, 'xgboost')

# %%
s3_input_trains3_inpu  = sagemaker.s3_input(s3_data='s3://{}/{}'.format(bucket, path_train),
                                            content_type='csv',
                                            distribution='ShardedByS3Key')
s3_input_validation = sagemaker.s3_input(s3_data='s3://{}/{}'.format(bucket, path_val),
                                         content_type='csv', 
                                         distribution='ShardedByS3Key')

# %%
sess = sagemaker.Session()
role = get_execution_role()

# %%
training_job_path = os.path.join('training_jobs', datetime.now().strftime('%Y-%m-%d-%H-%M-%S'))

# %%
xgb = sagemaker.estimator.Estimator(container,
                                    role, 
                                    train_instance_count=4, 
                                    train_instance_type='ml.m4.xlarge',
                                    output_path='s3://{}/{}/output'.format(bucket,training_job_path),
                                    sagemaker_session=sess)

# %%
's3://{}/{}/output'.format(bucket,training_job_path)
# Out:
# 's3://aws-worskhop-data/training_jobs/2020-05-30-15-54-16/output'

# %%
xgb.set_hyperparameters(max_depth=9,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=300,
                        subsample=0.8,
                        silent=0,
                        objective='reg:linear',
                        early_stopping_rounds=10,
                        num_round=10000)

# %%
xgb.fit({'train': s3_input_trains3_inpu, 'validation': s3_input_validation})
# Out:
# 2020-05-30 15:54:18 Starting - Starting the training job...
# 2020-05-30 15:54:20 Starting - Launching requested ML instances......
# 2020-05-30 15:55:24 Starting - Preparing the instances for training.........
# 2020-05-30 15:57:02 Downloading - Downloading input data...
# 2020-05-30 15:57:44 Training - Training image download completed. Training in progress..
# Arguments: train
# [2020-05-30:15:57:45:INFO] Running distributed xgboost training.
# [2020-05-30:15:57:47:INFO] Number of hosts: 4, master IP address: 10.0.122.160, host IP address: 10.0.122.160.
# [2020-05-30:15:57:47:INFO] Finished Yarn configuration files setup.
#
# Arguments: train
# [2020-05-30:15:57:45:INFO] Running distributed xgboost training.
# [2020-05-30:15:57:47:INFO] Number of hosts: 4, master IP address: 10.0.122.160, host IP address: 10.0.68.100.
# [2020-05-30:15:57:47:INFO] Finished Yarn configuration files setup.
#
# starting datanode, logging to /opt/amazon/hadoop/logs/hadoop--datanode-ip-10-0-68-100.eu-west-1.compute.internal.out
# Arguments: train
# [2020-05-30:15:57:45:INFO] Running distributed xgboost training.
# [2020-05-30:15:57:47:INFO] Number of hosts: 4, master IP address: 10.0.122.160, host IP address: 10.0.75.30.
# [2020-05-30:15:57:47:INFO] Finished Yarn configuration files setup.
#
# starting datanode, logging to /opt/amazon/hadoop/logs/hadoop--datanode-ip-10-0-75-30.eu-west-1.compute.internal.out
# Arguments: train
# [2020-05-30:15:57:46:INFO] Running distributed xgboost training.
# [2020-05-30:15:57:48:INFO] Number of hosts: 4, master IP address: 10.0.122.160, host IP address: 10.0.78.117.
# [2020-05-30:15:57:48:INFO] Finished Yarn configuration files setup.
#
# starting datanode, logging to /opt/amazon/hadoop/logs/hadoop--datanode-ip-10-0-78-117.eu-west-1.compute.internal.out
# starting namenode, logging to /opt/amazon/hadoop/logs/hadoop--namenode-ip-10-0-122-160.eu-west-1.compute.internal.out
# starting nodemanager, logging to /opt/amazon/hadoop/logs/yarn--nodemanager-ip-10-0-68-100.eu-west-1.compute.internal.out
# starting nodemanager, logging to /opt/amazon/hadoop/logs/yarn--nodemanager-ip-10-0-75-30.eu-west-1.compute.internal.out
# starting nodemanager, logging to /opt/amazon/hadoop/logs/yarn--nodemanager-ip-10-0-78-117.eu-west-1.compute.internal.out
# [2020-05-30:15:57:52:ERROR] Customer Error: No file found in path /opt/ml/input/data/train. If you are using ShardedByS3Key, make sure every machine get at least one partition file
# Traceback (most recent call last):
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train.py", line 44, in main
#     distributed_train(resource_config, train_config, data_config)
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train_methods.py", line 49, in distributed_train
#     train_files_size = get_size(train_path)
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train_helper.py", line 213, in get_size
#     dir_path))
# CustomerError: No file found in path /opt/ml/input/data/train. If you are using ShardedByS3Key, make sure every machine get at least one partition file
# Traceback (most recent call last):
#   File "/opt/amazon/bin/ml-train", line 11, in <module>
#     load_entry_point('SageMakerXGBoost==1.0', 'console_scripts', 'ml-train')()
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train.py", line 51, in main
#     train_files_size, val_files_size, mem_size = get_all_sizes()
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train_helper.py", line 507, in get_all_sizes
#     train_files_size = convertToMb(get_size(train_path))
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train_helper.py", line 213, in get_size
#     dir_path))
# sg_algorithms_sdk.base.exceptions.CustomerError: No file found in path /opt/ml/input/data/train. If you are using ShardedByS3Key, make sure every machine get at least one partition file
# [2020-05-30:15:57:52:ERROR] Customer Error: No file found in path /opt/ml/input/data/train. If you are using ShardedByS3Key, make sure every machine get at least one partition file
# Traceback (most recent call last):
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train.py", line 44, in main
#     distributed_train(resource_config, train_config, data_config)
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train_methods.py", line 49, in distributed_train
#     train_files_size = get_size(train_path)
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train_helper.py", line 213, in get_size
#     dir_path))
# CustomerError: No file found in path /opt/ml/input/data/train. If you are using ShardedByS3Key, make sure every machine get at least one partition file
# Traceback (most recent call last):
#   File "/opt/amazon/bin/ml-train", line 11, in <module>
#     load_entry_point('SageMakerXGBoost==1.0', 'console_scripts', 'ml-train')()
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train.py", line 51, in main
#     train_files_size, val_files_size, mem_size = get_all_sizes()
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train_helper.py", line 507, in get_all_sizes
#     train_files_size = convertToMb(get_size(train_path))
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train_helper.py", line 213, in get_size
#     dir_path))
# sg_algorithms_sdk.base.exceptions.CustomerError: No file found in path /opt/ml/input/data/train. If you are using ShardedByS3Key, make sure every machine get at least one partition file
# [2020-05-30:15:57:53:ERROR] Customer Error: No file found in path /opt/ml/input/data/train. If you are using ShardedByS3Key, make sure every machine get at least one partition file
# Traceback (most recent call last):
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train.py", line 44, in main
#     distributed_train(resource_config, train_config, data_config)
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train_methods.py", line 49, in distributed_train
#     train_files_size = get_size(train_path)
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train_helper.py", line 213, in get_size
#     dir_path))
# CustomerError: No file found in path /opt/ml/input/data/train. If you are using ShardedByS3Key, make sure every machine get at least one partition file
# Traceback (most recent call last):
#   File "/opt/amazon/bin/ml-train", line 11, in <module>
#     load_entry_point('SageMakerXGBoost==1.0', 'console_scripts', 'ml-train')()
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train.py", line 51, in main
#     train_files_size, val_files_size, mem_size = get_all_sizes()
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train_helper.py", line 507, in get_all_sizes
#     train_files_size = convertToMb(get_size(train_path))
#   File "/opt/amazon/lib/python2.7/site-packages/sage_xgboost/train_helper.py", line 213, in get_size
#     dir_path))
# sg_algorithms_sdk.base.exceptions.CustomerError: No file found in path /opt/ml/input/data/train. If you are using ShardedByS3Key, make sure every machine get at least one partition file
# starting resourcemanager, logging to /opt/amazon/hadoop/logs/yarn--resourcemanager-ip-10-0-122-160.eu-west-1.compute.internal.out
# starting datanode, logging to /opt/amazon/hadoop/logs/hadoop--datanode-ip-10-0-122-160.eu-west-1.compute.internal.out
# starting nodemanager, logging to /opt/amazon/hadoop/logs/yarn--nodemanager-ip-10-0-122-160.eu-west-1.compute.internal.out
# [2020-05-30:15:58:00:INFO] File size need to be processed in the node: 174.49mb. Available memory size in the node: 7805.46mb
# [2020-05-30:15:58:00:INFO] HTTP server started....
# [2020-05-30:15:58:00:INFO] Memory/core ratio is 7.83
# [2020-05-30:15:58:00:INFO] Yarn setup: number of workers: 4, physical cores per worker: 2, physical memory per worker: 15.67g.
# [2020-05-30:15:58:00:INFO] Yarn job submitted successfully.
# 2020-05-30 15:58:00,475 INFO start listen on 10.0.122.160:9091
# /xgboost/dmlc-core/tracker/dmlc_tracker/yarn.py:37: UserWarning: cannot find "/xgboost/dmlc-core/tracker/dmlc_tracker/../yarn/dmlc-yarn.jar", I will try to run build
#   warnings.warn("cannot find \"%s\", I will try to run build" % YARN_JAR_PATH)
# src/main/java/org/apache/hadoop/yarn/dmlc/Client.java:37: warning: Signal is internal proprietary API and may be removed in a future release
# import sun.misc.Signal;
#                ^
# src/main/java/org/apache/hadoop/yarn/dmlc/Client.java:38: warning: SignalHandler is internal proprietary API and may be removed in a future release
# import sun.misc.SignalHandler;
#                ^
# src/main/java/org/apache/hadoop/yarn/dmlc/Client.java:276: warning: Signal is internal proprietary API and may be removed in a future release
#         Signal intSignal = new Signal("INT");
#         ^
# src/main/java/org/apache/hadoop/yarn/dmlc/Client.java:276: warning: Signal is internal proprietary API and may be removed in a future release
#         Signal intSignal = new Signal("INT");
#                                ^
# src/main/java/org/apache/hadoop/yarn/dmlc/Client.java:277: warning: Signal is internal proprietary API and may be removed in a future release
#         Signal.handle(intSignal, handler);
#         ^
# src/main/java/org/apache/hadoop/yarn/dmlc/Client.java:332: warning: SignalHandler is internal proprietary API and may be removed in a future release
#     class CtrlCHandler implements SignalHandler{
#                                   ^
# src/main/java/org/apache/hadoop/yarn/dmlc/Client.java:339: warning: Signal is internal proprietary API and may be removed in a future release
#         public void handle(Signal signal){
#                            ^
# Note: src/main/java/org/apache/hadoop/yarn/dmlc/ApplicationMaster.java uses unchecked or unsafe operations.
# Note: Recompile with -Xlint:unchecked for details.
# 7 warnings
# 2020-05-30 15:58:05 Uploading - Uploading generated training model
# 2020-05-30 15:58:05 Failed - Training job failed
# 20/05/30 15:58:05 INFO client.RMProxy: Connecting to ResourceManager at algo-1/10.0.122.160:8032
# 20/05/30 15:58:05 INFO dmlc.Client: HDFS temp directory do not exist, creating.. /tmp
# 20/05/30 15:58:06 INFO dmlc.Client: jobname=DMLC[nworker=4]:python,username=root
# 20/05/30 15:58:06 INFO dmlc.Client: Submitting application application_1590854275929_0001
# 20/05/30 15:58:06 INFO impl.YarnClientImpl: Submitted application application_1590854275929_0001
# ---------------------------------------------------------------------------
# UnexpectedStatusException                 Traceback (most recent call last)
# <ipython-input-78-628226b3ae8c> in <module>()
# ----> 1 xgb.fit({'train': s3_input_trains3_inpu, 'validation': s3_input_validation})
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name)
#     299         self.latest_training_job = _TrainingJob.start_new(self, inputs)
#     300         if wait:
# --> 301             self.latest_training_job.wait(logs=logs)
#     302
#     303     def _compilation_job_name(self):
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/estimator.py in wait(self, logs)
#     814         """
#     815         if logs:
# --> 816             self.sagemaker_session.logs_for_job(self.job_name, wait=True)
#     817         else:
#     818             self.sagemaker_session.wait_for_job(self.job_name)
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/session.py in logs_for_job(self, job_name, wait, poll)
#    1464
#    1465         if wait:
# -> 1466             self._check_job_status(job_name, description, "TrainingJobStatus")
#    1467             if dot:
#    1468                 print()
#
# ~/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/sagemaker/session.py in _check_job_status(self, job, desc, status_key_name)
#    1077                 ),
#    1078                 allowed_statuses=["Completed", "Stopped"],
# -> 1079                 actual_status=status,
#    1080             )
#    1081
#
# UnexpectedStatusException: Error for Training job xgboost-2020-05-30-15-54-18-412: Failed. Reason: ClientError: No file found in path /opt/ml/input/data/train. If you are using ShardedByS3Key, make sure every machine get at least one partition file

# %% [markdown]
# ## Deploy the model

# %% [markdown]
# To deploy the model we move to the Amazon Sagemaker console and perform the following steps: <br>
# 1) Create model <br>
# 2) Create an endpoint configuration <br>
# 3) create and endpoint <br>

# %%
xgb_predictor = xgb.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')

# %% [markdown]
# ## Evaluate results

# %% [markdown]
# Parts taken from here:<br>
# https://aws.amazon.com/blogs/machine-learning/simplify-machine-learning-with-xgboost-and-amazon-sagemaker/

# %%
from sagemaker.predictor import csv_serializer

# %%
df_test = pd.read_csv('./df_val.csv', header=None)

# %%
xgb_predictor.content_type = 'text/csv'
xgb_predictor.serializer = csv_serializer
xgb_predictor.deserializer = None

def predict(data, rows=500):
    split_array = np.array_split(data, int(data.shape[0] / float(rows) + 1))
    predictions = ''
    for array in split_array:
        predictions = ','.join([predictions, xgb_predictor.predict(array).decode('utf-8')])

    return np.fromstring(predictions[1:], sep=',')

predictions = predict(df_test.as_matrix()[:, 1:])
predictions

# %%
df_val = pd.DataFrame()
df_val['prediction'] = predictions
df_val['target'] = df_test[0]

# %%
plt.figure(figsize=(15,6))
sns.regplot(x=df_val["target"], y=df_val["prediction"])
plt.show()

# %%
df_val['err'] = (df_val["target"] - df_val["prediction"])

# %%
df_val['err'].plot(kind='hist', bins=100, range=(-6,10), alpha=0.8, figsize=(15,6))
plt.show()

# %%
df_val.describe()

# %% [markdown]
# ## Make online predictions

# %%
import ast

# %%
csv_path = os.path.join('s3://', bucket, path_val, 'year=2015', 'month=4','run-1534713776930-part-r-00000')
df = pd.read_csv(csv_path, header=None)

n = 20
features = df.iloc[0:n,1:].values
values  = df.iloc[0:n,0].values

# %%
endpoint_name = 'xgboost-2018-08-20-19-04-07-244'
content_type = 'text/csv'
data = "\n".join(["\n".join([",".join(str(x) for x in sample)]) for sample in features])

runtime = boto3.Session().client('sagemaker-runtime')
response = runtime.invoke_endpoint(EndpointName=endpoint_name,\
                                   ContentType='text/csv',\
                                   Body=data)

# %%
result = list(ast.literal_eval(response['Body'].read().decode()))
print(result)

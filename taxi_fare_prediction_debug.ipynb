# %% [markdown]
# # Building Taxi Fare Prediction using SageMaker

# %% [markdown]
# <p>This demo notebook guides through the steps in creating an AWS Sagemaker predictions service</p>
# <p>To start using Sagemaker go here: <a href="https://aws.amazon.com/sagemaker/">Sagemaker</a></p>

# %%
# !pip install shap
# !pip install smdebug
# Out:
# Requirement already satisfied: shap in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (0.35.0)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from shap) (0.24.2)
# Requirement already satisfied: tqdm>4.25.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from shap) (4.46.1)
# Requirement already satisfied: scikit-learn in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from shap) (0.22.1)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from shap) (1.4.1)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from shap) (1.16.4)
# Requirement already satisfied: pytz>=2011k in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from pandas->shap) (2018.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from pandas->shap) (2.7.3)
# Requirement already satisfied: joblib>=0.11 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from scikit-learn->shap) (0.14.1)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas->shap) (1.11.0)
# WARNING: You are using pip version 19.3.1; however, version 20.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: smdebug in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (0.8.1)
# Requirement already satisfied: protobuf>=3.6.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from smdebug) (3.8.0)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from smdebug) (1.16.4)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from smdebug) (20.1)
# Requirement already satisfied: boto3>=1.10.32 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from smdebug) (1.12.39)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from protobuf>=3.6.0->smdebug) (45.2.0)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from protobuf>=3.6.0->smdebug) (1.11.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from packaging->smdebug) (2.2.0)
# Requirement already satisfied: botocore<1.16.0,>=1.15.39 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from boto3>=1.10.32->smdebug) (1.15.39)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from boto3>=1.10.32->smdebug) (0.9.4)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from boto3>=1.10.32->smdebug) (0.3.3)
# Requirement already satisfied: docutils<0.16,>=0.10 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from botocore<1.16.0,>=1.15.39->boto3>=1.10.32->smdebug) (0.14)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from botocore<1.16.0,>=1.15.39->boto3>=1.10.32->smdebug) (2.7.3)
# Requirement already satisfied: urllib3<1.26,>=1.20; python_version != "3.4" in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from botocore<1.16.0,>=1.15.39->boto3>=1.10.32->smdebug) (1.23)
# WARNING: You are using pip version 19.3.1; however, version 20.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import os
from s3fs.core import S3FileSystem
import random

import shap

import boto3
from botocore.client import Config
import json

# %%
from sagemaker import get_execution_role

role = get_execution_role()
print(role)
# Out:
# arn:aws:iam::282784146513:role/service-role/AmazonSageMaker-ExecutionRole-20190604T113688

# %%
def load_model(fname):
    model = xgb.XGBClassifier()
    model.load_model(fname)
    with open(fname.replace('.xgboost', '.json'), encoding='utf-8') as fin:
        params = json.load(fin)
    model.set_params(**params)
    return model

# %% [markdown]
# ## Read the whole data from S3

# %%
S3FileSystem.read_timeout = 3600

# %%
s3 = S3FileSystem(anon=False)
bucket = 'aws-worskhop-data/ZIPCHUNKS'
file_list = s3.ls(bucket)
subs = 'ZIPCHUNKS'
res = [i for i in file_list if subs in i]

# %%
# we remove the folder ZIPCHUNKS if it exists (so later we can merge the files in loop)
if 'aws-worskhop-data/ZIPCHUNKS' in res: res.remove('aws-worskhop-data/ZIPCHUNKS')

# %%
res
# Out:
# ['aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaa',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSab',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSac',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSad',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSae',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaf',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSag',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSah',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSai',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaj',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSak',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSal',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSam']

# %%
jj = 0

for filechunk in res:
        print (filechunk)
        if jj == 0:
            with s3.open('aws-worskhop-data/taxinyc_train.csv.zip', 'wb') as f:
                f.write(s3.cat(filechunk))
                jj = jj + 1        
                f.close()
        else:
            with s3.open('aws-worskhop-data/taxinyc_train.csv.zip', 'ab') as f:
                f.write(s3.cat(filechunk))
                jj = jj + 1
                f.close()
# Out:
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaa
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSab
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSac
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSad
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSae
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaf
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSag
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSah
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSai
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaj
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSak
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSal
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSam

# %%
bucket = 'aws-worskhop-data'
path = ''

filename = 'taxinyc_train.csv.zip'
s3_path = os.path.join('s3://', bucket, path, filename)

df_all = pd.read_csv(s3_path, header=0, skiprows=lambda i: i>0 and random.random() > 0.01)

# %%
df_all
# Out:
#         fare_amount  day  dayofweek  year  month  dayofmonth  hour  minute  \
# 0              3.00   27          2  2015      1          27     7      21
# 1              5.70    8          4  2011     12           8    14      56
# 2             11.50   23          4  2014     10          23    12       8
# 3             22.50   30          4  2010     12          30     8      25
# 4             20.50   21          3  2009      1          21     7      10
# 5              5.70    3          1  2011     10           3    20      19
# 6             13.30    9          6  2011      7           9    10       6
# 7              7.50    8          7  2014      6           8    23       5
# 8              6.90    2          5  2010      7           2     5      39
# 9             18.10    2          1  2009      2           2     6      39
# 10            18.00   26          7  2014      1          26     5      28
# 11             8.50    7          1  2014      7           7    10      18
# 12            18.00   26          4  2015      3          26    11      55
# 13            45.00   19          7  2010     12          19     5       7
# 14            83.25   10          5  2013      5          10     8       4
# 15             7.50   25          1  2013      2          25    19      13
# 16             8.00   19          2  2014      8          19     7      56
# 17            57.33   22          4  2014      5          22     2      38
# 18            10.90   21          6  2012      1          21    23      25
# 19             5.30    9          5  2009     10           9     4      12
# 20             7.70   13          3  2010      1          13    16      19
# 21             4.50   16          3  2011      3          16    14      41
# 22             9.00    2          6  2015      5           2     9      17
# 23            29.70    1          5  2012      6           1     9      49
# 24            21.30   12          1  2009      1          12     2       9
# 25             8.00   12          3  2012      9          12    20       3
# 26             5.70   11          1  2010     10          11    18      17
# 27             6.90   24          5  2012      8          24    14      54
# 28            10.50   10          3  2010     11          10    18      16
# 29             5.70    1          7  2009      3           1     9      35
# ...             ...  ...        ...   ...    ...         ...   ...     ...
# 553424         4.50    2          3  2009      9           2    17       2
# 553425         3.70   30          7  2010      5          30     3      41
# 553426         5.30   17          3  2010      3          17    19      58
# 553427        12.90   14          6  2011      5          14    20       6
# 553428         6.00    2          5  2015      1           2    21      53
# 553429         9.70    9          3  2011      3           9    13      39
# 553430        57.33    6          7  2013     10           6    16      33
# 553431        25.50   14          5  2012     12          14     3      55
# 553432         6.00    8          5  2014      8           8     9      53
# 553433         9.50   28          1  2013     10          28    15      29
# 553434         8.10   19          6  2011      3          19    13      18
# 553435        20.50   11          1  2015      5          11    18      53
# 553436        12.50   19          6  2011     11          19    12      43
# 553437         5.70   28          2  2009      4          28    20       7
# 553438         4.10   24          3  2009      6          24    14      25
# 553439         2.90    1          1  2009      6           1    11      48
# 553440         8.50    2          4  2012      8           2    11      45
# 553441        18.50   28          5  2011      1          28     4      23
# 553442         8.90    7          1  2011      2           7    14      28
# 553443         8.00   26          3  2014      2          26     1      50
# 553444        57.33   30          7  2014     11          30    17      21
# 553445         7.30   15          5  2012      6          15    19       0
# 553446        57.33    4          4  2013      7           4    12      31
# 553447        21.50    4          3  2014      6           4    22      25
# 553448        16.50   27          3  2010      1          27     4      21
# 553449        42.27    7          4  2010      1           7    19      17
# 553450         6.00    4          4  2013      4           4    18      17
# 553451        10.00    2          4  2013      5           2    22      40
# 553452         4.50   16          2  2011      8          16     4       1
# 553453         6.50   12          3  2012      9          12     8      49
#
#          sin_day   cos_day  sin_week  cos_week          pickup_datetime  \
# 0      -0.093022 -0.995664 -0.971880  0.235475  2015-01-27 12:21:21 UTC
# 1      -0.872958  0.487796  0.678702  0.734414  2011-12-08 19:56:47 UTC
# 2      -0.883323 -0.468765  0.567527  0.823355  2014-10-23 16:08:11 UTC
# 3      -0.362438 -0.932008  0.480989  0.876727  2010-12-30 13:25:00 UTC
# 4      -0.044854 -0.998994 -0.428100  0.903732  2009-01-21 12:10:17 UTC
# 5       0.082808  0.996566 -0.977495 -0.210959  2011-10-04 00:19:00 UTC
# 6      -0.522499 -0.852640  0.730503 -0.682910  2011-07-09 14:06:00 UTC
# 7       0.722364  0.691513 -0.534668 -0.845062  2014-06-09 03:05:00 UTC
# 8       0.574470 -0.818526  0.951776  0.306793  2010-07-02 09:39:45 UTC
# 9       0.091502 -0.995805 -0.773603 -0.633670  2009-02-02 11:39:00 UTC
# 10      0.390731 -0.920505  0.057315 -0.998356  2014-01-26 10:28:00 UTC
# 11     -0.567425 -0.823425 -0.832605 -0.553867  2014-07-07 14:18:17 UTC
# 12     -0.857130 -0.515100  0.561250  0.827647  2015-03-26 15:55:59 UTC
# 13      0.472551 -0.881303  0.070254 -0.997529  2010-12-19 10:07:12 UTC
# 14     -0.018325 -0.999832  0.975507  0.219968  2013-05-10 12:04:12 UTC
# 15      0.057274  0.998359 -0.976717 -0.214532  2013-02-26 00:13:08 UTC
# 16      0.017452 -0.999848 -0.975480  0.220089  2014-08-19 11:56:00 UTC
# 17      0.986286 -0.165048  0.245549  0.969384  2014-05-22 06:38:00 UTC
# 18      0.916159  0.400815  0.279540 -0.960134  2012-01-22 04:25:29 UTC
# 19      0.837639 -0.546224  0.933677  0.358116  2009-10-09 08:12:26 UTC
# 20     -0.646124  0.763232 -0.100188  0.994969  2010-01-13 21:19:00 UTC
# 21     -0.983414  0.181377 -0.197046  0.980394  2011-03-16 18:41:48 UTC
# 22     -0.333327 -0.942811  0.750654 -0.660696  2015-05-02 13:17:53 UTC
# 23     -0.457874 -0.889017  0.987786  0.155819  2012-06-01 13:49:00 UTC
# 24      0.954523 -0.298139 -0.656710 -0.754144  2009-01-12 07:09:23 UTC
# 25      0.013090  0.999914  0.001870  0.999998  2012-09-13 00:03:00 UTC
# 26     -0.432545  0.901612 -0.958728 -0.284324  2010-10-11 22:17:29 UTC
# 27     -0.972029  0.234859  0.999427 -0.033861  2012-08-24 18:54:20 UTC
# 28     -0.188953  0.981986 -0.027153  0.999631  2010-11-10 23:16:26 UTC
# 29     -0.625923 -0.779884 -0.096466 -0.995336  2009-03-01 14:35:00 UTC
# ...          ...       ...       ...       ...                      ...
# 553424 -0.700909  0.713250 -0.110726  0.993851  2009-09-02 21:02:00 UTC
# 553425  0.904020 -0.427489  0.160599 -0.987020  2010-05-30 07:41:14 UTC
# 553426 -0.006836  0.999977 -0.000977  1.000000  2010-03-17 23:58:26 UTC
# 553427  0.026177  0.999657  0.430511 -0.902585  2011-05-15 00:06:00 UTC
# 553428  0.685289  0.728271  0.945309 -0.326177  2015-01-03 02:53:02 UTC
# 553429 -0.985556  0.169350 -0.198757  0.980049  2011-03-09 18:39:00 UTC
# 553430 -0.784235  0.620464 -0.314584 -0.949230  2013-10-06 20:33:24 UTC
# 553431  0.722364 -0.691513  0.942849  0.333219  2012-12-14 08:55:00 UTC
# 553432 -0.474152 -0.880443  0.988192  0.153222  2014-08-08 13:53:13 UTC
# 553433 -0.924657  0.380801 -0.923768 -0.382952  2013-10-28 19:29:32 UTC
# 553434 -0.983255 -0.182236  0.643742 -0.765243  2011-03-19 17:18:00 UTC
# 553435 -0.288057  0.957613 -0.964793 -0.263011  2015-05-11 22:53:02 UTC
# 553436 -0.997357 -0.072658  0.631578 -0.775312  2011-11-19 17:43:20 UTC
# 553437  0.032356  0.999476 -0.778941  0.627098  2009-04-29 00:07:25 UTC
# 553438 -0.993703  0.112047 -0.206855  0.978372  2009-06-24 18:25:44 UTC
# 553439 -0.838671 -0.544639 -0.862261 -0.506464  2009-06-01 15:48:00 UTC
# 553440 -0.833364 -0.552725  0.555976  0.831198  2012-08-02 15:45:47 UTC
# 553441  0.631747 -0.775174  0.948577  0.316546  2011-01-28 09:23:17 UTC
# 553442 -0.926884  0.375348 -0.923446 -0.383729  2011-02-07 19:28:11 UTC
# 553443  0.976296 -0.216440 -0.598824  0.800881  2014-02-26 06:50:00 UTC
# 553444 -0.418660  0.908143 -0.377494 -0.926012  2014-11-30 22:21:00 UTC
# 553445 -0.258398  0.966039  0.982555 -0.185973  2012-06-15 23:00:06 UTC
# 553446 -0.925541 -0.378649  0.579180  0.815200  2013-07-04 16:31:00 UTC
# 553447  0.593126  0.805110  0.090581  0.995889  2014-06-05 02:25:31 UTC
# 553448  0.638992 -0.769214 -0.520832  0.853659  2010-01-27 09:21:08 UTC
# 553449  0.074906  0.997191  0.788465  0.615080  2010-01-08 00:17:11 UTC
# 553450 -0.433462  0.901172  0.740323  0.672251  2013-04-04 22:17:15 UTC
# 553451  0.643901  0.765109  0.840139  0.542372  2013-05-03 02:40:20 UTC
# 553452  0.863836 -0.503774 -0.997157  0.075352  2011-08-16 08:01:00 UTC
# 553453 -0.213954 -0.976844 -0.405930  0.913904  2012-09-12 12:49:25 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -73.958690        40.781070         -73.954850
# 1             -73.982710        40.755886         -73.976750
# 2             -73.965490        40.769070         -73.977660
# 3             -73.783310        40.643070         -73.788640
# 4             -73.941315        40.839350         -73.995190
# 5             -73.959250        40.771484         -73.946550
# 6             -73.995740        40.728237         -73.963700
# 7             -73.984740        40.758938         -73.973150
# 8             -73.982450        40.735794         -73.969215
# 9             -73.951100        40.770683         -74.008330
# 10            -73.975270        40.765250         -74.010470
# 11            -74.004524        40.741894         -73.991554
# 12            -73.976500        40.750190         -73.952010
# 13            -73.776920        40.645996         -73.986100
# 14            -73.985220        40.751072         -74.176956
# 15            -73.971344        40.762928         -73.949970
# 16            -73.970790        40.756690         -73.990310
# 17            -73.781230        40.644943         -73.944435
# 18            -73.958954        40.764126         -73.946150
# 19            -73.998375        40.720154         -73.987280
# 20            -73.986460        40.762444         -73.979860
# 21            -73.962910        40.765118         -73.963380
# 22            -73.982216        40.772614         -73.957960
# 23            -73.990364        40.750927         -73.867310
# 24            -73.967384        40.757706         -73.942970
# 25            -74.001230        40.729153         -74.005210
# 26            -74.002990        40.733517         -74.005740
# 27            -73.955700        40.776585         -73.938126
# 28            -73.981990        40.768867         -73.965900
# 29            -73.956680        40.779990         -73.960050
# ...                  ...              ...                ...
# 553424        -73.985016        40.742664         -73.978264
# 553425        -73.978226        40.741420         -73.984900
# 553426        -73.991790        40.744293         -73.978935
# 553427        -74.006820        40.731377         -73.976290
# 553428        -73.981674        40.746555         -73.973335
# 553429        -73.952576        40.772804         -73.978000
# 553430        -73.790146        40.643467         -73.999840
# 553431        -74.009420        40.724186         -73.968170
# 553432        -73.975204        40.765404         -73.972010
# 553433        -73.997925        40.751137         -73.998344
# 553434        -74.028175        40.745304         -74.032326
# 553435        -73.988200        40.737760         -73.922340
# 553436        -73.960144        40.761986         -73.965780
# 553437        -73.993720        40.767258         -73.993350
# 553438        -73.977844        40.742200         -73.985050
# 553439        -73.950640        40.783230         -73.950660
# 553440        -73.985910        40.756634         -73.977394
# 553441        -73.985954        40.740948         -73.971500
# 553442        -73.997310        40.741676         -73.982290
# 553443        -73.988130        40.775110         -73.972770
# 553444        -73.784904        40.648560         -73.985280
# 553445        -73.968940        40.755962         -73.985050
# 553446        -73.776770        40.645480         -73.940240
# 553447        -73.976190        40.730760         -73.976190
# 553448        -73.977516        40.789810         -73.990950
# 553449        -73.874790        40.774240         -73.988760
# 553450        -73.998505        40.724686         -73.990100
# 553451        -73.987850        40.722588         -73.972160
# 553452        -73.938416        40.850964         -73.936850
# 553453        -73.952990        40.783146         -73.962950
#
#         dropoff_latitude  passenger_count
# 0              40.783210                1
# 1              40.764824                1
# 2              40.754616                1
# 3              40.636410                3
# 4              40.749950                2
# 5              40.791523                2
# 6              40.757893                5
# 7              40.754818                1
# 8              40.758220                1
# 9              40.735880                1
# 10             40.720180                6
# 11             40.751270                1
# 12             40.773300                1
# 13             40.759995                1
# 14             40.692326                4
# 15             40.777170                1
# 16             40.756670                2
# 17             40.815525                1
# 18             40.766050                1
# 19             40.724747                1
# 20             40.743240                1
# 21             40.758774                1
# 22             40.762867                5
# 23             40.770454                5
# 24             40.841770                1
# 25             40.709465                1
# 26             40.745422                2
# 27             40.804710                1
# 28             40.793990                2
# 29             40.762756                5
# ...                  ...              ...
# 553424         40.751347                3
# 553425         40.732550                1
# 553426         40.752540                1
# 553427         40.784664                2
# 553428         40.743786                1
# 553429         40.748140                3
# 553430         40.744980                2
# 553431         40.757477                1
# 553432         40.757458                1
# 553433         40.724950                2
# 553434         40.750830                1
# 553435         40.698364                4
# 553436         40.803913                1
# 553437         40.752150                2
# 553438         40.732280                1
# 553439         40.785780                2
# 553440         40.764520                3
# 553441         40.781956                1
# 553442         40.723420                1
# 553443         40.759750                5
# 553444         40.738487                3
# 553445         40.769170                2
# 553446         40.738857                1
# 553447         40.730760                1
# 553448         40.741620                1
# 553449         40.744663                3
# 553450         40.719040                4
# 553451         40.747368                1
# 553452         40.842564                1
# 553453         40.769470                1
#
# [553454 rows x 18 columns]

# %% [markdown]
# ## Start Exploring the data

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-whitegrid')
# %matplotlib inline

# %%
# Sample the data - because it only take a 100K records to feel the data
df_all = df_all.sample(int(1e5))

# %%
df_small = df_all.sample(int(1e2))
df_small
# Out:
#         fare_amount  day  dayofweek  year  month  dayofmonth  hour  minute  \
# 544014        16.00   17          6  2015      1          17     9      19
# 276648        10.50   10          6  2014      5          10    19      42
# 417507         5.30    8          1  2011      8           8    17      21
# 93144         10.00   28          5  2012     12          28     5       0
# 496079         4.50   14          3  2009     10          14    18      51
# 257914         6.50   27          7  2009     12          27    11      16
# 383456        12.50   28          6  2009      3          28     8       3
# 360342         9.00    7          6  2013     12           7    19      56
# 439794         9.50   13          6  2013      7          13     6       5
# 453839         4.90   16          5  2011      9          16     4       1
# 444174        26.83   18          4  2014     12          18    15      43
# 354242        13.00    2          2  2015      6           2     5      25
# 494385         7.30    1          5  2011      4           1     8      22
# 314175         4.10   20          1  2010     12          20     2      50
# 72043         11.50    2          2  2014     12           2     7      28
# 510864        28.00   26          3  2014      2          26     3      56
# 200102        12.50   10          1  2014      3          10    16      16
# 253730        11.50   21          4  2015      5          21    22      53
# 309372         4.50   12          3  2012      9          12    18      52
# 296163        33.33   28          2  2014     10          28     2      57
# 172232         8.50    9          5  2014      5           9     3      44
# 312949        17.00    8          7  2014      6           8    16      56
# 534903         2.50   23          5  2011      9          23    21      48
# 22102          4.50   12          6  2009      9          12     7      14
# 109849         6.50   29          2  2014      4          29    13      36
# 388415         7.50   14          1  2013      1          14    14       1
# 426492        12.10   15          5  2010      1          15    15      19
# 203689         7.00   26          2  2013      3          26    14      31
# 305572         8.50    3          2  2009      2           3     4      14
# 355745        27.33   19          5  2014     12          19    15      11
# ...             ...  ...        ...   ...    ...         ...   ...     ...
# 132486        57.33   11          4  2013      7          11    14      43
# 315172        18.10   28          6  2012      4          28    16       0
# 32299         46.83    5          3  2013      6           5    19      26
# 417384        10.90   30          5  2012      3          30    17      45
# 67434          5.30   14          3  2010      4          14     2      44
# 16721         37.30   10          4  2011     11          10    10      48
# 449390        19.70   21          3  2010      4          21     9      13
# 445858        21.50    8          2  2013     10           8    17       3
# 343268         3.70   16          4  2010      9          16     0      17
# 546505        22.50   24          4  2012      5          24    12      48
# 81705          9.00   31          4  2013      1          31     3      42
# 151728        11.30   20          7  2011      3          20    17      32
# 66947         13.70   31          7  2009      5          31    18      54
# 145870         9.70   23          5  2010      7          23    14      55
# 531470        15.30    6          2  2010      7           6    21      16
# 258239         7.70    5          2  2010      1           5     3      12
# 405538        10.10    1          5  2009      5           1    13      13
# 345999         7.70    9          1  2011      5           9     8      31
# 160475         4.10   26          4  2012      4          26     4      38
# 508502        24.90    2          4  2011      6           2    17      37
# 228932        14.90   16          5  2009     10          16    17      20
# 228797        14.00   19          4  2013     12          19    16       3
# 204458         7.30    2          3  2011      2           2    14       7
# 483511         6.10   18          6  2012      2          18    14      30
# 550897         4.10    6          4  2009      8           6    13      57
# 549210        10.10   14          4  2011      7          14    17       0
# 150063         6.50   16          5  2014      5          16     6      21
# 194878         8.50   11          2  2013      6          11     3      39
# 421451        12.00    5          1  2012     11           5    14       6
# 119160         6.00   13          3  2014      8          13    16      32
#
#          sin_day   cos_day  sin_week  cos_week          pickup_datetime  \
# 544014 -0.570773 -0.821108  0.724852 -0.688904  2015-01-17 14:19:13 UTC
# 276648 -0.078459  0.996917  0.443965 -0.896044  2014-05-10 23:42:00 UTC
# 417507 -0.636190  0.771532 -0.948317 -0.317324  2011-08-08 21:21:58 UTC
# 93144   0.500000 -0.866025  0.955573  0.294755  2012-12-28 10:00:00 UTC
# 496079 -0.296542  0.955020 -0.042997  0.999075  2009-10-14 22:51:00 UTC
# 257914 -0.898794 -0.438371 -0.158897 -0.987295  2009-12-27 16:16:00 UTC
# 383456 -0.014035 -0.999902  0.780580 -0.625056  2009-03-28 12:03:13 UTC
# 360342  0.241922  0.970296  0.402176 -0.915562  2013-12-08 00:56:00 UTC
# 439794  0.480989 -0.876727  0.824479 -0.565892  2013-07-13 10:05:00 UTC
# 453839  0.862109 -0.506724  0.931279  0.364306  2011-09-16 08:01:47 UTC
# 444174 -0.754757  0.656004  0.700012  0.714131  2014-12-18 20:43:59 UTC
# 354242  0.622628 -0.782518 -0.991770  0.128033  2015-06-02 09:25:58 UTC
# 494385 -0.097366 -0.995249  0.977933  0.208918  2011-04-01 12:22:21 UTC
# 314175  0.887011 -0.461749 -0.675590 -0.737277  2010-12-20 07:50:00 UTC
# 72043  -0.121869 -0.992546 -0.970896  0.239502  2014-12-02 12:28:00 UTC
# 510864  0.719340 -0.694658 -0.534142  0.845395  2014-02-26 08:56:00 UTC
# 200102 -0.829038  0.559193 -0.934471 -0.356039  2014-03-10 20:16:00 UTC
# 253730  0.688144  0.725575  0.844706  0.535230  2015-05-22 02:53:56 UTC
# 309372 -0.288962  0.957341 -0.041865  0.999123  2012-09-12 22:52:49 UTC
# 296163  0.968239 -0.250028 -0.999348  0.036093  2014-10-28 06:57:55 UTC
# 172232  0.898794 -0.438371  0.927184  0.374607  2014-05-09 07:44:00 UTC
# 312949 -0.717367  0.696696 -0.328307 -0.944571  2014-06-08 20:56:39 UTC
# 534903  0.453990  0.891007  0.957751 -0.287599  2011-09-24 01:48:00 UTC
# 22102   0.199368 -0.979925  0.799385 -0.600819  2009-09-12 11:14:00 UTC
# 109849 -0.994695 -0.102865 -0.907258  0.420574  2014-04-29 17:36:23 UTC
# 388415 -0.964787  0.263031 -0.916811 -0.399321  2013-01-14 19:01:00 UTC
# 426492 -0.820817  0.571191  0.996231 -0.086742  2010-01-15 20:19:20 UTC
# 203689 -0.990866  0.134851 -0.892417  0.451211  2013-03-26 18:31:00 UTC
# 305572  0.662348 -0.749197 -0.992691  0.120683  2009-02-03 09:14:05 UTC
# 355745 -0.841039  0.540974  0.996668 -0.081566  2014-12-19 20:11:00 UTC
# ...          ...       ...       ...       ...                      ...
# 132486 -0.982450  0.186524  0.644219  0.764841  2013-07-11 18:43:00 UTC
# 315172 -0.863945  0.503586  0.562831 -0.826572  2012-04-28 20:00:57 UTC
# 32299  -0.146299  0.989240 -0.020974  0.999780  2013-06-05 23:26:21 UTC
# 417384 -0.555570  0.831470  0.990181 -0.139790  2012-03-30 21:45:00 UTC
# 67434   0.981349 -0.192237 -0.601649  0.798761  2010-04-14 06:44:20 UTC
# 16721  -0.838671 -0.544639  0.557124  0.830429  2011-11-10 15:48:00 UTC
# 449390 -0.314407 -0.949288 -0.392280  0.919846  2010-04-21 13:13:18 UTC
# 445858 -0.695808  0.718228 -0.845517  0.533948  2013-10-08 21:03:38 UTC
# 343268  0.900698  0.434445  0.159512  0.987196  2010-09-16 04:17:00 UTC
# 546505 -0.951751 -0.306872  0.588046  0.808828  2012-05-24 16:48:31 UTC
# 81705   0.759602 -0.650388  0.319835  0.947473  2013-01-31 08:42:17 UTC
# 151728 -0.601815  0.798636 -0.349039 -0.937108  2011-03-20 21:32:00 UTC
# 66947  -0.284015  0.958820 -0.396461 -0.918051  2009-05-31 22:54:00 UTC
# 145870 -0.971342  0.237686  0.999412 -0.034277  2010-07-23 18:55:00 UTC
# 531470  0.327149  0.944973 -0.751271  0.659994  2010-07-07 01:16:23 UTC
# 258239  0.838155 -0.545432 -0.996606  0.082322  2010-01-05 08:12:13 UTC
# 405538 -0.979045 -0.203642  0.999571  0.029292  2009-05-01 17:13:00 UTC
# 345999 -0.134851 -0.990866 -0.793733 -0.608267  2011-05-09 12:31:00 UTC
# 160475  0.771625 -0.636078  0.317305  0.948324  2012-04-26 08:38:00 UTC
# 508502 -0.583718  0.811956  0.723290  0.690544  2011-06-02 21:37:09 UTC
# 228932 -0.642788  0.766044  0.992239 -0.124344  2009-10-16 21:20:00 UTC
# 228797 -0.697790  0.716302  0.708428  0.705783  2013-12-19 21:03:00 UTC
# 204458 -0.956432  0.291954 -0.181071  0.983470  2011-02-02 19:07:54 UTC
# 483511 -0.923796  0.382885  0.578646 -0.815579  2012-02-18 19:30:03 UTC
# 550897 -0.999914 -0.013090  0.622027  0.782996  2009-08-06 17:57:00 UTC
# 549210 -0.707107  0.707107  0.707107  0.707107  2011-07-14 21:00:00 UTC
# 150063  0.418660 -0.908143  0.959349  0.282222  2014-05-16 10:21:00 UTC
# 194878  0.907533 -0.419980 -0.998084  0.061878  2013-06-11 07:39:20 UTC
# 421451 -0.958820  0.284015 -0.918051 -0.396461  2012-11-05 19:06:00 UTC
# 119160 -0.788011  0.615661 -0.129290  0.991607  2014-08-13 20:32:00 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 544014        -74.006294        40.706856         -74.007640
# 276648        -73.980220        40.757755         -73.975980
# 417507        -73.970980        40.758556         -73.972830
# 93144         -73.978200        40.752193         -73.960980
# 496079        -73.981320        40.746037         -73.975130
# 257914        -73.950490        40.783510         -73.931984
# 383456        -73.984290        40.759567         -74.001470
# 360342        -74.006714        40.744230         -73.993320
# 439794        -74.001920        40.740550         -73.981230
# 453839        -73.974170        40.743176         -73.981094
# 444174        -73.885360        40.773075         -73.974800
# 354242        -73.990010        40.751560         -73.986336
# 494385        -73.986946        40.742847         -73.977940
# 314175        -73.978380        40.752650         -73.982620
# 72043         -73.977670        40.757750         -73.980760
# 510864        -73.954840        40.765812         -73.981720
# 200102        -74.011780        40.713696         -73.991320
# 253730        -73.979710        40.760520         -73.945230
# 309372        -73.972496        40.757880         -73.986090
# 296163        -73.980630        40.734090         -73.861720
# 172232        -73.961070        40.772010         -73.978240
# 312949        -73.999320        40.720303         -73.985340
# 534903          0.000000         0.000000           0.000000
# 22102         -73.981970        40.743618         -73.978600
# 109849        -73.984160        40.764847         -73.979836
# 388415        -73.985725        40.735510         -73.990390
# 426492        -73.974170        40.757015         -74.008680
# 203689        -73.960710        40.766357         -73.972374
# 305572        -73.978060        40.752700         -73.994070
# 355745        -74.001970        40.738697         -73.985590
# ...                  ...              ...                ...
# 132486        -73.790690        40.644090         -73.928530
# 315172        -73.925180        40.768494         -74.000710
# 32299         -73.980675        40.759290         -74.032646
# 417384        -73.989784        40.718678         -73.973240
# 67434         -73.994550        40.750534         -73.979180
# 16721         -73.870790        40.773620         -73.988730
# 449390        -73.942820        40.790066         -74.001490
# 445858        -74.009170        40.716230         -73.970680
# 343268        -73.983580        40.765400         -73.947310
# 546505        -73.979260        40.767185         -74.004600
# 81705         -73.961780        40.767357         -73.976240
# 151728        -74.011314        40.715164         -73.977380
# 66947         -73.973380        40.751340         -73.915420
# 145870        -73.979485        40.752296         -73.947650
# 531470        -73.990130        40.756115         -73.949684
# 258239        -74.004130        40.742817         -73.994750
# 405538        -73.966460        40.767510         -73.987110
# 345999        -73.999400        40.741776         -74.010600
# 160475        -73.987144        40.733450         -73.994330
# 508502        -73.862570        40.768898         -73.994040
# 228932        -73.977370        40.752655         -73.981125
# 228797        -73.999600        40.743755         -73.959550
# 204458        -73.954400        40.784115         -73.967160
# 483511        -73.984310        40.779980         -73.968570
# 550897        -73.976360        40.790813         -73.969680
# 549210        -73.987530        40.738857         -73.952310
# 150063          0.000000         0.000000           0.000000
# 194878        -73.994170        40.751102         -73.971470
# 421451        -73.984970        40.763943         -74.004490
# 119160        -73.994680        40.746250         -73.992320
#
#         dropoff_latitude  passenger_count
# 544014         40.740870                2
# 276648         40.786366                1
# 417507         40.746650                1
# 93144          40.768430                1
# 496079         40.756104                1
# 257914         40.795326                2
# 383456         40.719860                2
# 360342         40.735912                1
# 439794         40.768314                5
# 453839         40.750492                1
# 444174         40.747883                1
# 354242         40.740420                5
# 494385         40.761436                1
# 314175         40.747353                2
# 72043          40.764156                5
# 510864         40.690186                4
# 200102         40.746510                1
# 253730         40.775265                1
# 309372         40.763035                2
# 296163         40.768430                1
# 172232         40.752350                1
# 312949         40.666380                1
# 534903          0.000000                1
# 22102          40.745200                1
# 109849         40.776100                1
# 388415         40.748367                2
# 426492         40.731976                1
# 203689         40.749370                1
# 305572         40.745857                1
# 355745         40.669980                1
# ...                  ...              ...
# 132486         40.864136                1
# 315172         40.741478                1
# 32299          40.634106                1
# 417384         40.748436                1
# 67434          40.751053                1
# 16721          40.762020                2
# 449390         40.715935                3
# 445858         40.750126                1
# 343268         40.791004                1
# 546505         40.707195                1
# 81705          40.760190                1
# 151728         40.733960                1
# 66947          40.749832                3
# 145870         40.775112                1
# 531470         40.727100                1
# 258239         40.749542                1
# 405538         40.746613                2
# 345999         40.713850                1
# 160475         40.729294                1
# 508502         40.724754                1
# 228932         40.720900                2
# 228797         40.767635                1
# 204458         40.765170                1
# 483511         40.801730                1
# 550897         40.794860                2
# 549210         40.772675                1
# 150063          0.000000                1
# 194878         40.763350                1
# 421451         40.742252                2
# 119160         40.737698                1
#
# [100 rows x 18 columns]

# %%
df_all.describe()
# Out:
#          fare_amount            day      dayofweek           year  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       11.337983      15.690310       3.985870    2011.736600
# std        10.418980       8.680282       1.908724       1.862051
# min        -7.000000       1.000000       1.000000    2008.000000
# 25%         6.000000       8.000000       2.000000    2010.000000
# 50%         8.500000      16.000000       4.000000    2012.000000
# 75%        12.500000      23.000000       6.000000    2013.000000
# max      1097.480000      31.000000       7.000000    2015.000000
#
#                month     dayofmonth           hour         minute  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        6.263960      15.690310      11.775360      29.641370
# std         3.436449       8.680282       5.843874      17.345059
# min         1.000000       1.000000       0.000000       0.000000
# 25%         3.000000       8.000000       7.000000      15.000000
# 50%         6.000000      16.000000      12.000000      30.000000
# 75%         9.000000      23.000000      17.000000      45.000000
# max        12.000000      31.000000      23.000000      59.000000
#
#              sin_day        cos_day       sin_week       cos_week  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       -0.202148      -0.046526       0.044627       0.027258
# std         0.653247       0.728183       0.711169       0.701081
# min        -1.000000      -1.000000      -1.000000      -1.000000
# 25%        -0.816642      -0.777146      -0.710339      -0.669594
# 50%        -0.336684      -0.115371       0.031785       0.074730
# 75%         0.366501       0.709596       0.721501       0.730522
# max         1.000000       1.000000       1.000000       1.000000
#
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# count     100000.000000    100000.000000      100000.000000     100000.000000
# mean         -72.472312        39.931597         -72.548193         39.900868
# std           15.882166         7.558636          14.777307          9.584905
# min         -736.566650      -503.113200       -3394.483000      -2103.962000
# 25%          -73.992220        40.734820         -73.991320         40.733917
# 50%          -73.981800        40.752693         -73.980090         40.753220
# 75%          -73.967090        40.767265         -73.963615         40.768147
# max         2815.895500      1293.444200          40.786800        410.333340
#
#        passenger_count
# count    100000.000000
# mean          1.692130
# std           1.603837
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max         208.000000

# %% [markdown]
# ### Date-Time Features

# %%
df_all['ts'] = df_all['pickup_datetime'].apply(pd.Timestamp)
df_all['weekday'] = df_all['ts'].dt.weekday
df_all['day'] = df_all['ts'].dt.day
df_all['month'] = df_all['ts'].dt.month
df_all['year'] = df_all['ts'].dt.year
df_all['hour'] = df_all['ts'].dt.hour

# %%
time_features = ['day', 'month', 'weekday', 'year', 'hour']

fig = plt.figure(figsize=(20,12))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(len(time_features)):
    ax = fig.add_subplot(2, 3, i+1)
    sns.boxplot(x=time_features[i], y="fare_amount", data=df_all[df_all['year'] >= 2013], showfliers=False)

plt.show()

# %% [markdown]
# ### Geographic

# %% [markdown]
# https://www.kaggle.com/breemen/nyc-taxi-fare-data-exploration

# %%
nyc_box = (-74.1, -73.7, 40.6, 40.9)

# %%
def filter_coordinates(df, box):
    return (df.pickup_longitude >= box[0]) & (df.pickup_longitude <= box[1]) & \
           (df.pickup_latitude >= box[2]) & (df.pickup_latitude <=box[3]) & \
           (df.dropoff_longitude >= box[0]) & (df.dropoff_longitude <= box[1]) & \
           (df.dropoff_latitude >= box[2]) & (df.dropoff_latitude <= box[3])

# %%
def plot_hires(df, box, figsize=(12, 12), ax=None, c=sns.color_palette("husl", 2)):
    if ax == None:
        fig, ax = plt.subplots(1, 1, figsize=figsize)

    idx = filter_coordinates(df, box)
    ax.scatter(df[idx].pickup_longitude, df[idx].pickup_latitude, c=c[0], s=0.1, lw=0.1, alpha=0.5)
    ax.scatter(df[idx].dropoff_longitude, df[idx].dropoff_latitude, c=c[1], s=0.1, lw=0.1, alpha=0.5)

# %%
plot_hires(df_all, nyc_box)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# <p>In the scatter plot above, the two major NYC airports are easily observed, indicating that it may be informative to "tell" our algorithm whether the ride starts or ends in an airport.</p>
# <p>To do so I use the airports.csv, available <a href="http://ourairports.com/data/">here</a> in the following way:</p>
# <ul>
# <li>from this file I extract the location of 3 of the listed NYC airports</li>
# <li>I than calculate the distance of dropoff and pickup points from every record to each airport, Assuming it will provide additional information to our model.</li>
# </ul>
# <p>Further details are in the feature extraction below</p>

# %% [markdown]
# ## Ride distance

# %%
df_all['air_distance'] = (df_all.pickup_longitude - df_all.dropoff_longitude)**2 +\
                     (df_all.pickup_latitude - df_all.dropoff_latitude)**2
df_all['air_distance'] = np.sqrt(df_all['air_distance'])

# %%
df_all['price_per_distance'] = df_all['fare_amount'] / df_all['air_distance']

# %%
time_features = ['weekday', 'year', 'hour']
fig = plt.figure(figsize=(18,5))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(len(time_features)):
    ax = fig.add_subplot(1, 3, i+1)
    sns.boxplot(x=time_features[i], y="price_per_distance", data=df_all[df_all['year'] >= 2013], showfliers=False)

plt.show()
# Out:
# invalid value encountered in reduce

# %%
time_features = ['weekday', 'year', 'hour']
fig = plt.figure(figsize=(18,5))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(len(time_features)):
    ax = fig.add_subplot(1, 3, i+1)
    sns.boxplot(x=time_features[i], y="air_distance", data=df_all[df_all['year'] >= 2013], showfliers=False)

plt.show()

# %% [markdown]
# ## Split train test

# %% [markdown]
# <p>If you managed to create the dataset using Athena, you have two options on how to create train and validation sets files.&nbsp;</p>
# <ol>
# <li>Create a seperate query, using a WHERE on the year clause to split the train and validation by time (e.g. year, month)</li>
# <li>Create a single query, partition the results by time, and use aws-cli to mv the directories to different train/validation directotires</li>
# </ol>

# %% [markdown]
# ## Train model

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
import sagemaker
from sagemaker import get_execution_role
import boto3
from datetime import datetime
import os
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
bucket = 'aws-worskhop-data'

path_train = 'taxinyc-query-results/train/78a6a6df-267a-4783-bef4-fd6eb4f082fa.csv'
path_validate = 'taxinyc-query-results/validate/60c4073e-00bc-4e80-a9aa-d93e53687a28.csv' 

s3_path_2014 = os.path.join('s3://', bucket, path_train)
s3_path_2015 = os.path.join('s3://', bucket, path_validate)

# %%
df_2014 = pd.read_csv(s3_path_2014, header=0, skiprows=lambda i: i>0 and random.random() > 0.1)

#n = 10  # every 100th line = 1% of the lines
#df_2014 = pd.read_csv(s3_path_2014, header=0, skiprows=lambda i: i % n != 0)

df_2014
df_2014.to_csv('train_small_2014.csv', header=False, index=False)
df_2014_final = pd.read_csv('./train_small_2014.csv')
df_2014_final
# Out:
#           8.5  23  7  2014   3  23.1   8  35  -0.15305770187116807  \
# 0       14.50  30  4  2014   1    30  11  24             -0.915077
# 1        9.50  14  3  2014   5    14  14  44             -0.981627
# 2        6.50  23  1  2014   6    23  17  48             -0.541403
# 3        6.50  17  7  2014   8    17  10   0             -0.500000
# 4       10.50  24  7  2014   8    24  14  38             -0.986286
# 5        6.50   8  1  2014   9     8   7  25              0.152123
# 6        8.00  26  7  2014  10    26  17  25             -0.625923
# 7       18.00  18  2  2014   3    18  14  38             -0.985605
# 8       11.50  20  6  2014  12    20   6  18              0.178731
# 9       11.50  20  4  2014  11    20   6  49              0.047978
# 10      17.00   7  5  2014  11     7  17  28             -0.387314
# 11       5.00  24  5  2014  10    24  11  29             -0.790690
# 12      15.00   6  7  2014   4     6  17  44             -0.559193
# 13       6.00   8  6  2014   2     8  13  46             -0.979385
# 14       5.50  27  1  2014  10    27  20  46              0.199368
# 15      43.33   6  5  2014   6     6   4  35              0.779884
# 16       5.50  24  1  2014  11    24  14  57             -0.872496
# 17       4.50   2  2  2014  12     2  16  11             -0.672367
# 18       6.00  18  5  2014   4    18  17  45             -0.555207
# 19      57.33   3  3  2014   9     3   3  34              0.917060
# 20      12.50  21  5  2014   2    21  16  40             -0.573576
# 21      11.50   7  7  2014   9     7  17  23             -0.632705
# 22       5.50  31  5  2014   1    31  12  45             -0.997859
# 23      36.50  20  7  2014   7    20   0   5              0.876727
# 24       6.00  19  3  2014   3    19  13  17             -0.982464
# 25      10.00   2  5  2014   5     2   5  30              0.608761
# 26      11.00  11  3  2014   6    11  20  53              0.231111
# 27       8.50   2  7  2014   3     2  14   0             -0.965926
# 28      19.00   4  2  2014  11     4   3  36              0.777146
# 29       4.50  25  6  2014   1    25   4  35              0.591310
# ...       ...  .. ..   ...  ..   ...  ..  ..                   ...
# 824728  16.00   2  7  2014  11     2  14  14             -0.948324
# 824729   9.00  13  5  2014   6    13  20  46              0.199368
# 824730  12.50   8  6  2014  11     8  13   1             -0.999983
# 824731  15.00   3  6  2014   5     3   8  42             -0.184523
# 824732  39.33  20  1  2014   1    20  12  25             -0.988362
# 824733  11.00  18  4  2014  12    18   4  12              0.667345
# 824734  19.50  11  6  2014  10    11  16  54             -0.725174
# 824735   8.50  14  1  2014   4    14  18   7             -0.472871
# 824736   3.50  21  1  2014   4    21  18  26             -0.398749
# 824737  26.00  17  5  2014  10    17  17  28             -0.612965
# 824738   4.00  21  1  2014   7    21  11  49             -0.841432
# 824739   6.50  18  2  2014  11    18  15   2             -0.860631
# 824740  16.50  28  1  2014   4    28  18   7             -0.471653
# 824741   8.50   2  7  2014   2     2  15  53             -0.728371
# 824742   6.50  14  4  2014   8    14   9  25             -0.364741
# 824743   7.50  10  1  2014  11    10  10  42             -0.826098
# 824744   6.50  19  5  2014   9    19  13  47             -0.998392
# 824745   7.50  30  2  2014  12    30  17  56             -0.275358
# 824746  14.00  29  3  2014   1    29   2  54              0.877739
# 824747  10.00  30  6  2014   8    30  16  12             -0.838671
# 824748   8.50  14  5  2014  11    14   3  47              0.746057
# 824749  12.50  21  2  2014  10    21  15  58             -0.870356
# 824750   6.00  27  3  2014   8    27  18  36             -0.358096
# 824751  11.50  21  7  2014   9    21   8  11             -0.047978
# 824752  50.33  15  7  2014   6    15   2   6              0.999640
# 824753  18.50  12  3  2014   2    12   7  26             -0.113203
# 824754   6.50  15  2  2014   4    15  15  50             -0.887011
# 824755  11.00   1  6  2014   2     1   5  30              0.382683
# 824756   4.00  26  3  2014  11    26   3  12              0.837043
# 824757   4.00  29  7  2014   6    29   7  45              0.065403
#
#         -0.988217253390122  -0.02194990793510307  -0.9997590717476088  \
# 0                -0.403279              0.576059             0.817408
# 1                 0.190809             -0.195702             0.980663
# 2                 0.840764             -0.953507            -0.301370
# 3                -0.866025             -0.074730            -0.997204
# 4                 0.165048             -0.245549            -0.969384
# 5                -0.988362             -0.768044            -0.640397
# 6                 0.779884             -0.344947            -0.938622
# 7                 0.169063             -0.890175             0.455619
# 8                -0.983898              0.797578            -0.603216
# 9                -0.998848              0.427696             0.903923
# 10                0.921948              0.985991            -0.166799
# 11               -0.612217              0.995574             0.093984
# 12                0.829038             -0.356039            -0.934471
# 13                0.202004              0.600512            -0.799616
# 14                0.979925             -0.980907            -0.194479
# 15               -0.625923              0.938622             0.344947
# 16                0.488621             -0.930189            -0.367081
# 17                0.740218             -0.843056             0.537825
# 18                0.831712              0.990172            -0.139852
# 19               -0.398749             -0.576636             0.817001
# 20                0.819152              0.990612            -0.136704
# 21                0.774393             -0.343777            -0.939051
# 22               -0.065403              0.999956             0.009350
# 23                0.480989              0.291776            -0.956487
# 24               -0.186453             -0.248559             0.968617
# 25               -0.793353              0.949894             0.312572
# 26                0.972927              0.033311             0.999445
# 27                0.258819             -0.258819            -0.965926
# 28               -0.629320             -0.995276             0.097087
# 29               -0.806445              0.834916            -0.550377
# ...                    ...                   ...                  ...
# 824728            0.317305             -0.267238            -0.963630
# 824729            0.979925              0.968148            -0.250380
# 824730            0.005890              0.622832            -0.782356
# 824731           -0.982828              0.765028            -0.643996
# 824732           -0.152123             -0.891289            -0.453435
# 824733           -0.744748              0.337653             0.941271
# 824734            0.688566              0.535160            -0.844751
# 824735            0.881132             -0.956871            -0.290513
# 824736            0.917060             -0.960224            -0.279231
# 824737            0.790110              0.991544            -0.129774
# 824738           -0.540363             -0.862629            -0.505837
# 824739            0.509229             -0.865261             0.501322
# 824740            0.881784             -0.956928            -0.290324
# 824741            0.685183             -0.326157            -0.945315
# 824742           -0.931109              0.481298             0.876557
# 824743           -0.563526             -0.860615            -0.509256
# 824744           -0.056693              0.999967             0.008103
# 824745            0.961342             -0.806051             0.591846
# 824746           -0.479139             -0.566141             0.824309
# 824747            0.544639              0.557124            -0.830429
# 824748           -0.665882              0.941176             0.337917
# 824749            0.492424             -0.866648             0.498920
# 824750            0.933685             -0.052294             0.998632
# 824751           -0.998848             -0.006857            -0.999976
# 824752           -0.026831              0.218782            -0.975774
# 824753           -0.993572             -0.419226             0.907882
# 824754            0.461749             -0.869125             0.494592
# 824755           -0.923880              0.815561            -0.578671
# 824756           -0.547137             -0.556770             0.830666
# 824757           -0.997859              0.009350            -0.999956
#
#               0.0      0.0.1      0.0.2      0.0.3  1
# 0      -73.985190  40.753716 -73.971924  40.797180  1
# 1      -73.979200  40.754494 -74.001030  40.733480  1
# 2      -73.998920  40.728207 -73.988770  40.727486  1
# 3      -73.977800  40.741978 -73.973010  40.747612  3
# 4      -73.979294  40.766502 -73.984880  40.742950  3
# 5      -73.985245  40.728360 -73.992424  40.724860  2
# 6      -73.979020  40.772152 -73.955680  40.782340  1
# 7      -74.007614  40.708683 -73.991410  40.727287  1
# 8      -74.009190  40.706970 -73.987390  40.722652  2
# 9      -73.982010  40.728233 -73.987390  40.738976  1
# 10     -74.008680  40.719097 -73.978450  40.745758  2
# 11     -73.969720  40.766370 -73.963760  40.774124  2
# 12     -73.960785  40.776670 -73.987760  40.779550  3
# 13     -73.966350  40.804356 -73.956276  40.805588  1
# 14     -73.959710  40.766895 -73.962970  40.760860  5
# 15     -73.986404  40.766895 -73.873030  40.774384  1
# 16     -73.973404  40.752632 -73.974200  40.747143  5
# 17     -73.966310  40.767944 -73.971080  40.761360  1
# 18     -73.966156  40.758350 -73.980354  40.742650  1
# 19     -73.975075  40.743570 -73.789380  40.642197  1
# 20     -74.002490  40.728333 -73.992100  40.714935  2
# 21     -73.981270  40.761707 -73.949930  40.776222  2
# 22     -73.962800  40.772453 -73.958550  40.779860  1
# 23     -73.974920  40.755894 -73.918830  40.638240  1
# 24     -73.961270  40.771553 -73.970900  40.758324  1
# 25     -73.981766  40.743940 -73.989815  40.756350  1
# 26     -73.952000  40.725887 -73.930970  40.701870  1
# 27     -73.966130  40.794880 -73.950780  40.779390  2
# 28     -73.998410  40.682056 -74.002320  40.729412  1
# 29     -73.946144  40.777440 -73.956764  40.780050  5
# ...           ...        ...        ...        ... ..
# 824728 -73.984260  40.770557 -73.986120  40.730705  3
# 824729 -73.999240  40.727783 -74.016210  40.714733  2
# 824730 -73.999310  40.722470 -73.981766  40.736782  2
# 824731 -73.973470  40.763107 -73.998570  40.723057  1
# 824732 -73.956184  40.776430 -74.008095  40.739094  1
# 824733 -73.986810  40.739273 -74.010345  40.720280  1
# 824734 -73.991490  40.750168 -73.945150  40.778650  2
# 824735 -73.979430  40.766308 -73.999040  40.760840  1
# 824736 -74.007590  40.707355 -74.010540  40.709830  1
# 824737 -73.991990  40.726265 -73.960010  40.712510  1
# 824738 -73.981950  40.778980 -73.976295  40.776337  1
# 824739 -73.983260  40.730618 -73.974266  40.742847  1
# 824740 -73.918686  40.743355 -73.979860  40.775272  1
# 824741 -73.985740  40.756256 -73.980890  40.742000  3
# 824742 -73.961460  40.771480 -73.969750  40.760210  1
# 824743 -73.949080  40.781544 -73.961586  40.779820  1
# 824744 -73.948380  40.778328 -73.961050  40.779340  2
# 824745 -73.970000  40.756454 -73.962740  40.774090  4
# 824746 -73.967630  40.787697 -73.980286  40.752270  1
# 824747 -73.981980  40.769950 -73.973370  40.795240  1
# 824748 -74.004310  40.707546 -73.997110  40.721863  1
# 824749 -73.983570  40.770900 -73.977745  40.745520  1
# 824750 -74.002730  40.749706 -73.989525  40.763847  2
# 824751 -73.989830  40.747227 -73.969290  40.764435  1
# 824752 -74.014780  40.709350 -73.929410  40.754124  1
# 824753 -73.984350  40.756588 -74.003410  40.743443  6
# 824754 -73.978294  40.762630 -73.988960  40.754612  6
# 824755 -73.971200  40.758343 -73.991160  40.744335  1
# 824756 -73.995926  40.753025 -74.002860  40.755287  1
# 824757 -73.990200  40.766994 -73.983215  40.767876  5
#
# [824758 rows x 17 columns]

# %%
df_2015 = pd.read_csv(s3_path_2015, header=0, skiprows=lambda i: i>0 and random.random() > 0.1)

#n = 10  # every 100th line = 1% of the lines
#df_2015 = pd.read_csv(s3_path_2015, header=0, skiprows=lambda i: i % n != 0)

df_2015
df_2015.to_csv('validate_small_2015.csv', header=False, index=False)
df_2015_final = pd.read_csv('./validate_small_2015.csv')
df_2015_final
# Out:
#           8.5  28  6  2015  3  28.1  16  40  -0.7650619086947137  \
# 0        9.50  23  2  2015  6    23  10  57            -0.698259
# 1        6.00  20  5  2015  3    20  16  45            -0.751504
# 2        9.50   9  6  2015  5     9  11  23            -0.776001
# 3       41.04   9  2  2015  6     9  18  11            -0.455933
# 4        9.50  18  7  2015  1    18   5   5             0.479777
# 5        9.50  11  6  2015  4    11   7  23             0.157799
# 6       25.50  13  6  2015  6    13   8  39            -0.170783
# 7        7.50  17  2  2015  3    17  21  54             0.478628
# 8       44.54   8  5  2015  5     8   7  21             0.168848
# 9       57.54   9  4  2015  4     9   4  16             0.827203
# 10      10.50  26  4  2015  2    26  11  56            -0.961701
# 11       8.00   6  5  2015  3     6  15  52            -0.730262
# 12      57.54  31  2  2015  3    31   9   1            -0.265065
# 13       4.00  12  5  2015  6    12  15  57            -0.871321
# 14       2.50  21  6  2015  2    21  15  49            -0.738995
# 15       7.00   4  7  2015  1     4  16  13            -0.664687
# 16       9.00  20  1  2015  4    20  11  16            -0.756757
# 17       5.00   7  7  2015  6     7   9  32            -0.394142
# 18       6.50  17  3  2015  6    17   9  55            -0.482964
# 19      22.00  26  7  2015  4    26  21  53             0.475112
# 20      14.50  30  2  2015  6    30   8  39            -0.172717
# 21       7.00  27  1  2015  4    27  15   3            -0.962119
# 22       7.00  16  5  2015  1    16  17  54            -0.281783
# 23      27.50  18  1  2015  5    18   8   3            -0.016798
# 24       9.50  28  6  2015  2    28  14  13            -0.949357
# 25      11.00   5  4  2015  3     5  15  23            -0.810510
# 26      34.50  13  6  2015  6    13  20  27             0.121003
# 27      22.00   8  4  2015  1     8   7  43            -0.189381
# 28      23.00  29  1  2015  6    29   2  44             0.980913
# 29       8.50  28  6  2015  3    28  17  30            -0.606451
# ...       ...  .. ..   ... ..   ...  ..  ..                  ...
# 384781   9.00  13  5  2015  3    13   4  43             0.755186
# 384782  11.00  24  2  2015  3    24   9   2            -0.268850
# 384783   8.50  10  6  2015  1    10  22   0             0.708750
# 384784   7.50  24  2  2015  2    24  14  14            -0.947047
# 384785   6.50  20  1  2015  4    20  14  31            -0.990689
# 384786  57.54  11  1  2015  5    11   1  15             0.980856
# 384787   6.50   8  4  2015  1     8  12  33            -0.993473
# 384788   7.50  24  3  2015  6    24  10  34            -0.625299
# 384789   9.50   5  4  2015  3     5  14  23            -0.933997
# 384790   7.00  27  3  2015  5    27  16  27            -0.800601
# 384791   6.00  15  4  2015  1    15  18  13            -0.202431
# 384792   6.50  27  3  2015  5    27  12  22            -0.911104
# 384793  14.50  25  4  2015  6    25   2  35             0.987949
# 384794   6.00   7  6  2015  3     7   6  21             0.165908
# 384795   8.00  10  3  2015  6    10   2  51             0.974647
# 384796   4.50   9  1  2015  2     9   3   1             0.863285
# 384797   5.50  16  1  2015  2    16  17  16            -0.435100
# 384798   7.50   9  1  2015  2     9  13  46            -0.979910
# 384799   5.50  14  2  2015  4    14  18  37            -0.351229
# 384800   5.50  23  4  2015  4    23   2  47             0.978329
# 384801  57.33   2  1  2015  3     2  16   7            -0.682743
# 384802   8.50  11  1  2015  5    11  18  49            -0.304102
# 384803   9.00   6  5  2015  2     6   6  41             0.080199
# 384804   9.50  21  3  2015  1    21   8  14            -0.317925
# 384805   9.00  17  3  2015  6    17   3  15             0.946649
# 384806   6.00   2  1  2015  2     2   7  57            -0.248690
# 384807  17.50  10  7  2015  5    10   2  56             0.969374
# 384808   5.50   4  4  2015  6     4  17  21            -0.639048
# 384809  17.00  22  3  2015  4    22   4  58             0.713098
# 384810   4.00  12  4  2015  3    12   3  58             0.869746
#
#         0.6439567344662229  0.5423629857294058  -0.8401442683912593  \
# 0                -0.715845           -0.944469             0.328602
# 1                 0.659728            0.994708            -0.102741
# 2                -0.630732            0.696636            -0.717425
# 3                 0.890014           -0.822180             0.569228
# 4                -0.877391            0.071425            -0.997446
# 5                -0.987471            0.795744            -0.605633
# 6                -0.985309            0.766311            -0.642469
# 7                 0.878018           -0.735429             0.677602
# 8                -0.985642            0.969249             0.246083
# 9                -0.561903            0.304716             0.952443
# 10               -0.274099            0.591996             0.805941
# 11                0.683168            0.994234            -0.107235
# 12               -0.964230           -0.965686             0.259712
# 13                0.490714            0.997317            -0.073207
# 14                0.673711            0.537606            -0.843196
# 15                0.747122           -0.338132            -0.941099
# 16               -0.653696           -0.852222            -0.523180
# 17               -0.919049           -0.057844            -0.998326
# 18               -0.875640           -0.367941             0.929849
# 19                0.879925           -0.496469            -0.868054
# 20               -0.984971           -0.969111             0.246627
# 21                0.272630           -0.917379            -0.398015
# 22                0.959478            0.983194            -0.182562
# 23               -0.999859           -0.783325            -0.621612
# 24                0.314200            0.587155            -0.809475
# 25                0.585724            0.690800             0.723046
# 26                0.992652            0.418207            -0.908352
# 27               -0.981904            0.458243             0.888827
# 28               -0.194448           -0.645101            -0.764098
# 29                0.795121            0.515750            -0.856739
# ...                    ...                 ...                  ...
# 384781           -0.655510            0.940507             0.339774
# 384782           -0.963182           -0.965540             0.260254
# 384783            0.705459            0.329965            -0.943993
# 384784            0.321095           -0.879733             0.475469
# 384785            0.136148           -0.909262            -0.416224
# 384786            0.194734           -0.601359            -0.798979
# 384787           -0.114070            0.610639             0.791909
# 384788           -0.780385           -0.345054             0.938583
# 384789            0.357281            0.663429             0.748239
# 384790            0.599198           -0.132225             0.991220
# 384791            0.979296            0.763347             0.645989
# 384792           -0.412177           -0.281245             0.959636
# 384793           -0.154782            0.244109             0.969748
# 384794           -0.986141            0.796455            -0.604698
# 384795           -0.223746           -0.597967             0.801521
# 384796           -0.504716           -0.680744            -0.732522
# 384797            0.900382           -0.958613            -0.284713
# 384798            0.199439           -0.913042            -0.407866
# 384799            0.936290           -0.812756             0.582604
# 384800           -0.207058            0.251466             0.967866
# 384801            0.730659           -0.945471            -0.325706
# 384802            0.952639           -0.964159            -0.265326
# 384803           -0.996779            0.972312             0.233688
# 384804           -0.948116           -0.391792             0.920054
# 384805           -0.322266           -0.586170             0.810188
# 384806           -0.968583           -0.803709            -0.595023
# 384807           -0.245589            0.187830            -0.982201
# 384808            0.769167            0.716353             0.697738
# 384809           -0.701065           -0.533061             0.846077
# 384810           -0.493499            0.293732             0.955888
#
#         -73.99243  40.728603  -73.997314   40.73768  1
# 0      -73.996010  40.726320  -74.013460  40.715440  1
# 1      -73.946160  40.792460  -73.935490  40.799313  5
# 2      -73.989060  40.776997  -73.988680  40.758743  2
# 3      -73.988330  40.755276  -73.980150  40.614887  1
# 4      -73.976260  40.740010  -73.984860  40.715370  2
# 5      -73.963455  40.758556  -73.986565  40.766773  1
# 6      -74.003590  40.707882  -73.885730  40.744300  1
# 7      -74.004240  40.710094  -73.999800  40.716103  1
# 8      -73.872940  40.774094  -73.974884  40.758920  1
# 9      -73.968760  40.756570  -73.789560  40.647060  5
# 10     -73.969270  40.689526  -73.965580  40.710587  2
# 11     -73.989920  40.729420  -73.976340  40.739970  1
# 12     -74.015530  40.706790  -73.789640  40.642770  1
# 13     -73.952940  40.776860  -73.958740  40.769870  2
# 14     -73.987490  40.755024  -73.987490  40.755028  1
# 15     -74.004660  40.741844  -73.990350  40.746550  1
# 16     -73.968820  40.791058  -73.973140  40.795390  3
# 17     -73.995870  40.744190  -74.006840  40.742560  1
# 18     -73.991920  40.764614  -73.979940  40.781060  1
# 19     -73.981250  40.729244  -73.907040  40.683243  1
# 20     -73.955310  40.773260  -73.983800  40.749700  1
# 21     -73.974690  40.790203  -73.982350  40.776290  2
# 22     -73.991710  40.764870  -73.983770  40.760110  1
# 23     -73.994120  40.738174  -73.964080  40.802680  1
# 24     -73.991060  40.729630  -74.008660  40.716150  2
# 25     -73.976616  40.683020  -73.984390  40.665670  1
# 26     -73.983580  40.765636  -73.855630  40.830574  1
# 27     -73.988945  40.753000  -74.015570  40.711437  1
# 28     -73.951240  40.778774  -74.014280  40.709232  1
# 29     -73.988090  40.732000  -74.003880  40.737420  1
# ...           ...        ...         ...        ... ..
# 384781 -73.981920  40.757385  -73.960710  40.758423  1
# 384782 -73.968500  40.758835  -73.982040  40.769444  1
# 384783 -73.991684  40.732044  -73.991684  40.732044  5
# 384784 -73.985600  40.757374  -73.998650  40.739933  1
# 384785 -73.971310  40.675520  -73.985930  40.669025  1
# 384786 -73.953094  40.785736  -73.778770  40.645092  1
# 384787 -73.954720  40.780888  -73.957090  40.769890  2
# 384788 -74.005670  40.750816  -73.991540  40.742450  1
# 384789 -73.989975  40.734550  -73.976585  40.751686  2
# 384790 -73.963670  40.771393  -73.951200  40.770786  1
# 384791 -73.973885  40.762684  -73.973610  40.755280  1
# 384792 -73.967230  40.769257  -73.963360  40.764782  2
# 384793 -73.965990  40.768238  -73.990944  40.723460  6
# 384794 -73.970860  40.751640  -73.980710  40.742220  1
# 384795 -74.000200  40.736988  -73.982850  40.760185  1
# 384796 -74.004715  40.746826  -74.003880  40.738810  6
# 384797 -73.982220  40.731750  -73.973080  40.744390  1
# 384798 -73.970080  40.755474  -73.953100  40.768444  2
# 384799 -73.972374  40.762093  -73.970085  40.762722  1
# 384800 -73.948240  40.774510  -73.961426  40.774574  1
# 384801 -73.789280  40.647160  -73.979750  40.761720  2
# 384802 -73.950500  40.777470  -73.977880  40.783830  2
# 384803 -73.999670  40.738700  -73.983246  40.734740  1
# 384804 -73.970740  40.758366  -73.978950  40.766570  2
# 384805 -73.978740  40.736480  -73.975750  40.755600  6
# 384806 -73.989494  40.735664  -74.001670  40.735264  1
# 384807 -73.952110  40.824400  -73.976590  40.763270  1
# 384808 -73.995680  40.739918  -73.988860  40.746030  1
# 384809 -73.951996  40.769238  -73.981440  40.763615  1
# 384810 -73.957436  40.779920  -73.954110  40.784310  1
#
# [384811 rows x 17 columns]

# %%
# !aws s3 cp train_small_2014.csv s3://aws-worskhop-data/taxinyc-query-results/train2/train_small_2014.csv
# Out:
# upload: ./train_small_2014.csv to s3://aws-worskhop-data/taxinyc-query-results/train2/train_small_2014.csv

# %%
# !aws s3 cp validate_small_2015.csv s3://aws-worskhop-data/taxinyc-query-results/validate2/validate_small_2015.csv
# Out:
# upload: ./validate_small_2015.csv to s3://aws-worskhop-data/taxinyc-query-results/validate2/validate_small_2015.csv

# %%
path_train = os.path.join('taxinyc-query-results','train2')
path_val = os.path.join('taxinyc-query-results','validate2')
bucket = 'aws-worskhop-data'

# %%
container = get_image_uri(boto3.Session().region_name, 'xgboost', repo_version="0.90-2")

# %%
's3://{}/{}'.format(bucket, path_train)
# Out:
# 's3://aws-worskhop-data/taxinyc-query-results/train2'

# %%
s3_input_trains3_inpu  = sagemaker.s3_input(s3_data='s3://{}/{}'.format(bucket, path_train),
                                            content_type='csv',
                                            distribution='ShardedByS3Key')
s3_input_validation = sagemaker.s3_input(s3_data='s3://{}/{}'.format(bucket, path_val),
                                         content_type='csv', 
                                         distribution='ShardedByS3Key')

# %%
sess = sagemaker.Session()
role = get_execution_role()

# %%
training_job_path = os.path.join('training_jobs', datetime.now().strftime('%Y-%m-%d-%H-%M-%S'))

# %%
's3://{}/{}/output'.format(bucket,training_job_path)
# Out:
# 's3://aws-worskhop-data/training_jobs/2020-06-07-05-09-11/output'

# %% [markdown]
# ## Train and explain the model

# %%
from smdebug.trials import create_trial
from sagemaker.debugger import rule_configs, Rule, DebuggerHookConfig, CollectionConfig

# %%
hyperparameters = {
    "max_depth": "9",
    "eta": "0.2",
    "gamma": "4",
    "min_child_weight": "300",
    "subsample": "0.8",
    "silent": "0",
    "objective": "reg:linear",
    "early_stopping_rounds": "10",
    "num_round": "10000"
}

save_interval = 5

# %%
xgboost_estimator = sagemaker.estimator.Estimator(
    role=role,
    train_instance_count=1,
    train_instance_type='ml.m5.4xlarge',
    output_path='s3://{}/{}/output'.format(bucket,training_job_path),
    image_name=container,
    hyperparameters=hyperparameters,
    train_max_run=1800,

    debugger_hook_config=DebuggerHookConfig(
        s3_output_path='s3://{}/{}/output'.format(bucket,training_job_path),  # Required
        collection_configs=[
            CollectionConfig(
                name="metrics",
                parameters={
                    "save_interval": str(save_interval)
                }
            ),
            CollectionConfig(
                name="feature_importance",
                parameters={
                    "save_interval": str(save_interval)
                }
            ),
            CollectionConfig(
                name="full_shap",
                parameters={
                    "save_interval": str(save_interval)
                }
            ),
            CollectionConfig(
                name="average_shap",
                parameters={
                    "save_interval": str(save_interval)
                }
            ),
        ],
    ),

    rules=[
        Rule.sagemaker(
            rule_configs.loss_not_decreasing(),
            rule_parameters={
                "collection_names": "metrics",
                "num_steps": str(save_interval * 2),
            },
        ),
    ],
)

# %%
xgboost_estimator.fit({'train': s3_input_trains3_inpu, 'validation': s3_input_validation})
# Out:
# 2020-06-07 05:09:11 Starting - Starting the training job...
# 2020-06-07 05:09:34 Starting - Launching requested ML instances
# ********* Debugger Rule Status *********
# *
# *  LossNotDecreasing: InProgress
# *
# ****************************************
# ......
# 2020-06-07 05:10:35 Starting - Preparing the instances for training...
# 2020-06-07 05:11:04 Downloading - Downloading input data...
# 2020-06-07 05:11:37 Training - Training image download completed. Training in progress...INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value reg:linear to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# [05:11:39] 824759x16 matrix with 13196144 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# INFO:root:Determined delimiter of CSV input is ','
# [05:11:39] 384812x16 matrix with 6156992 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# INFO:root:Single node training.
# [2020-06-07 05:11:39.585 ip-10-0-221-175.eu-west-1.compute.internal:1 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020-06-07 05:11:39.585 ip-10-0-221-175.eu-west-1.compute.internal:1 INFO hook.py:151] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2020-06-07 05:11:39.585 ip-10-0-221-175.eu-west-1.compute.internal:1 INFO hook.py:196] Saving to /opt/ml/output/tensors
# INFO:root:Debug hook created from config
# INFO:root:Train matrix has 824759 rows
# INFO:root:Validation matrix has 384812 rows
# [05:11:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]#011train-rmse:13.87#011validation-rmse:14.2576
# [2020-06-07 05:11:40.328 ip-10-0-221-175.eu-west-1.compute.internal:1 INFO hook.py:325] Monitoring the collections: average_shap, losses, full_shap, metrics, feature_importance
# [1]#011train-rmse:11.6776#011validation-rmse:12.0782
# [2]#011train-rmse:10.0073#011validation-rmse:10.4201
# [3]#011train-rmse:8.75538#011validation-rmse:9.18199
# [4]#011train-rmse:7.83439#011validation-rmse:8.27491
# [5]#011train-rmse:7.14119#011validation-rmse:7.58963
# [6]#011train-rmse:6.65017#011validation-rmse:7.10669
# [7]#011train-rmse:6.25296#011validation-rmse:6.7109
# [8]#011train-rmse:5.99945#011validation-rmse:6.45357
# [9]#011train-rmse:5.81678#011validation-rmse:6.26761
# [10]#011train-rmse:5.6765#011validation-rmse:6.12125
# [11]#011train-rmse:5.58502#011validation-rmse:6.02333
# [12]#011train-rmse:5.48409#011validation-rmse:5.91667
# [13]#011train-rmse:5.38627#011validation-rmse:5.8156
# [14]#011train-rmse:5.33512#011validation-rmse:5.76101
# [15]#011train-rmse:5.29491#011validation-rmse:5.71852
# [16]#011train-rmse:5.26881#011validation-rmse:5.69077
# [17]#011train-rmse:5.23313#011validation-rmse:5.6497
# [18]#011train-rmse:5.19435#011validation-rmse:5.60984
# [19]#011train-rmse:5.15317#011validation-rmse:5.56143
# [20]#011train-rmse:5.12574#011validation-rmse:5.53571
# [21]#011train-rmse:5.11568#011validation-rmse:5.52541
# [22]#011train-rmse:5.09248#011validation-rmse:5.50441
# [23]#011train-rmse:5.06458#011validation-rmse:5.47802
# [24]#011train-rmse:5.05037#011validation-rmse:5.46703
# [25]#011train-rmse:5.03295#011validation-rmse:5.44988
# [26]#011train-rmse:4.9955#011validation-rmse:5.41329
# [27]#011train-rmse:4.98423#011validation-rmse:5.40337
# [28]#011train-rmse:4.97861#011validation-rmse:5.39786
# [29]#011train-rmse:4.97477#011validation-rmse:5.39338
# [30]#011train-rmse:4.96497#011validation-rmse:5.38657
# [31]#011train-rmse:4.92347#011validation-rmse:5.34885
# [32]#011train-rmse:4.91909#011validation-rmse:5.34601
# [33]#011train-rmse:4.91523#011validation-rmse:5.3444
# [34]#011train-rmse:4.89832#011validation-rmse:5.32838
# [35]#011train-rmse:4.88855#011validation-rmse:5.31852
# [36]#011train-rmse:4.88291#011validation-rmse:5.31263
# [37]#011train-rmse:4.8797#011validation-rmse:5.30916
# [38]#011train-rmse:4.87679#011validation-rmse:5.3059
# [39]#011train-rmse:4.87435#011validation-rmse:5.30444
# [40]#011train-rmse:4.86577#011validation-rmse:5.29608
# [41]#011train-rmse:4.86158#011validation-rmse:5.29149
# [42]#011train-rmse:4.85856#011validation-rmse:5.28842
# [43]#011train-rmse:4.85562#011validation-rmse:5.28612
# [44]#011train-rmse:4.85234#011validation-rmse:5.28421
# [45]#011train-rmse:4.84783#011validation-rmse:5.28043
# [46]#011train-rmse:4.8415#011validation-rmse:5.27409
# [47]#011train-rmse:4.83975#011validation-rmse:5.27272
# [48]#011train-rmse:4.83792#011validation-rmse:5.27318
# [49]#011train-rmse:4.83595#011validation-rmse:5.27224
# [50]#011train-rmse:4.83364#011validation-rmse:5.27037
# [51]#011train-rmse:4.83051#011validation-rmse:5.26872
# [52]#011train-rmse:4.82679#011validation-rmse:5.26447
# [53]#011train-rmse:4.81774#011validation-rmse:5.25578
# [54]#011train-rmse:4.81433#011validation-rmse:5.25364
# [55]#011train-rmse:4.80705#011validation-rmse:5.24772
# [56]#011train-rmse:4.80584#011validation-rmse:5.24722
# [57]#011train-rmse:4.80309#011validation-rmse:5.24471
# [58]#011train-rmse:4.80021#011validation-rmse:5.24234
# [59]#011train-rmse:4.79844#011validation-rmse:5.24062
# [60]#011train-rmse:4.79727#011validation-rmse:5.23926
# [61]#011train-rmse:4.79513#011validation-rmse:5.23745
# [62]#011train-rmse:4.79427#011validation-rmse:5.23702
# [63]#011train-rmse:4.79091#011validation-rmse:5.23488
# [64]#011train-rmse:4.78966#011validation-rmse:5.23441
# [65]#011train-rmse:4.78723#011validation-rmse:5.2328
# [66]#011train-rmse:4.78439#011validation-rmse:5.22945
# [67]#011train-rmse:4.78184#011validation-rmse:5.22954
# [68]#011train-rmse:4.78072#011validation-rmse:5.22941
# [69]#011train-rmse:4.77651#011validation-rmse:5.22608
# [70]#011train-rmse:4.77456#011validation-rmse:5.22367
# [71]#011train-rmse:4.77332#011validation-rmse:5.22216
# [72]#011train-rmse:4.77127#011validation-rmse:5.22027
# [73]#011train-rmse:4.77088#011validation-rmse:5.21996
# [74]#011train-rmse:4.76865#011validation-rmse:5.21863
# [75]#011train-rmse:4.76781#011validation-rmse:5.21844
# [76]#011train-rmse:4.7663#011validation-rmse:5.21855
# [77]#011train-rmse:4.76506#011validation-rmse:5.21826
# [78]#011train-rmse:4.76429#011validation-rmse:5.21742
# [79]#011train-rmse:4.76166#011validation-rmse:5.21706
# [80]#011train-rmse:4.76052#011validation-rmse:5.21682
# [81]#011train-rmse:4.75859#011validation-rmse:5.21543
# [82]#011train-rmse:4.75782#011validation-rmse:5.2151
# [83]#011train-rmse:4.75117#011validation-rmse:5.2093
# [84]#011train-rmse:4.75039#011validation-rmse:5.20931
# [85]#011train-rmse:4.75001#011validation-rmse:5.20928
# [86]#011train-rmse:4.74959#011validation-rmse:5.20932
# [87]#011train-rmse:4.74888#011validation-rmse:5.20888
# [88]#011train-rmse:4.74826#011validation-rmse:5.2085
# [89]#011train-rmse:4.74683#011validation-rmse:5.20829
# [90]#011train-rmse:4.74658#011validation-rmse:5.20817
# [91]#011train-rmse:4.74457#011validation-rmse:5.20602
# [92]#011train-rmse:4.74294#011validation-rmse:5.20474
# [93]#011train-rmse:4.74236#011validation-rmse:5.20475
# [94]#011train-rmse:4.7385#011validation-rmse:5.20095
# [95]#011train-rmse:4.73763#011validation-rmse:5.20036
# [96]#011train-rmse:4.73667#011validation-rmse:5.19907
# [97]#011train-rmse:4.73512#011validation-rmse:5.19968
# [98]#011train-rmse:4.73191#011validation-rmse:5.19628
# [99]#011train-rmse:4.73097#011validation-rmse:5.19571
# [100]#011train-rmse:4.72999#011validation-rmse:5.19618
# [101]#011train-rmse:4.72938#011validation-rmse:5.19607
# [102]#011train-rmse:4.72795#011validation-rmse:5.19509
# [103]#011train-rmse:4.7247#011validation-rmse:5.1925
# [104]#011train-rmse:4.72296#011validation-rmse:5.191
# [105]#011train-rmse:4.72112#011validation-rmse:5.18995
#
# 2020-06-07 05:46:34 Stopping - Stopping the training job
# ********* Debugger Rule Status *********
# *
# *  LossNotDecreasing: Stopped
# *
# ****************************************
# [106]#011train-rmse:4.72039#011validation-rmse:5.18973
# [107]#011train-rmse:4.71852#011validation-rmse:5.18916
# [108]#011train-rmse:4.71783#011validation-rmse:5.18892
# [109]#011train-rmse:4.7168#011validation-rmse:5.18872
# [110]#011train-rmse:4.71573#011validation-rmse:5.18792
#
# 2020-06-07 05:48:32 Uploading - Uploading generated training model
# 2020-06-07 05:48:32 MaxRuntimeExceeded - Training job runtime exceeded MaxRuntimeInSeconds provided
# Training seconds: 2248
# Billable seconds: 2248

# %%
xgboost_estimator.latest_training_job.rule_job_summary()
# Out:
# [{'RuleConfigurationName': 'LossNotDecreasing',
#   'RuleEvaluationJobArn': 'arn:aws:sagemaker:eu-west-1:282784146513:processing-job/sagemaker-xgboost-2020-06--lossnotdecreasing-e12aa3d1',
#   'RuleEvaluationStatus': 'Stopped',
#   'LastModifiedTime': datetime.datetime(2020, 6, 7, 5, 47, 35, 95000, tzinfo=tzlocal())}]

# %%
s3_output_path = xgboost_estimator.latest_job_debugger_artifacts_path()
trial = create_trial(s3_output_path)
# Out:
# [2020-06-07 05:48:46.906 ip-172-16-77-40:28219 INFO s3_trial.py:42] Loading trial debug-output at path s3://aws-worskhop-data/training_jobs/2020-06-07-05-09-11/output/sagemaker-xgboost-2020-06-07-05-09-11-735/debug-output

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import re


def get_data(trial, tname):
    """
    For the given tensor name, walks though all the iterations
    for which you have data and fetches the values.
    Returns the set of steps and the values.
    """
    tensor = trial.tensor(tname)
    steps = tensor.steps()
    vals = [tensor.value(s) for s in steps]
    return steps, vals

def plot_collection(trial, collection_name, regex='.*', figsize=(8, 6)):
    """
    Takes a `trial` and a collection name, and 
    plots all tensors that match the given regex.
    """
    fig, ax = plt.subplots(figsize=figsize)
    sns.despine()

    tensors = trial.collection(collection_name).tensor_names

    for tensor_name in sorted(tensors):
        if re.match(regex, tensor_name):
            steps, data = get_data(trial, tensor_name)
            ax.plot(steps, data, label=tensor_name)

    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    ax.set_xlabel('Iteration')

# %%
plot_collection(trial, "metrics")
# Out:
# [2020-06-07 05:48:48.155 ip-172-16-77-40:28219 INFO trial.py:198] Training has ended, will refresh one final time in 1 sec.
# [2020-06-07 05:48:49.173 ip-172-16-77-40:28219 INFO trial.py:210] Loaded all steps

# %%
def plot_feature_importance(trial, importance_type="weight"):
    SUPPORTED_IMPORTANCE_TYPES = ["weight", "gain", "cover", "total_gain", "total_cover"]
    if importance_type not in SUPPORTED_IMPORTANCE_TYPES:
        raise ValueError(f"{importance_type} is not one of the supported importance types.")
    plot_collection(
        trial,
        "feature_importance",
        regex=f"feature_importance/{importance_type}/.*")

# %%
plot_feature_importance(trial)

# %%
plot_feature_importance(trial, importance_type="cover")

# %%
plot_collection(trial,"average_shap")

# %%
feature_names = list(df_small.columns[1:])

# %%
shap_values = trial.tensor("full_shap/f0").value(trial.last_complete_step)
shap_no_base = shap_values[:, :-1]
shap_base_value = shap_values[0, -1]
shap.summary_plot(shap_no_base, plot_type='bar', feature_names=feature_names)

# %% [markdown]
# # Building Taxi Fare Prediction using SageMaker

# %% [markdown]
# <p>This demo notebook guides through the steps in creating an AWS Sagemaker predictions service</p>
# <p>To start using Sagemaker go here: <a href="https://aws.amazon.com/sagemaker/">Sagemaker</a></p>

# %%
# !pip install shap
# !pip install smdebug
# Out:
# Requirement already satisfied: shap in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (0.35.0)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from shap) (1.4.1)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from shap) (0.24.2)
# Requirement already satisfied: tqdm>4.25.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from shap) (4.46.1)
# Requirement already satisfied: scikit-learn in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from shap) (0.22.1)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from shap) (1.16.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from pandas->shap) (2.7.3)
# Requirement already satisfied: pytz>=2011k in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from pandas->shap) (2018.4)
# Requirement already satisfied: joblib>=0.11 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from scikit-learn->shap) (0.14.1)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas->shap) (1.11.0)
# WARNING: You are using pip version 19.3.1; however, version 20.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: smdebug in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (0.8.1)
# Requirement already satisfied: protobuf>=3.6.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from smdebug) (3.8.0)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from smdebug) (1.16.4)
# Requirement already satisfied: boto3>=1.10.32 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from smdebug) (1.12.39)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from smdebug) (20.1)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from protobuf>=3.6.0->smdebug) (45.2.0)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from protobuf>=3.6.0->smdebug) (1.11.0)
# Requirement already satisfied: botocore<1.16.0,>=1.15.39 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from boto3>=1.10.32->smdebug) (1.15.39)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from boto3>=1.10.32->smdebug) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from boto3>=1.10.32->smdebug) (0.9.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from packaging->smdebug) (2.2.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from botocore<1.16.0,>=1.15.39->boto3>=1.10.32->smdebug) (2.7.3)
# Requirement already satisfied: urllib3<1.26,>=1.20; python_version != "3.4" in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from botocore<1.16.0,>=1.15.39->boto3>=1.10.32->smdebug) (1.23)
# Requirement already satisfied: docutils<0.16,>=0.10 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from botocore<1.16.0,>=1.15.39->boto3>=1.10.32->smdebug) (0.14)
# WARNING: You are using pip version 19.3.1; however, version 20.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import os
from s3fs.core import S3FileSystem
import random

import shap

import boto3
from botocore.client import Config
import json

# %%
from sagemaker import get_execution_role

role = get_execution_role()
print(role)
# Out:
# arn:aws:iam::282784146513:role/service-role/AmazonSageMaker-ExecutionRole-20190604T113688

# %%
def load_model(fname):
    model = xgb.XGBClassifier()
    model.load_model(fname)
    with open(fname.replace('.xgboost', '.json'), encoding='utf-8') as fin:
        params = json.load(fin)
    model.set_params(**params)
    return model

# %% [markdown]
# ## Read the whole data from S3

# %%
S3FileSystem.read_timeout = 3600

# %%
s3 = S3FileSystem(anon=False)
bucket = 'aws-worskhop-data/ZIPCHUNKS'
file_list = s3.ls(bucket)
subs = 'ZIPCHUNKS'
res = [i for i in file_list if subs in i]

# %%
# we remove the folder ZIPCHUNKS if it exists (so later we can merge the files in loop)
if 'aws-worskhop-data/ZIPCHUNKS' in res: res.remove('aws-worskhop-data/ZIPCHUNKS')

# %%
res
# Out:
# ['aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaa',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSab',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSac',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSad',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSae',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaf',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSag',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSah',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSai',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaj',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSak',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSal',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSam']

# %%
jj = 0

for filechunk in res:
        print (filechunk)
        if jj == 0:
            with s3.open('aws-worskhop-data/taxinyc_train.csv.zip', 'wb') as f:
                f.write(s3.cat(filechunk))
                jj = jj + 1        
                f.close()
        else:
            with s3.open('aws-worskhop-data/taxinyc_train.csv.zip', 'ab') as f:
                f.write(s3.cat(filechunk))
                jj = jj + 1
                f.close()
# Out:
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaa
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSab
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSac
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSad
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSae
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaf
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSag
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSah
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSai
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaj
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSak
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSal
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSam

# %%
bucket = 'aws-worskhop-data'
path = ''

filename = 'taxinyc_train.csv.zip'
s3_path = os.path.join('s3://', bucket, path, filename)

df_all = pd.read_csv(s3_path, header=0, skiprows=lambda i: i>0 and random.random() > 0.01)

# %%
df_all
# Out:
#         fare_amount  day  dayofweek  year  month  dayofmonth  hour  minute  \
# 0             27.00    1          6  2013      6           1    18      43
# 1             57.33    3          7  2013     11           3     1      51
# 2              8.00   18          1  2013      2          18    11      25
# 3              3.70   22          2  2009      9          22     2      33
# 4              4.50   11          6  2009      7          11    20      57
# 5             10.10   20          1  2009      7          20     1      36
# 6              5.00   22          4  2013      8          22    14      28
# 7             13.30    8          7  2012      1           8     0      16
# 8             19.50   21          4  2013      3          21     7      56
# 9              5.50   24          4  2013     10          24     2      10
# 10             7.50   18          7  2013      8          18    18      54
# 11             9.70   31          6  2010      7          31     6       3
# 12             5.50   15          1  2013      7          15     7      58
# 13            45.00   13          1  2010     12          13    19      18
# 14             4.90   16          4  2009      4          16     6      49
# 15            16.50   27          6  2014      9          27    19       6
# 16            10.50    8          3  2011      6           8     7      13
# 17            10.10   29          3  2009      4          29    14      15
# 18             4.50   23          6  2009      5          23     5      49
# 19             6.50   21          2  2015      4          21    15      19
# 20             8.00    7          4  2013      2           7     2      19
# 21            41.83   28          3  2015      1          28     8      41
# 22            12.50   11          5  2014      7          11     9      37
# 23            10.10   21          6  2009      3          21    12      37
# 24            10.50    5          3  2012     12           5     9      26
# 25            17.00   19          4  2013     12          19    13      48
# 26             6.00   30          6  2013     11          30     3      39
# 27             5.50   30          3  2013      1          30     9       7
# 28            20.50   29          2  2012      5          29    14       9
# 29            16.50    6          7  2014      4           6     5      10
# ...             ...  ...        ...   ...    ...         ...   ...     ...
# 554837         8.00   12          3  2014      3          12     9      50
# 554838        28.90   30          1  2011      5          30     1      40
# 554839        14.00   31          5  2014     10          31    14      37
# 554840         8.50   25          3  2012      1          25    17      44
# 554841         4.90   14          1  2012      5          14    15      21
# 554842         9.00    9          1  2015      2           9     5      24
# 554843         8.10   25          2  2010      5          25    16      42
# 554844         7.70   24          1  2011      1          24     3      29
# 554845        13.00    9          2  2013      7           9    17       0
# 554846         8.00    7          1  2013     10           7     0      39
# 554847        14.00   17          2  2015      2          17    10      26
# 554848        13.00   17          2  2013      9          17    15      42
# 554849         9.00   18          6  2014      1          18    16      19
# 554850        12.50    9          2  2015      6           9    17      45
# 554851        11.00   12          3  2014      3          12    16      28
# 554852         5.50   13          7  2014      4          13    17      33
# 554853         6.50   27          3  2010      1          27     2      14
# 554854         5.70   18          5  2009     12          18    16      56
# 554855         5.70   22          5  2011      7          22    21      28
# 554856         8.10   28          3  2011     12          28     5      26
# 554857        14.00   31          5  2013      5          31    14      29
# 554858         6.00   10          7  2015      5          10     9      27
# 554859        10.50    2          5  2010      7           2    21      23
# 554860         6.50   20          5  2011      5          20     2      28
# 554861        11.30    9          2  2009      6           9    17      45
# 554862         7.30   11          5  2009      9          11     2      43
# 554863         7.50   26          7  2015      4          26    20      14
# 554864         6.00   10          6  2013      8          10    16      25
# 554865         4.10    4          7  2010      7           4     7      47
# 554866         8.60   28          6  2009      3          28    20      16
#
#          sin_day   cos_day  sin_week  cos_week          pickup_datetime  \
# 0      -0.326806  0.945092  0.476227 -0.879322  2013-06-01 22:43:42 UTC
# 1       0.975149 -0.221548  0.191298 -0.981532  2013-11-03 06:51:12 UTC
# 2      -0.916363 -0.400349 -0.873893 -0.486118  2013-02-18 16:25:36 UTC
# 3       0.989651 -0.143493 -0.999788  0.020569  2009-09-22 06:33:00 UTC
# 4       0.246717  0.969088  0.401529 -0.915846  2009-07-12 00:57:08 UTC
# 5       0.994522  0.104528 -0.611724 -0.791071  2009-07-20 05:36:00 UTC
# 6      -0.992546  0.121869  0.637040  0.770831  2013-08-22 18:28:00 UTC
# 7       0.982233  0.187667  0.248730 -0.968573  2012-01-08 05:16:44 UTC
# 8       0.017452 -0.999848  0.431636  0.902048  2013-03-21 11:56:00 UTC
# 9       0.998967 -0.045436  0.228846  0.973463  2013-10-24 06:10:25 UTC
# 10     -0.284015  0.958820 -0.396461 -0.918051  2013-08-18 22:54:00 UTC
# 11      0.488621 -0.872496  0.825184 -0.564864  2010-07-31 10:03:00 UTC
# 12      0.008727 -0.999962 -0.781054 -0.624464  2013-07-15 11:58:00 UTC
# 13      0.078459  0.996917 -0.977363 -0.211568  2010-12-14 00:18:00 UTC
# 14      0.304864 -0.952396  0.393598  0.919283  2009-04-16 10:49:00 UTC
# 15     -0.233445  0.972370  0.463959 -0.885857  2014-09-27 23:06:00 UTC
# 16      0.201078 -0.979575 -0.459757  0.888045  2011-06-08 11:13:36 UTC
# 17     -0.997669  0.068233 -0.213000  0.977052  2009-04-29 18:15:39 UTC
# 18      0.540974 -0.841039  0.830082 -0.557642  2009-05-23 09:49:00 UTC
# 19     -0.940016  0.341132 -0.878286  0.478135  2015-04-21 19:19:47 UTC
# 20      0.940313 -0.340311  0.270590  0.962695  2013-02-07 07:19:35 UTC
# 21     -0.427358 -0.904083 -0.376224  0.926529  2015-01-28 13:41:12 UTC
# 22     -0.410719 -0.911762  0.986593  0.163203  2014-07-11 13:37:00 UTC
# 23     -0.935572 -0.353135  0.662955 -0.748660  2009-03-21 16:37:17 UTC
# 24     -0.597683 -0.801732 -0.349731  0.936850  2012-12-05 14:26:49 UTC
# 25     -0.978148  0.207912  0.646600  0.762830  2013-12-19 18:48:00 UTC
# 26      0.768842 -0.639439  0.853616 -0.520903  2013-11-30 08:39:00 UTC
# 27     -0.529673 -0.848202 -0.360733  0.932669  2013-01-30 14:07:56 UTC
# 28     -0.999067  0.043183 -0.898274  0.439435  2012-05-29 18:09:54 UTC
# 29      0.675590 -0.737277  0.105768 -0.994391  2014-04-06 09:10:00 UTC
# ...          ...       ...       ...       ...                      ...
# 554837 -0.461749 -0.887011 -0.371136  0.928578  2014-03-12 13:50:00 UTC
# 554838  0.996541  0.083098 -0.614154 -0.789186  2011-05-30 05:40:56 UTC
# 554839 -0.986608  0.163111  0.999726 -0.023404  2014-10-31 18:37:33 UTC
# 554840 -0.325568  0.945519 -0.047356  0.998878  2012-01-25 22:44:00 UTC
# 554841 -0.938191  0.346117 -0.921718 -0.387860  2012-05-14 19:21:00 UTC
# 554842  0.405208 -0.914224 -0.743305 -0.668953  2015-02-09 10:24:23 UTC
# 554843 -0.759413  0.650609 -0.852526  0.522685  2010-05-25 20:42:21 UTC
# 554844  0.793663 -0.608357 -0.693709 -0.720256  2011-01-24 08:29:53 UTC
# 554845 -0.705511  0.708699 -0.846553  0.532305  2013-07-09 21:00:31 UTC
# 554846  0.938191  0.346117 -0.583237 -0.812302  2013-10-07 04:39:00 UTC
# 554847 -0.784280 -0.620407 -0.938274  0.345893  2015-02-17 15:26:37 UTC
# 554848 -0.902585  0.430511 -0.871581  0.490252  2013-09-17 19:42:00 UTC
# 554849 -0.643289  0.765624  0.521515 -0.853242  2014-01-18 21:19:51 UTC
# 554850 -0.554784  0.831994 -0.831395  0.555683  2015-06-09 21:45:13 UTC
# 554851 -0.798636  0.601815 -0.131762  0.991281  2014-03-12 20:28:00 UTC
# 554852 -0.596633  0.802514 -0.349906 -0.936785  2014-04-13 21:33:29 UTC
# 554853  0.948324 -0.317305 -0.586776  0.809749  2010-01-27 07:14:00 UTC
# 554854 -0.512605  0.858625  0.989140 -0.146977  2009-12-18 21:56:39 UTC
# 554855  0.374741  0.927129  0.961256 -0.275657  2011-07-23 01:28:02 UTC
# 554856  0.396681 -0.917957 -0.485618  0.874171  2011-12-28 10:26:31 UTC
# 554857 -0.991746  0.128219  0.999831 -0.018366  2013-05-31 18:29:28 UTC
# 554858 -0.371908 -0.928270 -0.054411 -0.998519  2015-05-10 13:27:20 UTC
# 554859  0.354291  0.935135  0.962116 -0.272640  2010-07-03 01:23:00 UTC
# 554860  0.992546 -0.121869  0.908404  0.418094  2011-05-20 06:28:00 UTC
# 554861 -0.553089  0.833122 -0.831233  0.555924  2009-06-09 21:45:41 UTC
# 554862  0.982110 -0.188310  0.912380  0.409345  2009-09-11 06:43:25 UTC
# 554863  0.064605  0.997911 -0.442186 -0.896923  2015-04-27 00:14:49 UTC
# 554864 -0.806014  0.591896  0.550290 -0.834974  2013-08-10 20:25:10 UTC
# 554865  0.056693 -0.998392  0.008103 -0.999967  2010-07-04 11:47:00 UTC
# 554866  0.073238  0.997314  0.424425 -0.905463  2009-03-29 00:16:48 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -73.976974        40.758774         -73.958610
# 1             -73.978330        40.762190         -73.781944
# 2             -73.944080        40.775944         -73.964310
# 3             -73.990320        40.757008         -73.983000
# 4             -73.983910        40.760300         -73.986100
# 5             -73.971270        40.795525         -73.998060
# 6             -73.966324        40.758640         -73.960570
# 7             -73.988580        40.769054         -73.954250
# 8             -73.972534        40.760020         -74.010605
# 9             -73.982120        40.723800         -73.986280
# 10            -73.989900        40.756763         -73.975610
# 11            -74.002625        40.728462         -73.978020
# 12            -73.965420        40.759365         -73.965225
# 13            -73.825775        40.715412         -74.002110
# 14            -74.015990        40.711185         -74.006710
# 15            -73.985115        40.727932         -73.983690
# 16            -73.997260        40.757015         -73.972500
# 17            -73.969200        40.749832         -73.963540
# 18            -73.982380        40.768265         -73.985090
# 19            -73.958860        40.771990         -73.944020
# 20            -73.982130        40.761890         -73.991900
# 21            -73.972500        40.759113         -73.870920
# 22            -74.004610        40.727856         -73.977940
# 23            -73.962880        40.799385         -73.988190
# 24            -73.959750        40.770980         -73.979370
# 25            -73.955940        40.779200         -73.992430
# 26            -73.974270        40.754040         -73.992670
# 27            -73.990010        40.741720         -73.996350
# 28            -73.992810        40.728150         -73.917960
# 29            -73.990280        40.731697         -73.953520
# ...                  ...              ...                ...
# 554837        -73.982475        40.752556         -73.971700
# 554838        -73.776695        40.645317         -73.909080
# 554839        -73.993180        40.767822         -74.009970
# 554840        -73.976295        40.757465         -73.952230
# 554841        -73.985466        40.731796         -73.986595
# 554842        -73.981610        40.720750         -73.976350
# 554843        -73.972570        40.764725         -73.994125
# 554844        -73.987700        40.765747         -73.976140
# 554845        -73.954400        40.764256         -73.991220
# 554846        -73.976166        40.748566         -73.991000
# 554847        -73.999760        40.723454         -73.991760
# 554848        -74.005630        40.750996         -73.964540
# 554849        -73.988880        40.726746         -74.009740
# 554850        -73.975430        40.752026         -73.960464
# 554851        -73.950230        40.771810         -73.981520
# 554852        -74.006470        40.739600         -74.004845
# 554853        -73.978610        40.763428         -73.991516
# 554854        -73.986650        40.758156         -73.997560
# 554855        -74.006424        40.739346         -73.998560
# 554856        -73.956260        40.767845         -73.978040
# 554857        -73.979546        40.735455         -74.004684
# 554858        -73.957360        40.774082         -73.945130
# 554859        -73.953470        40.790974         -73.991490
# 554860        -73.981750        40.777348         -73.995810
# 554861        -73.952170        40.778084         -73.989780
# 554862        -73.952160        40.781357         -73.977394
# 554863        -73.960870        40.806953         -73.973860
# 554864        -73.997840        40.736030         -73.989235
# 554865          0.000000         0.000000           0.000000
# 554866        -73.988930        40.736626         -74.000725
#
#         dropoff_latitude  passenger_count
# 0              40.690710                1
# 1              40.644340                1
# 2              40.758896                1
# 3              40.759190                1
# 4              40.753647                1
# 5              40.760696                3
# 6              40.761593                5
# 7              40.730080                1
# 8              40.701862                1
# 9              40.734413                1
# 10             40.765560                1
# 11             40.751270                1
# 12             40.763430                1
# 13             40.709850                5
# 14             40.714268                1
# 15             40.774487                1
# 16             40.753918                1
# 17             40.774242                1
# 18             40.758770                1
# 19             40.775930                1
# 20             40.749430                1
# 21             40.774094                1
# 22             40.753000                1
# 23             40.779280                1
# 24             40.766403                1
# 25             40.758670                1
# 26             40.751743                6
# 27             40.748210                1
# 28             40.771713                1
# 29             40.785294                1
# ...                  ...              ...
# 554837         40.763275                1
# 554838         40.694427                1
# 554839         40.734524                1
# 554840         40.783120                1
# 554841         40.722256                1
# 554842         40.739998                1
# 554843         40.745987                1
# 554844         40.755302                1
# 554845         40.755173                1
# 554846         40.724037                5
# 554847         40.710133                1
# 554848         40.764810                1
# 554849         40.713450                1
# 554850         40.769550                1
# 554851         40.761790                1
# 554852         40.734000                1
# 554853         40.750458                5
# 554854         40.751602                2
# 554855         40.734700                1
# 554856         40.756973                1
# 554857         40.739796                2
# 554858         40.790950                1
# 554859         40.749893                1
# 554860         40.755530                5
# 554861         40.762430                1
# 554862         40.766290                1
# 554863         40.794456                2
# 554864         40.735850                1
# 554865          0.000000                1
# 554866         40.730690                1
#
# [554867 rows x 18 columns]

# %% [markdown]
# ## Start Exploring the data

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-whitegrid')
# %matplotlib inline

# %%
# Sample the data - because it only take a 100K records to feel the data
df_all = df_all.sample(int(1e5))

# %%
df_small = df_all.sample(int(1e2))
df_small
# Out:
#         fare_amount  day  dayofweek  year  month  dayofmonth  hour  minute  \
# 474410         6.90   14          2  2011      6          14    16      47
# 49543         24.50    4          6  2010     12           4     2       1
# 372128        14.50   22          2  2014      7          22    17      49
# 409972         4.50   27          7  2010      6          27    14      42
# 81584          7.00   20          1  2015      4          20    20      36
# 359373        18.50   25          1  2014      8          25    16      53
# 211103         2.90    2          2  2011      8           2    10      36
# 57287          9.00   22          3  2015      4          22    15      49
# 94748          8.00    9          5  2014      5           9    21      17
# 48978         21.30   14          4  2012      6          14    20      22
# 231262         3.70   28          7  2010      3          28     0       1
# 307568        18.50   17          1  2014     11          17    20       9
# 330597         4.00   17          3  2013      7          17    13      15
# 486500         4.90   22          4  2009      1          22     1      51
# 271544         7.30   14          6  2012      4          14    19       9
# 300929         7.30    2          6  2011      7           2     7      39
# 445536         6.00   12          1  2012     11          12    12      30
# 166063        10.00   28          6  2013     12          28    11       0
# 287448         7.00   30          5  2010      4          30    13       4
# 29603         19.00   20          5  2015      3          20     5      28
# 114152        10.10   11          7  2011      9          11    12      43
# 297753        13.30   28          4  2010     10          28    18      12
# 222457         6.50   15          2  2009      9          15    18      20
# 152950         5.30    5          1  2010      4           5     6      12
# 440214         5.40   27          2  2009      1          27     0      50
# 155729        16.00   31          5  2014      1          31    15      39
# 401026         5.00    9          6  2013     11           9     2      48
# 455976        19.30   21          3  2012      3          21    18      10
# 7794           8.50   24          3  2015      6          24    20      32
# 287257         9.70    2          4  2012      8           2    12      43
# ...             ...  ...        ...   ...    ...         ...   ...     ...
# 86154          8.00   14          4  2013     11          14    17      20
# 344232        11.00    4          2  2014     11           4     7      24
# 101679         4.50   27          6  2015      6          27    16      10
# 239994         4.90   21          6  2010      8          21     6      35
# 17226         15.50    9          5  2014      5           9    16       4
# 246545        13.00   11          4  2013      4          11     5      11
# 255983        10.50   17          4  2011     11          17     2      20
# 533786         4.10   29          2  2012      5          29    14      42
# 459287        14.10   29          4  2011     12          29    17      21
# 173830         9.00   15          2  2013      1          15     7      42
# 150320        49.57    2          2  2010     11           2     3       3
# 186444        10.50    6          2  2010      4           6    19      42
# 485522        16.50   27          2  2012      3          27     8      33
# 279778         6.90    9          5  2011     12           9    17      27
# 542183         5.50    2          4  2014      1           2    13      57
# 98504         15.70   27          3  2011      7          27     7      11
# 390012         4.50   23          3  2011     11          23    14       5
# 243991         9.70   19          1  2010      4          19    15      23
# 427982         6.00   26          5  2013      7          26     5       8
# 476141         6.50   10          4  2014      4          10    15      14
# 292873        10.50    7          7  2015      6           7    18      14
# 233691         6.50   24          4  2014      4          24    15      16
# 246529         6.50   12          3  2011      1          12    11      50
# 217514        30.50    8          7  2009      3           8    15       6
# 250103         8.50   19          1  2012     11          19    15       1
# 475155        14.50    1          1  2010      3           1    18      12
# 148375        10.90   17          4  2011     11          17     9      41
# 390025         9.50   11          6  2014      1          11     5      50
# 142091         9.00   18          5  2014      7          18    22      32
# 33151          6.50   12          1  2011     12          12     8      51
#
#          sin_day   cos_day  sin_week  cos_week          pickup_datetime  \
# 474410 -0.743437  0.668806 -0.850713  0.525631  2011-06-14 20:47:54 UTC
# 49543   0.964730 -0.263242  0.883809 -0.467847  2010-12-04 07:01:03 UTC
# 372128 -0.540974  0.841039 -0.830082  0.557642  2014-07-22 21:49:00 UTC
# 409972 -0.983255  0.182236 -0.247965 -0.968769  2010-06-27 18:42:00 UTC
# 81584   0.160240  0.987078 -0.979786 -0.200050  2015-04-21 00:36:53 UTC
# 359373 -0.725975  0.687721 -0.942600 -0.333924  2014-08-25 20:53:48 UTC
# 211103 -0.629659 -0.776871 -0.948699  0.316181  2011-08-02 14:36:06 UTC
# 57287  -0.889017  0.457874 -0.155819  0.987786  2015-04-22 19:49:00 UTC
# 94748   0.331955  0.943295  0.963037 -0.269370  2014-05-10 01:17:33 UTC
# 48978   0.097728  0.995213  0.790473  0.612497  2012-06-15 00:22:26 UTC
# 231262  0.868199  0.496217  0.294159 -0.955756  2010-03-28 04:01:00 UTC
# 307568  0.296542  0.955020 -0.983594 -0.180397  2014-11-18 01:09:00 UTC
# 330597 -0.980785 -0.195090 -0.249776  0.968304  2013-07-17 17:15:00 UTC
# 486500  0.975342 -0.220697  0.253396  0.967363  2009-01-22 06:51:00 UTC
# 271544 -0.220272  0.975439  0.462246 -0.886752  2012-04-14 23:09:06 UTC
# 300929  0.091502 -0.995805  0.789926 -0.613203  2011-07-02 11:39:00 UTC
# 445536 -0.991445 -0.130526 -0.892698 -0.450655  2012-11-12 17:30:00 UTC
# 166063 -0.866025 -0.500000  0.680173 -0.733052  2013-12-28 16:00:00 UTC
# 287448 -0.970348 -0.241710  0.999392  0.034868  2010-04-30 17:04:03 UTC
# 29603   0.613883 -0.789397  0.949605  0.313450  2015-03-20 09:28:31 UTC
# 114152 -0.944830 -0.327561 -0.175807 -0.984425  2011-09-11 16:43:31 UTC
# 297753 -0.453990  0.891007  0.738119  0.674671  2010-10-28 22:12:00 UTC
# 222457 -0.422618  0.906308 -0.819152  0.573576  2009-09-15 22:20:00 UTC
# 152950  0.453990 -0.891007 -0.738119 -0.674671  2010-04-05 10:12:00 UTC
# 440214  0.999114  0.042094 -0.999982 -0.006015  2009-01-27 05:50:21 UTC
# 155729 -0.768609  0.639719  0.995088 -0.098999  2014-01-31 20:39:05 UTC
# 401026  0.891007 -0.453990  0.869741 -0.493508  2013-11-09 07:48:00 UTC
# 455976 -0.461749  0.887011 -0.068513  0.997650  2012-03-21 22:10:00 UTC
# 7794    0.141909  0.989880  0.020340  0.999793  2015-06-25 00:32:38 UTC
# 287257 -0.945424 -0.325843  0.585733  0.810504  2012-08-02 16:43:56 UTC
# ...          ...       ...       ...       ...                      ...
# 86154  -0.421168  0.906983  0.741627  0.670812  2013-11-14 22:20:22 UTC
# 344232 -0.104528 -0.994522 -0.971490  0.237080  2014-11-04 12:24:00 UTC
# 101679 -0.841393  0.540424  0.557719 -0.830030  2015-06-27 20:10:51 UTC
# 239994  0.360946 -0.932587  0.813621 -0.581396  2010-08-21 10:35:22 UTC
# 17226  -0.857167  0.515038  0.997014 -0.077216  2014-05-09 20:04:00 UTC
# 246545  0.672367 -0.740218  0.336743  0.941597  2013-04-11 09:11:00 UTC
# 255983  0.939693 -0.342020  0.270840  0.962624  2011-11-17 07:20:00 UTC
# 533786 -0.983162  0.182736 -0.889269  0.457384  2012-05-29 18:42:07 UTC
# 459287 -0.418660  0.908143  0.741892  0.670519  2011-12-29 22:21:00 UTC
# 173830 -0.183165 -0.983082 -0.968735  0.248096  2013-01-15 12:42:13 UTC
# 150320  0.962455 -0.271440 -0.999229  0.039260  2010-11-02 07:03:00 UTC
# 186444 -0.074979  0.997185 -0.788471  0.615072  2010-04-06 23:42:48 UTC
# 485522 -0.143493 -0.989651 -0.970145  0.242527  2012-03-27 12:33:00 UTC
# 279778 -0.394744  0.918791  0.986183 -0.165662  2011-12-09 22:27:00 UTC
# 542183 -0.968601  0.248619  0.651145  0.758953  2014-01-02 18:57:35 UTC
# 98504   0.212178 -0.977231 -0.461196  0.887298  2011-07-27 11:11:00 UTC
# 390012 -0.959662  0.281155 -0.182654  0.983177  2011-11-23 19:05:19 UTC
# 243991 -0.933633  0.358232 -0.922434 -0.386155  2010-04-19 19:23:58 UTC
# 427982  0.680934 -0.732345  0.945586  0.325372  2013-07-26 09:08:20 UTC
# 476141 -0.947304  0.320337  0.659221  0.751949  2014-04-10 19:14:44 UTC
# 292873 -0.443723  0.896164 -0.373817 -0.927503  2015-06-07 22:14:38 UTC
# 233691 -0.945519  0.325568  0.659814  0.751429  2014-04-24 19:16:00 UTC
# 246529 -0.954869 -0.297028 -0.264304  0.964439  2011-01-12 16:50:53 UTC
# 217514 -0.958820  0.284015 -0.262430 -0.964951  2009-03-08 19:06:00 UTC
# 250103 -0.863836  0.503774 -0.931101 -0.364761  2012-11-19 20:01:00 UTC
# 475155 -0.204638  0.978838 -0.967955 -0.251124  2010-03-01 23:12:46 UTC
# 148375 -0.646124 -0.763232  0.521967  0.852966  2011-11-17 14:41:00 UTC
# 390025  0.300498 -0.953783  0.808265 -0.588819  2014-01-11 10:50:03 UTC
# 142091  0.618065  0.786127  0.949367 -0.314170  2014-07-19 02:32:42 UTC
# 33151  -0.466901 -0.884309 -0.823184 -0.567775  2011-12-12 13:51:20 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 474410        -73.982270        40.765247         -73.957480
# 49543         -73.781630        40.644894         -73.874580
# 372128        -73.982040        40.763650         -74.003810
# 409972        -73.961170        40.760980         -73.954640
# 81584         -74.007324        40.727257         -73.994800
# 359373        -73.977776        40.783577         -73.985310
# 211103        -73.982450        40.777607         -73.979940
# 57287         -73.974600        40.762910         -73.954994
# 94748         -73.980780        40.721480         -74.002304
# 48978         -73.959580        40.762688         -73.993400
# 231262        -73.990906        40.760723         -73.995865
# 307568        -73.996670        40.729706         -73.976930
# 330597        -73.955060        40.780815         -73.960900
# 486500        -73.961260        40.768616         -73.969490
# 271544        -73.998320        40.745280         -73.986145
# 300929        -73.984474        40.722107         -73.991820
# 445536        -73.979890        40.735800         -73.976520
# 166063        -73.969710        40.768654         -73.969630
# 287448        -73.953860        40.765370         -73.953860
# 29603         -73.994300        40.736280         -74.009180
# 114152        -73.991135        40.751150         -73.976800
# 297753        -73.991270        40.760193         -73.993385
# 222457        -73.988020        40.737610         -73.987495
# 152950        -73.983050        40.770668         -73.972466
# 440214        -73.991340        40.750076         -73.980835
# 155729        -73.957855        40.769627         -73.996185
# 401026        -74.004890        40.751766         -74.008540
# 455976        -73.988365        40.723022         -73.981570
# 7794          -73.944550        40.779453         -73.964530
# 287257        -73.971120        40.795380         -73.947014
# ...                  ...              ...                ...
# 86154         -73.991200        40.750530         -74.008060
# 344232        -73.987045        40.736550         -74.007100
# 101679        -73.989000        40.757805         -73.994730
# 239994        -73.974250        40.752888         -73.966430
# 17226         -74.008606        40.711563         -73.982430
# 246545        -73.975720        40.743656         -73.987410
# 255983        -73.948715        40.773724         -73.980610
# 533786        -73.992980        40.743070         -74.003360
# 459287        -73.974240        40.791073           0.000000
# 173830        -73.966194        40.789770         -73.966490
# 150320        -73.970290        40.762074         -73.786510
# 186444        -73.988850        40.763367         -73.951860
# 485522        -73.982086        40.764700         -73.937750
# 279778        -73.999374        40.743820         -73.992165
# 542183        -73.946625        40.785130         -73.945210
# 98504         -73.989716        40.752876         -74.005390
# 390012        -73.961044        40.769410         -73.961044
# 243991        -74.007380        40.704018         -73.984470
# 427982        -73.981800        40.773518         -73.972590
# 476141          0.000000         0.000000           0.000000
# 292873        -74.012535        40.715065         -73.992810
# 233691        -73.963370        40.762608         -73.971504
# 246529        -73.973076        40.743656         -73.955040
# 217514        -73.990230        40.756165         -73.955185
# 250103        -74.004590        40.740560         -73.990780
# 475155        -73.961240        40.718906         -73.997925
# 148375        -73.965870        40.765244         -73.971320
# 390025        -73.970150        40.756523         -73.989670
# 142091        -73.997190        40.741707         -73.988250
# 33151         -73.974174        40.756245         -73.965576
#
#         dropoff_latitude  passenger_count
# 474410         40.771840                2
# 49543          40.735050                1
# 372128         40.741850                2
# 409972         40.769460                1
# 81584          40.750397                3
# 359373         40.731945                1
# 211103         40.779552                1
# 57287          40.774273                1
# 94748          40.733680                1
# 48978          40.694614                1
# 231262         40.753063                1
# 307568         40.751920                1
# 330597         40.775760                2
# 486500         40.763160                1
# 271544         40.762344                3
# 300929         40.744007                5
# 445536         40.727386                1
# 166063         40.750670                3
# 287448         40.765370                1
# 29603          40.704422                1
# 114152         40.790504                2
# 297753         40.722200                5
# 222457         40.722620                2
# 152950         40.759620                1
# 440214         40.759758                1
# 155729         40.732742                1
# 401026         40.745647                6
# 455976         40.658894                1
# 7794           40.774822                1
# 287257         40.780697                1
# ...                  ...              ...
# 86154          40.738900                1
# 344232         40.718280                2
# 101679         40.760590                1
# 239994         40.759186                4
# 17226          40.741917                1
# 246545         40.756380                2
# 255983         40.752796                1
# 533786         40.747303                1
# 459287         40.759857                1
# 173830         40.770462                1
# 150320         40.639977                1
# 186444         40.787250                1
# 485522         40.818280                1
# 279778         40.761604                2
# 542183         40.775345                1
# 98504          40.707287                5
# 390012         40.769410                1
# 243991         40.730476                1
# 427982         40.764790                1
# 476141          0.000000                1
# 292873         40.742960                3
# 233691         40.746616                1
# 246529         40.769264                1
# 217514         40.694700                1
# 250103         40.750008                1
# 475155         40.676990                2
# 148375         40.790253                1
# 390025         40.741420                1
# 142091         40.724148                1
# 33151          40.772230                1
#
# [100 rows x 18 columns]

# %%
df_all.describe()
# Out:
#          fare_amount            day     dayofweek           year  \
# count  100000.000000  100000.000000  100000.00000  100000.000000
# mean       11.330877      15.713970       3.99143    2011.739000
# std         9.673474       8.686317       1.90486       1.861938
# min        -3.000000       1.000000       1.00000    2008.000000
# 25%         6.000000       8.000000       2.00000    2010.000000
# 50%         8.500000      16.000000       4.00000    2012.000000
# 75%        12.500000      23.000000       6.00000    2013.000000
# max       187.000000      31.000000       7.00000    2015.000000
#
#                month     dayofmonth           hour         minute  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean        6.266710      15.713970      11.826060      29.565850
# std         3.439034       8.686317       5.833553      17.390534
# min         1.000000       1.000000       0.000000       0.000000
# 25%         3.000000       8.000000       7.000000      14.000000
# 50%         6.000000      16.000000      12.000000      30.000000
# 75%         9.000000      23.000000      17.000000      45.000000
# max        12.000000      31.000000      23.000000      59.000000
#
#              sin_day        cos_day       sin_week       cos_week  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       -0.204952      -0.041796       0.047875       0.028276
# std         0.652099       0.728714       0.710766       0.701235
# min        -1.000000      -1.000000      -1.000000      -1.000000
# 25%        -0.817564      -0.771625      -0.705342      -0.670644
# 50%        -0.337917      -0.107096       0.039535       0.078050
# 75%         0.359522       0.716302       0.721070       0.732348
# max         1.000000       1.000000       1.000000       1.000000
#
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# count     100000.000000    100000.000000      100000.000000     100000.000000
# mean         -72.531992        39.945787         -72.536126         39.935350
# std           10.338885         6.377867          10.556307          6.053681
# min          -80.821630       -74.013210        -736.483340        -74.006775
# 25%          -73.992070        40.735125         -73.991425         40.733900
# 50%          -73.981834        40.752750         -73.980210         40.752953
# 75%          -73.967040        40.767236         -73.963790         40.768010
# max           40.815390       406.216670          40.803620         45.650000
#
#        passenger_count
# count    100000.000000
# mean          1.681980
# std           1.302928
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max           6.000000

# %% [markdown]
# ### Date-Time Features

# %%
df_all['ts'] = df_all['pickup_datetime'].apply(pd.Timestamp)
df_all['weekday'] = df_all['ts'].dt.weekday
df_all['day'] = df_all['ts'].dt.day
df_all['month'] = df_all['ts'].dt.month
df_all['year'] = df_all['ts'].dt.year
df_all['hour'] = df_all['ts'].dt.hour

# %%
time_features = ['day', 'month', 'weekday', 'year', 'hour']

fig = plt.figure(figsize=(20,12))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(len(time_features)):
    ax = fig.add_subplot(2, 3, i+1)
    sns.boxplot(x=time_features[i], y="fare_amount", data=df_all[df_all['year'] >= 2013], showfliers=False)

plt.show()

# %% [markdown]
# ### Geographic

# %% [markdown]
# https://www.kaggle.com/breemen/nyc-taxi-fare-data-exploration

# %%
nyc_box = (-74.1, -73.7, 40.6, 40.9)

# %%
def filter_coordinates(df, box):
    return (df.pickup_longitude >= box[0]) & (df.pickup_longitude <= box[1]) & \
           (df.pickup_latitude >= box[2]) & (df.pickup_latitude <=box[3]) & \
           (df.dropoff_longitude >= box[0]) & (df.dropoff_longitude <= box[1]) & \
           (df.dropoff_latitude >= box[2]) & (df.dropoff_latitude <= box[3])

# %%
def plot_hires(df, box, figsize=(12, 12), ax=None, c=sns.color_palette("husl", 2)):
    if ax == None:
        fig, ax = plt.subplots(1, 1, figsize=figsize)

    idx = filter_coordinates(df, box)
    ax.scatter(df[idx].pickup_longitude, df[idx].pickup_latitude, c=c[0], s=0.1, lw=0.1, alpha=0.5)
    ax.scatter(df[idx].dropoff_longitude, df[idx].dropoff_latitude, c=c[1], s=0.1, lw=0.1, alpha=0.5)

# %%
plot_hires(df_all, nyc_box)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# <p>In the scatter plot above, the two major NYC airports are easily observed, indicating that it may be informative to "tell" our algorithm whether the ride starts or ends in an airport.</p>
# <p>To do so I use the airports.csv, available <a href="http://ourairports.com/data/">here</a> in the following way:</p>
# <ul>
# <li>from this file I extract the location of 3 of the listed NYC airports</li>
# <li>I than calculate the distance of dropoff and pickup points from every record to each airport, Assuming it will provide additional information to our model.</li>
# </ul>
# <p>Further details are in the feature extraction below</p>

# %% [markdown]
# ## Ride distance

# %%
df_all['air_distance'] = (df_all.pickup_longitude - df_all.dropoff_longitude)**2 +\
                     (df_all.pickup_latitude - df_all.dropoff_latitude)**2
df_all['air_distance'] = np.sqrt(df_all['air_distance'])

# %%
df_all['price_per_distance'] = df_all['fare_amount'] / df_all['air_distance']

# %%
time_features = ['weekday', 'year', 'hour']
fig = plt.figure(figsize=(18,5))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(len(time_features)):
    ax = fig.add_subplot(1, 3, i+1)
    sns.boxplot(x=time_features[i], y="price_per_distance", data=df_all[df_all['year'] >= 2013], showfliers=False)

plt.show()

# %%
time_features = ['weekday', 'year', 'hour']
fig = plt.figure(figsize=(18,5))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(len(time_features)):
    ax = fig.add_subplot(1, 3, i+1)
    sns.boxplot(x=time_features[i], y="air_distance", data=df_all[df_all['year'] >= 2013], showfliers=False)

plt.show()

# %% [markdown]
# ## Split train test

# %% [markdown]
# <p>If you managed to create the dataset using Athena, you have two options on how to create train and validation sets files.&nbsp;</p>
# <ol>
# <li>Create a seperate query, using a WHERE on the year clause to split the train and validation by time (e.g. year, month)</li>
# <li>Create a single query, partition the results by time, and use aws-cli to mv the directories to different train/validation directotires</li>
# </ol>

# %% [markdown]
# ## Train model

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
import sagemaker
from sagemaker import get_execution_role
import boto3
from datetime import datetime
import os
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
bucket = 'aws-worskhop-data'

path_train = 'taxinyc-query-results/train/78a6a6df-267a-4783-bef4-fd6eb4f082fa.csv'
path_validate = 'taxinyc-query-results/validate/60c4073e-00bc-4e80-a9aa-d93e53687a28.csv' 

s3_path_2014 = os.path.join('s3://', bucket, path_train)
s3_path_2015 = os.path.join('s3://', bucket, path_validate)

# %%
df_2014 = pd.read_csv(s3_path_2014, header=0, skiprows=lambda i: i>0 and random.random() > 0.1)

#n = 10  # every 100th line = 1% of the lines
#df_2014 = pd.read_csv(s3_path_2014, header=0, skiprows=lambda i: i % n != 0)

df_2014
df_2014.to_csv('train_small_2014.csv', header=False, index=False)
df_2014_final = pd.read_csv('./train_small_2014.csv')
df_2014_final
# Out:
#           6.5  18  2  2014  11  18.1  15  33  -0.7835127396130923  \
# 0        8.50  24  4  2014   4    24  10  54            -0.688355
# 1       12.00  22  6  2014  11    22  21  26             0.597275
# 2       23.00   7  1  2014   7     7  20   6             0.027267
# 3        8.50  20  4  2014  11    20  18  44            -0.066709
# 4        4.50  30  1  2014   6    30  20  29             0.126199
# 5       23.00   7  3  2014   5     7  16  36            -0.777146
# 6        9.50  11  6  2014  10    11  19  48            -0.052336
# 7        8.00  11  3  2014   6    11  12  44            -0.945519
# 8       16.00  19  6  2014   7    19  10  26            -0.594823
# 9       10.50  27  4  2014   2    27  10  59            -0.863982
# 10      16.50   4  4  2014  12     4  10  23            -0.774393
# 11      11.50  20  6  2014  12    20   6  18             0.178731
# 12      10.50  11  2  2014  11    11   4   2             0.698467
# 13       5.50  11  6  2014   1    11  21  33             0.621262
# 14      17.00  20  3  2014   8    20  20  47             0.203642
# 15      11.00  19  1  2014   5    19   6  54             0.284015
# 16      37.50  25  2  2014  11    25  18  41            -0.082808
# 17      15.50  12  7  2014  10    12   9  56            -0.484810
# 18       7.50  14  5  2014   3    14  22  49             0.674786
# 19       9.50   9  2  2014   9     9   4  58             0.713250
# 20      27.50  30  1  2014   6    30  23  48             0.840054
# 21       5.50   7  5  2014  11     7  15  50            -0.737130
# 22       8.00  31  3  2014  12    31  13  46            -0.979925
# 23       5.50  24  2  2014   6    24  20  49             0.212178
# 24      13.00   6  2  2014   5     6  14  53            -0.973379
# 25      15.00  30  3  2014   7    30   2  27             0.992853
# 26      32.50   4  1  2014   8     4  12  53            -0.958654
# 27      11.50  28  4  2014   8    28  13  41            -0.996578
# 28       8.50   7  3  2014   5     7  15  14            -0.948162
# 29      10.00  26  3  2014   2    26   5   1             0.495774
# ...       ...  .. ..   ...  ..   ...  ..  ..                  ...
# 826071  20.00  14  2  2014   1    14  17  29            -0.384765
# 826072   5.00   3  1  2014   2     3   1  54             0.972370
# 826073  12.50  23  7  2014  11    23  13  29            -0.991699
# 826074  52.00  16  7  2014   3    16   9  38            -0.414693
# 826075   8.00  24  3  2014  12    24  11  32            -0.927184
# 826076  13.50   7  5  2014   3     7   3   7             0.848318
# 826077  16.00  27  4  2014   2    27  14   9            -0.954826
# 826078  10.00  26  6  2014   7    26   9  11            -0.308740
# 826079  17.00  25  5  2014   4    25  13   5            -0.971342
# 826080   9.00  28  4  2014   8    28   4  45             0.750255
# 826081   6.50   2  1  2014   6     2   3  53             0.879891
# 826082  22.00  20  6  2014   9    20  20  32             0.139173
# 826083  21.00   9  5  2014   5     9  16  38            -0.771625
# 826084  10.00  23  7  2014  11    23  10  26            -0.784957
# 826085  19.50  11  6  2014  10    11  16  54            -0.725174
# 826086   4.00  18  2  2014  11    18  18  40            -0.085127
# 826087   3.50  21  1  2014   4    21  18  26            -0.398749
# 826088  14.50  11  5  2014   7    11  20  26             0.117393
# 826089   6.50  23  3  2014   4    23   3  30             0.923880
# 826090  13.00  11  3  2014   6    11  19   3            -0.246153
# 826091   6.00  20  5  2014   6    20   4   1             0.863836
# 826092  10.50  11  7  2014   5    11  16  52            -0.729665
# 826093   7.50  18  2  2014  11    18   4  56             0.515038
# 826094  14.00  25  4  2014  12    25  20  53             0.473320
# 826095   9.00  27  4  2014  11    27  19  16             0.069756
# 826096   6.50  29  3  2014   1    29   3   5             0.854912
# 826097   7.50  24  2  2014   6    24  15  34            -0.917060
# 826098   9.50  16  6  2014   8    16  13  40            -0.996314
# 826099  50.33  15  7  2014   6    15   2   6             0.999640
# 826100  15.50   3  6  2014   5     3  14  16            -0.997564
#
#         0.62137572117358  -0.8553427325730253  0.5180625539782915  -73.982605  \
# 0              -0.725374             0.528862            0.848708  -73.988850
# 1               0.802036             0.349799           -0.936825  -74.006905
# 2               0.999628            -0.975787           -0.218721  -73.782050
# 3               0.997772             0.775850            0.630918  -73.984604
# 4               0.992005            -0.978791           -0.204862  -73.955900
# 5               0.629320            -0.126817            0.991926  -73.995735
# 6               0.998630             0.440611           -0.897698  -73.983280
# 7              -0.325568            -0.268439            0.963297  -73.995740
# 8              -0.803857             0.721933           -0.691963  -73.983010
# 9              -0.503523             0.562839            0.826566  -73.963130
# 10             -0.632705             0.544116            0.839010  -73.874600
# 11             -0.983898             0.797578           -0.603216  -74.009190
# 12             -0.715642            -0.993516            0.113688  -73.956890
# 13              0.783603             0.345747           -0.938328  -74.005390
# 14              0.979045             0.029292            0.999571  -73.983240
# 15             -0.958820            -0.755527           -0.655118  -73.951965
# 16              0.996566            -0.789161            0.614187  -73.979220
# 17             -0.874620            -0.072244           -0.997387  -73.987710
# 18              0.738014             0.945974           -0.324242  -74.005100
# 19             -0.700909            -0.993851            0.110726  -73.991300
# 20              0.542503            -0.996647           -0.081825  -73.973680
# 21              0.675751             0.994388           -0.105799  -74.005700
# 22              0.199368            -0.194479            0.980907  -73.979195
# 23              0.977231            -0.762426            0.647075  -73.993590
# 24              0.229200            -0.886146            0.463407  -73.957726
# 25             -0.119343            -0.610038            0.792372  -73.948050
# 26             -0.284573            -0.882323           -0.470645  -73.870850
# 27             -0.082663             0.614203            0.789148  -73.991580
# 28              0.317787            -0.177259            0.984164  -73.994120
# 29             -0.868451            -0.499397            0.866373  -73.972010
# ...                  ...                  ...                 ...         ...
# 826071          0.923014            -0.815747            0.578409  -73.985870
# 826072         -0.233445            -0.649448           -0.760406  -74.000670
# 826073          0.128579            -0.240440           -0.970664  -73.970825
# 826074         -0.909961            -0.061049           -0.998135    0.000000
# 826075         -0.374607            -0.275637            0.961262  -73.982270
# 826076         -0.529487             0.932658            0.360762  -73.988365
# 826077          0.297167             0.656600            0.754239  -73.974330
# 826078         -0.951146             0.753099           -0.657907  -74.011925
# 826079         -0.237686             0.999412            0.034277  -74.003720
# 826080         -0.661148             0.321764            0.946820  -73.982220
# 826081         -0.475176            -0.677189           -0.735809  -73.956604
# 826082          0.990268             0.415827           -0.909444  -73.988205
# 826083          0.636078             0.995154           -0.098327  -74.005000
# 826084         -0.619551            -0.128590           -0.991698  -74.006294
# 826085          0.688566             0.535160           -0.844751  -73.991490
# 826086          0.996370            -0.789365            0.613924  -73.985970
# 826087          0.917060            -0.960224           -0.279231  -74.007590
# 826088          0.993086             0.971050           -0.238876  -73.994156
# 826089         -0.382683            -0.578671            0.815561  -73.993920
# 826090          0.969231            -0.035522            0.999369  -73.961100
# 826091         -0.503774             0.931101            0.364761  -73.955080
# 826092          0.683805            -0.325902           -0.945404  -74.000030
# 826093         -0.857167            -0.989199            0.146576  -73.982290
# 826094          0.880891             0.823773            0.566920  -73.984024
# 826095          0.997564             0.788011            0.615661  -73.955660
# 826096         -0.518773            -0.560742            0.827990  -73.991570
# 826097          0.398749            -0.874015            0.485900  -73.991750
# 826098         -0.085779             0.633035           -0.774123  -73.972730
# 826099         -0.026831             0.218782           -0.975774  -74.014780
# 826100          0.069756             0.615661           -0.788011  -73.993904
#
#         40.762356  -73.99594  40.753807  1
# 0       40.753223 -73.993744  40.735886  4
# 1       40.725784 -73.992744  40.756504  3
# 2       40.644640 -73.846660  40.722843  1
# 3       40.759907 -73.988730  40.745705  1
# 4       40.779590 -73.950820  40.783140  5
# 5       40.723250 -73.973320  40.795288  5
# 6       40.726400 -73.990814  40.718670  1
# 7       40.732746 -73.993590  40.744990  2
# 8       40.766370 -73.991640  40.731840  3
# 9       40.768147 -73.982960  40.761326  1
# 10      40.774090 -73.936470  40.755180  1
# 11      40.706970 -73.987390  40.722652  2
# 12      40.778470 -73.968890  40.761967  1
# 13      40.739906 -73.995450  40.749634  1
# 14      40.764420 -73.942870  40.818290  1
# 15      40.778355 -73.970590  40.752350  1
# 16      40.766860 -73.986710  40.672710  1
# 17      40.750050 -73.995770  40.769470  1
# 18      40.741184 -74.003110  40.724415  2
# 19      40.730087 -73.992650  40.748013  2
# 20      40.761753 -73.986030  40.676964  2
# 21      40.741196 -74.001800  40.751620  1
# 22      40.740390 -73.996310  40.725414  5
# 23      40.721283 -73.986940  40.728283  1
# 24      40.765278 -73.975190  40.792503  2
# 25      40.770450 -74.002860  40.760693  1
# 26      40.773670 -73.966805  40.683090  1
# 27      40.750004 -73.982864  40.755490  1
# 28      40.751183 -73.974620  40.764990  1
# 29      40.746513 -73.978160  40.759087  1
# ...           ...        ...        ... ..
# 826071  40.757740 -73.942060  40.822662  2
# 826072  40.747307 -74.002700  40.737614  6
# 826073  40.758945 -73.988710  40.748398  2
# 826074   0.000000   0.000000   0.000000  5
# 826075  40.757020 -73.991550  40.750210  1
# 826076  40.723454 -73.958480  40.764385  1
# 826077  40.752070 -73.975190  40.787872  1
# 826078  40.713770 -74.007650  40.742790  3
# 826079  40.741990 -74.000280  40.761642  1
# 826080  40.770393 -73.963220  40.766273  1
# 826081  40.766968 -73.963844  40.774258  2
# 826082  40.723446 -73.970750  40.796757  2
# 826083  40.728813 -73.966480  40.804237  1
# 826084  40.733650 -73.988940  40.737328  1
# 826085  40.750168 -73.945150  40.778650  2
# 826086  40.738310 -73.980780  40.733900  1
# 826087  40.707355 -74.010540  40.709830  1
# 826088  40.751470 -73.949936  40.776040  1
# 826089  40.751366 -73.983315  40.759550  1
# 826090  40.760685 -73.937965  40.812900  1
# 826091  40.777355 -73.945786  40.790090  1
# 826092  40.727850 -73.978450  40.751087  1
# 826093  40.757660 -73.971930  40.763080  1
# 826094  40.724630 -73.946120  40.724300  1
# 826095  40.779900 -73.932350  40.795810  1
# 826096  40.750330 -73.985580  40.742420  1
# 826097  40.759660 -73.996666  40.742720  5
# 826098  40.765083 -73.981606  40.752340  2
# 826099  40.709350 -73.929410  40.754124  1
# 826100  40.767174 -73.988884  40.730990  2
#
# [826101 rows x 17 columns]

# %%
df_2015 = pd.read_csv(s3_path_2015, header=0, skiprows=lambda i: i>0 and random.random() > 0.1)

#n = 10  # every 100th line = 1% of the lines
#df_2015 = pd.read_csv(s3_path_2015, header=0, skiprows=lambda i: i % n != 0)

df_2015
df_2015.to_csv('validate_small_2015.csv', header=False, index=False)
df_2015_final = pd.read_csv('./validate_small_2015.csv')
df_2015_final
# Out:
#         20.0  29  4  2015  1  29.1  18  24  -0.1526264962055698  \
# 0       11.0  27  6  2015  6    27  16  24            -0.807433
# 1       17.0  23  4  2015  4    23  14  23            -0.994873
# 2        9.5  18  7  2015  1    18   5   5             0.479777
# 3       25.5  13  6  2015  6    13   8  39            -0.170783
# 4        8.0   8  3  2015  4     8  20   9             0.042530
# 5        8.0  16  2  2015  6    16  17  28            -0.612735
# 6       10.5  26  4  2015  2    26  11  56            -0.961701
# 7       19.5  20  5  2015  3    20   6  40             0.338396
# 8        8.0   6  5  2015  3     6  15  52            -0.730262
# 9        9.5  26  1  2015  1    26   4  16             0.653366
# 10       7.0  18  6  2015  4    18   3  38             0.909176
# 11       5.0   7  7  2015  6     7   9  32            -0.394142
# 12       7.0  23  1  2015  2    23  12  37            -0.995142
# 13       6.5  24  2  2015  2    24   6  52             0.031847
# 14       4.0   5  4  2015  3     5  16  11            -0.672259
# 15       7.5   5  5  2015  6     5  19  17            -0.184595
# 16       7.0  27  1  2015  4    27  15   3            -0.962119
# 17      10.0  29  1  2015  6    29   4  11             0.840685
# 18       6.5  25  4  2015  6    25   6   4             0.481945
# 19       6.0  24  2  2015  2    24   5  16             0.437848
# 20       6.5  18  3  2015  2    18   3  41             0.763091
# 21      20.0  10  7  2015  5    10  13  48            -0.998795
# 22      13.0  17  2  2015  2    17  17  10            -0.460781
# 23      12.0   6  5  2015  2     6  12  55            -0.999825
# 24       7.5   2  1  2015  2     2  15  59            -0.708237
# 25       9.0   3  5  2015  4     3  21  34             0.400616
# 26      23.0  29  1  2015  6    29   2  44             0.980913
# 27       4.0  29  4  2015  1    29  10  36            -0.810638
# 28      18.0   9  6  2015  5     9   0   5             0.877774
# 29       5.0  23  4  2015  4    23  15  19            -0.940263
# ...      ...  .. ..   ... ..   ...  ..  ..                  ...
# 384649   7.0   6  1  2015  4     6   6  59             0.259311
# 384650   7.0  27  6  2015  6    27  12  48            -0.951483
# 384651   6.5  27  1  2015  4    27  14  22            -0.995284
# 384652   6.0  19  7  2015  4    19  22  23             0.586431
# 384653   7.5  12  2  2015  5    12  10  28            -0.604657
# 384654   7.5  24  3  2015  6    24  10  34            -0.625299
# 384655   8.0   8  5  2015  5     8  22  44             0.656169
# 384656  12.5  10  2  2015  3    10  20  54             0.233445
# 384657  64.5  25  4  2015  6    25  13  18            -0.983663
# 384658   8.5  29  4  2015  1    29  15  25            -0.804678
# 384659  13.5  17  2  2015  2    17  23  16             0.899081
# 384660   3.5  30  2  2015  6    30  15  41            -0.904238
# 384661   6.5  27  3  2015  5    27  12  22            -0.911104
# 384662   7.5   9  5  2015  1     9   8  33            -0.396814
# 384663   7.5  24  2  2015  2    24  15   3            -0.858326
# 384664  12.0  25  6  2015  4    25  21  25             0.365757
# 384665   4.0  26  7  2015  4    26  13  46            -0.998253
# 384666   3.5  11  6  2015  4    11   4   3             0.858438
# 384667   4.5   9  1  2015  2     9   3   1             0.863285
# 384668   7.5   3  7  2015  5     3   8  24            -0.105686
# 384669   5.5   7  4  2015  5     7   4  18             0.822847
# 384670   6.5  10  5  2015  4    10  18  56            -0.274029
# 384671   8.5  20  3  2015  5    20   6   3             0.485891
# 384672   7.0  14  6  2015  3    14   5  58             0.506473
# 384673   8.0  12  5  2015  6    12  11   3            -0.717620
# 384674  10.5  23  1  2015  3    23  12  32            -0.928324
# 384675  25.5  12  2  2015  5    12  14  28            -0.992537
# 384676   9.5  25  3  2015  2    25  19  27             0.121508
# 384677  11.5   4  3  2015  2     4   0  44             0.997609
# 384678  17.5  15  7  2015  2    15  17  49            -0.301954
#
#         0.98828394333613  0.7679974963844364  0.6404528441245598  -73.97409  \
# 0               0.589960            0.550576           -0.834785 -73.980510
# 1               0.101129            0.634739            0.772727 -73.972870
# 2              -0.877391            0.071425           -0.997446 -73.976260
# 3              -0.985309            0.766311           -0.642469 -74.003590
# 4               0.999095            0.006077            0.999982 -73.954220
# 5               0.790289           -0.837020            0.547172 -73.975800
# 6              -0.274099            0.591996            0.805941 -73.969270
# 7              -0.941004            0.962773            0.270310 -74.007270
# 8               0.683168            0.994234           -0.107235 -73.989920
# 9              -0.757043           -0.714480           -0.699656 -73.955990
# 10             -0.416413            0.872669           -0.488313 -73.995560
# 11             -0.919049           -0.057844           -0.998326 -73.995870
# 12             -0.098451           -0.894767           -0.446532 -74.013660
# 13             -0.999493           -0.975930            0.218082 -73.996290
# 14              0.740316            0.711953            0.702227 -73.954770
# 15              0.982815            0.980486           -0.196588 -73.983610
# 16              0.272630           -0.917379           -0.398015 -73.974690
# 17             -0.541525           -0.685251           -0.728307 -73.959220
# 18             -0.876202            0.368096            0.929788 -73.966000
# 19             -0.899049           -0.987282            0.158979 -73.995240
# 20             -0.646290           -0.541996            0.840381 -73.982994
# 21             -0.049068           -0.215679           -0.976464 -73.985910
# 22              0.887514           -0.822623            0.568587 -73.992836
# 23             -0.018688            0.999996            0.002670 -73.954346
# 24              0.705975           -0.943808           -0.330495 -73.974100
# 25              0.916246            0.960143           -0.279510   0.000000
# 26             -0.194448           -0.645101           -0.764098 -73.951240
# 27             -0.585547            0.551226            0.834356 -73.991040
# 28              0.479075            0.929616           -0.368530 -73.990020
# 29              0.340448            0.661507            0.749939 -73.981220
# ...                  ...                 ...                 ...        ...
# 384649         -0.965794           -0.757924           -0.652343 -74.010690
# 384650         -0.307703            0.657790           -0.753201 -73.997640
# 384651          0.097004           -0.906904           -0.421337 -73.980830
# 384652          0.809999           -0.512694           -0.858571 -73.985860
# 384653         -0.796486           -0.950124            0.311871 -73.949210
# 384654         -0.780385           -0.345054            0.938583 -74.005670
# 384655          0.754614            0.947124           -0.320869 -73.993004
# 384656          0.972370           -0.760406            0.649448 -73.976340
# 384657         -0.180018            0.603067            0.797690 -73.872860
# 384658          0.593712            0.691821            0.722069 -74.004425
# 384659          0.437783           -0.672759            0.739862 -73.990100
# 384660          0.427029           -0.871851            0.489772 -74.008880
# 384661         -0.412177           -0.281245            0.959636 -73.967230
# 384662         -0.917899            0.986236            0.165345 -73.961380
# 384663          0.513104           -0.864938            0.501879 -73.975360
# 384664          0.930710            0.385091           -0.922879 -73.970920
# 384665         -0.059089           -0.214279           -0.976773 -73.959564
# 384666         -0.512917            0.864953           -0.501852 -73.999176
# 384667         -0.504716           -0.680744           -0.732522 -74.004715
# 384668         -0.994400           -0.015126           -0.999886 -73.960590
# 384669         -0.568263            0.305765            0.952107 -73.973400
# 384670          0.961721            0.982983           -0.183696   0.000000
# 384671         -0.874020           -0.497992            0.867181 -74.004940
# 384672         -0.862256            0.826841           -0.562436 -73.959280
# 384673         -0.696435            0.993950            0.109838 -73.975914
# 384674         -0.371773           -0.876036           -0.482245 -73.982320
# 384675          0.121942           -0.893255            0.449551 -73.955320
# 384676          0.992590            0.017400            0.999849 -73.979790
# 384677          0.069104           -0.631184            0.775633 -73.946850
# 384678          0.953323           -0.393999           -0.919111   0.000000
#
#         40.747440000000005  -73.956924  40.720566  1.1
# 0                40.764526  -73.984740  40.745308    1
# 1                40.753350  -73.962880  40.794100    5
# 2                40.740010  -73.984860  40.715370    2
# 3                40.707882  -73.885730  40.744300    1
# 4                40.764110  -73.951040  40.782890    1
# 5                40.748653  -73.961110  40.762480    1
# 6                40.689526  -73.965580  40.710587    2
# 7                40.719204  -73.958780  40.759890    3
# 8                40.729420  -73.976340  40.739970    1
# 9                40.776047  -73.966500  40.793423    1
# 10               40.759510  -73.982300  40.752460    1
# 11               40.744190  -74.006840  40.742560    1
# 12               40.713917  -74.003810  40.725178    5
# 13               40.723630  -73.992690  40.734050    1
# 14               40.765640  -73.960060  40.762060    1
# 15               40.759190  -73.980650  40.746710    3
# 16               40.790203  -73.982350  40.776290    2
# 17               40.780262  -73.938965  40.804817    2
# 18               40.765220  -73.972330  40.757030    1
# 19               40.683660  -74.000310  40.692776    1
# 20               40.738853  -73.976270  40.749542    2
# 21               40.759040  -74.004450  40.730366    2
# 22               40.730180  -73.968636  40.755707    5
# 23               40.781330  -73.977240  40.779640    1
# 24               40.763050  -73.973300  40.747900    1
# 25                0.000000    0.000000   0.000000    1
# 26               40.778774  -74.014280  40.709232    1
# 27               40.750120  -73.994090  40.746086    1
# 28               40.719208  -73.931910  40.761333    2
# 29               40.732460  -73.982340  40.740080    5
# ...                    ...         ...        ...  ...
# 384649           40.717617  -74.008880  40.734790    1
# 384650           40.756680  -73.988640  40.769010    5
# 384651           40.761997  -73.968220  40.762203    1
# 384652           40.755775  -73.980255  40.745670    1
# 384653           40.773280  -73.962080  40.755660    1
# 384654           40.750816  -73.991540  40.742450    1
# 384655           40.741238  -73.972404  40.749344    1
# 384656           40.755527  -74.004550  40.716500    1
# 384657           40.774426  -73.942570  40.603844    1
# 384658           40.730766  -73.988110  40.739223    1
# 384659           40.719265  -73.981220  40.676700    2
# 384660           40.733406  -74.006060  40.735638    2
# 384661           40.769257  -73.963360  40.764782    2
# 384662           40.777283  -73.976950  40.788498    1
# 384663           40.759460  -73.955860  40.771164    2
# 384664           40.755432  -73.992480  40.756943    1
# 384665           40.762850  -73.952970  40.771816    1
# 384666           40.734276  -73.994050  40.741070    1
# 384667           40.746826  -74.003880  40.738810    6
# 384668           40.778380  -73.977740  40.774480    1
# 384669           40.784874  -73.982000  40.778400    1
# 384670            0.000000    0.000000   0.000000    3
# 384671           40.746430  -74.007150  40.740765    1
# 384672           40.783108  -73.973390  40.763930    1
# 384673           40.754310  -73.978516  40.759884    1
# 384674           40.767136  -73.977970  40.753800    1
# 384675           40.768480  -74.002530  40.755920    1
# 384676           40.752430  -73.953770  40.770756    1
# 384677           40.800150  -73.973470  40.758743    6
# 384678            0.000000  -74.005250  40.728750    3
#
# [384679 rows x 17 columns]

# %%
# !aws s3 cp train_small_2014.csv s3://aws-worskhop-data/taxinyc-query-results/train2/train_small_2014.csv
# Out:
# upload: ./train_small_2014.csv to s3://aws-worskhop-data/taxinyc-query-results/train2/train_small_2014.csv

# %%
# !aws s3 cp validate_small_2015.csv s3://aws-worskhop-data/taxinyc-query-results/validate2/validate_small_2015.csv
# Out:
# upload: ./validate_small_2015.csv to s3://aws-worskhop-data/taxinyc-query-results/validate2/validate_small_2015.csv

# %%
path_train = os.path.join('taxinyc-query-results','train2')
path_val = os.path.join('taxinyc-query-results','validate2')
bucket = 'aws-worskhop-data'

# %%
container = get_image_uri(boto3.Session().region_name, 'xgboost', repo_version="0.90-2")

# %%
's3://{}/{}'.format(bucket, path_train)
# Out:
# 's3://aws-worskhop-data/taxinyc-query-results/train2'

# %%
s3_input_trains3_inpu  = sagemaker.s3_input(s3_data='s3://{}/{}'.format(bucket, path_train),
                                            content_type='csv',
                                            distribution='ShardedByS3Key')
s3_input_validation = sagemaker.s3_input(s3_data='s3://{}/{}'.format(bucket, path_val),
                                         content_type='csv', 
                                         distribution='ShardedByS3Key')

# %%
sess = sagemaker.Session()
role = get_execution_role()

# %%
training_job_path = os.path.join('training_jobs', datetime.now().strftime('%Y-%m-%d-%H-%M-%S'))

# %%
's3://{}/{}/output'.format(bucket,training_job_path)
# Out:
# 's3://aws-worskhop-data/training_jobs/2020-06-07-07-50-43/output'

# %% [markdown]
# ## Train and debug the model

# %%
from smdebug.trials import create_trial
from sagemaker.debugger import rule_configs, Rule, DebuggerHookConfig, CollectionConfig

# %%
hyperparameters = {
    "max_depth": "9",
    "eta": "0.2",
    "gamma": "4",
    "min_child_weight": "300",
    "subsample": "0.8",
    "silent": "0",
    "objective": "reg:linear",
    "early_stopping_rounds": "10",
    "num_round": "10000"
}

save_interval = 5

# %%
xgboost_estimator = sagemaker.estimator.Estimator(
    role=role,
    train_instance_count=1,
    train_instance_type='ml.m5.4xlarge',
    output_path='s3://{}/{}/output'.format(bucket,training_job_path),
    image_name=container,
    hyperparameters=hyperparameters,
    train_max_run=10800,
    sagemaker_session=sess,

    debugger_hook_config=DebuggerHookConfig(
        s3_output_path='s3://{}/{}/output'.format(bucket,training_job_path),  # Required
        collection_configs=[
            CollectionConfig(
                name="metrics",
                parameters={
                    "save_interval": str(save_interval)
                }
            ),
            CollectionConfig(
                name="feature_importance",
                parameters={
                    "save_interval": str(save_interval)
                }
            ),
            CollectionConfig(
                name="full_shap",
                parameters={
                    "save_interval": str(save_interval)
                }
            ),
            CollectionConfig(
                name="average_shap",
                parameters={
                    "save_interval": str(save_interval)
                }
            ),
        ],
    ),

    rules=[
        Rule.sagemaker(
            rule_configs.loss_not_decreasing(),
            rule_parameters={
                "collection_names": "metrics",
                "num_steps": str(save_interval * 2),
            },
        ),
    ],
)

# %%
xgboost_estimator.fit({'train': s3_input_trains3_inpu, 'validation': s3_input_validation})
# Out:
# 2020-06-07 11:45:25 Starting - Starting the training job...
# 2020-06-07 11:45:28 Starting - Launching requested ML instances
# ********* Debugger Rule Status *********
# *
# *  LossNotDecreasing: InProgress
# *
# ****************************************
# .........
# 2020-06-07 11:47:10 Starting - Preparing the instances for training...
# 2020-06-07 11:47:51 Downloading - Downloading input data...
# 2020-06-07 11:48:16 Training - Training image download completed. Training in progress...INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value reg:linear to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# [11:48:18] 826102x16 matrix with 13217632 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# INFO:root:Determined delimiter of CSV input is ','
# [11:48:18] 384680x16 matrix with 6154880 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# INFO:root:Single node training.
# [2020-06-07 11:48:18.566 ip-10-0-70-113.eu-west-1.compute.internal:1 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020-06-07 11:48:18.566 ip-10-0-70-113.eu-west-1.compute.internal:1 INFO hook.py:151] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2020-06-07 11:48:18.566 ip-10-0-70-113.eu-west-1.compute.internal:1 INFO hook.py:196] Saving to /opt/ml/output/tensors
# INFO:root:Debug hook created from config
# INFO:root:Train matrix has 826102 rows
# INFO:root:Validation matrix has 384680 rows
# [11:48:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]#011train-rmse:13.9504#011validation-rmse:14.9711
# [2020-06-07 11:48:19.305 ip-10-0-70-113.eu-west-1.compute.internal:1 INFO hook.py:325] Monitoring the collections: full_shap, feature_importance, average_shap, losses, metrics
# [1]#011train-rmse:11.7482#011validation-rmse:12.8886
# [2]#011train-rmse:10.0819#011validation-rmse:11.3528
# [3]#011train-rmse:8.82157#011validation-rmse:10.2178
# [4]#011train-rmse:7.88664#011validation-rmse:9.40108
# [5]#011train-rmse:7.17643#011validation-rmse:8.79343
# [6]#011train-rmse:6.68681#011validation-rmse:8.38397
# [7]#011train-rmse:6.33562#011validation-rmse:8.0942
# [8]#011train-rmse:6.02957#011validation-rmse:7.84614
# [9]#011train-rmse:5.83297#011validation-rmse:7.68636
# [10]#011train-rmse:5.69142#011validation-rmse:7.57171
# [11]#011train-rmse:5.57258#011validation-rmse:7.47432
# [12]#011train-rmse:5.50269#011validation-rmse:7.41667
# [13]#011train-rmse:5.40227#011validation-rmse:7.33568
# [14]#011train-rmse:5.35845#011validation-rmse:7.29917
# [15]#011train-rmse:5.32998#011validation-rmse:7.2763
# [16]#011train-rmse:5.27736#011validation-rmse:7.23477
# [17]#011train-rmse:5.21279#011validation-rmse:7.18571
# [18]#011train-rmse:5.18261#011validation-rmse:7.16306
# [19]#011train-rmse:5.12574#011validation-rmse:7.12013
# [20]#011train-rmse:5.09041#011validation-rmse:7.08624
# [21]#011train-rmse:5.07597#011validation-rmse:7.07666
# [22]#011train-rmse:5.05048#011validation-rmse:7.05075
# [23]#011train-rmse:5.04278#011validation-rmse:7.04552
# [24]#011train-rmse:5.01947#011validation-rmse:7.03084
# [25]#011train-rmse:4.99111#011validation-rmse:7.00961
# [26]#011train-rmse:4.9698#011validation-rmse:6.99559
# [27]#011train-rmse:4.96479#011validation-rmse:6.99418
# [28]#011train-rmse:4.96115#011validation-rmse:6.9916
# [29]#011train-rmse:4.95519#011validation-rmse:6.98785
# [30]#011train-rmse:4.94246#011validation-rmse:6.97852
# [31]#011train-rmse:4.9389#011validation-rmse:6.97641
# [32]#011train-rmse:4.93469#011validation-rmse:6.97619
# [33]#011train-rmse:4.92859#011validation-rmse:6.97283
# [34]#011train-rmse:4.92302#011validation-rmse:6.96929
# [35]#011train-rmse:4.91482#011validation-rmse:6.96392
# [36]#011train-rmse:4.90009#011validation-rmse:6.95328
# [37]#011train-rmse:4.89589#011validation-rmse:6.94962
# [38]#011train-rmse:4.89119#011validation-rmse:6.94563
# [39]#011train-rmse:4.88775#011validation-rmse:6.94479
# [40]#011train-rmse:4.88495#011validation-rmse:6.94324
# [41]#011train-rmse:4.88261#011validation-rmse:6.94178
# [42]#011train-rmse:4.8795#011validation-rmse:6.94079
# [43]#011train-rmse:4.87726#011validation-rmse:6.94101
# [44]#011train-rmse:4.87509#011validation-rmse:6.939
# [45]#011train-rmse:4.87059#011validation-rmse:6.93589
# [46]#011train-rmse:4.86917#011validation-rmse:6.93595
# [47]#011train-rmse:4.86618#011validation-rmse:6.93427
# [48]#011train-rmse:4.86007#011validation-rmse:6.93034
# [49]#011train-rmse:4.8524#011validation-rmse:6.92408
# [50]#011train-rmse:4.85065#011validation-rmse:6.92357
# [51]#011train-rmse:4.84853#011validation-rmse:6.92226
# [52]#011train-rmse:4.84698#011validation-rmse:6.92124
# [53]#011train-rmse:4.84571#011validation-rmse:6.9204
# [54]#011train-rmse:4.84351#011validation-rmse:6.91888
# [55]#011train-rmse:4.8405#011validation-rmse:6.91729
# [56]#011train-rmse:4.83918#011validation-rmse:6.9166
# [57]#011train-rmse:4.83189#011validation-rmse:6.9117
# [58]#011train-rmse:4.8294#011validation-rmse:6.9099
# [59]#011train-rmse:4.82679#011validation-rmse:6.90969
# [60]#011train-rmse:4.82425#011validation-rmse:6.90852
# [61]#011train-rmse:4.82172#011validation-rmse:6.90758
# [62]#011train-rmse:4.81901#011validation-rmse:6.90558
# [63]#011train-rmse:4.81728#011validation-rmse:6.90439
# [64]#011train-rmse:4.81461#011validation-rmse:6.90355
# [65]#011train-rmse:4.81261#011validation-rmse:6.90177
# [66]#011train-rmse:4.80965#011validation-rmse:6.89985
# [67]#011train-rmse:4.80845#011validation-rmse:6.8989
# [68]#011train-rmse:4.80608#011validation-rmse:6.89708
# [69]#011train-rmse:4.80266#011validation-rmse:6.89473
# [70]#011train-rmse:4.78187#011validation-rmse:6.88302
# [71]#011train-rmse:4.77924#011validation-rmse:6.88136
# [72]#011train-rmse:4.77763#011validation-rmse:6.8807
# [73]#011train-rmse:4.77602#011validation-rmse:6.88061
# [74]#011train-rmse:4.77489#011validation-rmse:6.8797
# [75]#011train-rmse:4.77439#011validation-rmse:6.87972
# [76]#011train-rmse:4.77311#011validation-rmse:6.87952
# [77]#011train-rmse:4.77217#011validation-rmse:6.87871
# [78]#011train-rmse:4.76949#011validation-rmse:6.87722
# [79]#011train-rmse:4.76741#011validation-rmse:6.87628
# [80]#011train-rmse:4.76667#011validation-rmse:6.87618
# [81]#011train-rmse:4.76206#011validation-rmse:6.87246
# [82]#011train-rmse:4.7608#011validation-rmse:6.87225
# [83]#011train-rmse:4.75592#011validation-rmse:6.86844
# [84]#011train-rmse:4.75475#011validation-rmse:6.86796
# [85]#011train-rmse:4.75363#011validation-rmse:6.86717
#
# ********* Debugger Rule Status *********
# *
# *  LossNotDecreasing: IssuesFound
# *
# ****************************************
# [86]#011train-rmse:4.75202#011validation-rmse:6.86685
# [87]#011train-rmse:4.75046#011validation-rmse:6.8655
# [88]#011train-rmse:4.74981#011validation-rmse:6.86571
# [89]#011train-rmse:4.74873#011validation-rmse:6.86547
# [90]#011train-rmse:4.74808#011validation-rmse:6.86448
# [91]#011train-rmse:4.74681#011validation-rmse:6.86481
# [92]#011train-rmse:4.74581#011validation-rmse:6.86363
# [93]#011train-rmse:4.74495#011validation-rmse:6.86326
# [94]#011train-rmse:4.74391#011validation-rmse:6.86271
# [95]#011train-rmse:4.74167#011validation-rmse:6.86208
# [96]#011train-rmse:4.73998#011validation-rmse:6.86031
# [97]#011train-rmse:4.73851#011validation-rmse:6.85935
# [98]#011train-rmse:4.73771#011validation-rmse:6.8589
# [99]#011train-rmse:4.73731#011validation-rmse:6.85901
# [100]#011train-rmse:4.73564#011validation-rmse:6.85842
# [101]#011train-rmse:4.72828#011validation-rmse:6.85388
# [102]#011train-rmse:4.72673#011validation-rmse:6.85242
# [103]#011train-rmse:4.72356#011validation-rmse:6.85014
# [104]#011train-rmse:4.72279#011validation-rmse:6.84977
# [105]#011train-rmse:4.72202#011validation-rmse:6.84981
# [106]#011train-rmse:4.7156#011validation-rmse:6.84608
# [107]#011train-rmse:4.71352#011validation-rmse:6.84443
# [108]#011train-rmse:4.71112#011validation-rmse:6.84322
# [109]#011train-rmse:4.71043#011validation-rmse:6.84314
# [110]#011train-rmse:4.70929#011validation-rmse:6.84192
# [111]#011train-rmse:4.70733#011validation-rmse:6.84063
# [112]#011train-rmse:4.70541#011validation-rmse:6.84041
# [113]#011train-rmse:4.70431#011validation-rmse:6.83961
# [114]#011train-rmse:4.70341#011validation-rmse:6.8392
# [115]#011train-rmse:4.70221#011validation-rmse:6.83826
# [116]#011train-rmse:4.70132#011validation-rmse:6.83844
# [117]#011train-rmse:4.70003#011validation-rmse:6.83706
# [118]#011train-rmse:4.69926#011validation-rmse:6.83642
# [119]#011train-rmse:4.69845#011validation-rmse:6.8357
# [120]#011train-rmse:4.69765#011validation-rmse:6.83547
# [121]#011train-rmse:4.69695#011validation-rmse:6.83481
# [122]#011train-rmse:4.69641#011validation-rmse:6.83427
# [123]#011train-rmse:4.6954#011validation-rmse:6.83369
# [124]#011train-rmse:4.69346#011validation-rmse:6.83331
# [125]#011train-rmse:4.69082#011validation-rmse:6.83168
# [126]#011train-rmse:4.68983#011validation-rmse:6.83154
# [127]#011train-rmse:4.68868#011validation-rmse:6.83057
# [128]#011train-rmse:4.68749#011validation-rmse:6.83009
# [129]#011train-rmse:4.68689#011validation-rmse:6.83004
# [130]#011train-rmse:4.68523#011validation-rmse:6.8297
# [131]#011train-rmse:4.6836#011validation-rmse:6.82946
# [132]#011train-rmse:4.68243#011validation-rmse:6.82862
# [133]#011train-rmse:4.68198#011validation-rmse:6.82857
# [134]#011train-rmse:4.68077#011validation-rmse:6.82819
# [135]#011train-rmse:4.6801#011validation-rmse:6.82843
# [136]#011train-rmse:4.67594#011validation-rmse:6.82575
# [137]#011train-rmse:4.67525#011validation-rmse:6.82575
# [138]#011train-rmse:4.6737#011validation-rmse:6.82526
# [139]#011train-rmse:4.67207#011validation-rmse:6.82449
# [140]#011train-rmse:4.66796#011validation-rmse:6.82169
# [141]#011train-rmse:4.66676#011validation-rmse:6.8212
# [142]#011train-rmse:4.66551#011validation-rmse:6.82055
# [143]#011train-rmse:4.66476#011validation-rmse:6.82049
# [144]#011train-rmse:4.66266#011validation-rmse:6.81996
# [145]#011train-rmse:4.66211#011validation-rmse:6.81958
# [146]#011train-rmse:4.66121#011validation-rmse:6.81899
# [147]#011train-rmse:4.66037#011validation-rmse:6.81913
# [148]#011train-rmse:4.65968#011validation-rmse:6.81895
# [149]#011train-rmse:4.65815#011validation-rmse:6.81871
# [150]#011train-rmse:4.65733#011validation-rmse:6.8186
# [151]#011train-rmse:4.65684#011validation-rmse:6.81856
# [152]#011train-rmse:4.65556#011validation-rmse:6.81794
# [153]#011train-rmse:4.6554#011validation-rmse:6.81777
# [154]#011train-rmse:4.65395#011validation-rmse:6.8171
# [155]#011train-rmse:4.65348#011validation-rmse:6.81688
# [156]#011train-rmse:4.65209#011validation-rmse:6.81631
# [157]#011train-rmse:4.65117#011validation-rmse:6.81595
# [158]#011train-rmse:4.65037#011validation-rmse:6.81609
# [159]#011train-rmse:4.64963#011validation-rmse:6.81629
# [160]#011train-rmse:4.64698#011validation-rmse:6.81401
# [161]#011train-rmse:4.64615#011validation-rmse:6.81414
# [162]#011train-rmse:4.6457#011validation-rmse:6.81403
# [163]#011train-rmse:4.64472#011validation-rmse:6.81359
# [164]#011train-rmse:4.64438#011validation-rmse:6.81338
# [165]#011train-rmse:4.64419#011validation-rmse:6.81325
# [166]#011train-rmse:4.64282#011validation-rmse:6.81302
# [167]#011train-rmse:4.64179#011validation-rmse:6.81322
# [168]#011train-rmse:4.64033#011validation-rmse:6.81318
# [169]#011train-rmse:4.63971#011validation-rmse:6.81288
# [170]#011train-rmse:4.63943#011validation-rmse:6.81249
# [171]#011train-rmse:4.63885#011validation-rmse:6.81149
# [172]#011train-rmse:4.63835#011validation-rmse:6.81142
# [173]#011train-rmse:4.63765#011validation-rmse:6.81104
# [174]#011train-rmse:4.6368#011validation-rmse:6.81088
# [175]#011train-rmse:4.63615#011validation-rmse:6.81078
# [176]#011train-rmse:4.63522#011validation-rmse:6.8105
# [177]#011train-rmse:4.6346#011validation-rmse:6.81045
# [178]#011train-rmse:4.63414#011validation-rmse:6.81045
# [179]#011train-rmse:4.63198#011validation-rmse:6.80901
# [180]#011train-rmse:4.63125#011validation-rmse:6.80856
# [181]#011train-rmse:4.63024#011validation-rmse:6.80869
# [182]#011train-rmse:4.6297#011validation-rmse:6.80853
# [183]#011train-rmse:4.62871#011validation-rmse:6.80739
# [184]#011train-rmse:4.62788#011validation-rmse:6.80648
# [185]#011train-rmse:4.6273#011validation-rmse:6.80673
# [186]#011train-rmse:4.62617#011validation-rmse:6.80702
# [187]#011train-rmse:4.62483#011validation-rmse:6.80608
# [188]#011train-rmse:4.62454#011validation-rmse:6.80597
# [189]#011train-rmse:4.62346#011validation-rmse:6.80626
# [190]#011train-rmse:4.62317#011validation-rmse:6.80583
# [191]#011train-rmse:4.62246#011validation-rmse:6.80586
# [192]#011train-rmse:4.62181#011validation-rmse:6.80593
# [193]#011train-rmse:4.62065#011validation-rmse:6.80586
# [194]#011train-rmse:4.61957#011validation-rmse:6.80558
# [195]#011train-rmse:4.61886#011validation-rmse:6.80501
# [196]#011train-rmse:4.61839#011validation-rmse:6.80466
# [197]#011train-rmse:4.61775#011validation-rmse:6.80454
# [198]#011train-rmse:4.61718#011validation-rmse:6.8046
# [199]#011train-rmse:4.61636#011validation-rmse:6.8043
# [200]#011train-rmse:4.61618#011validation-rmse:6.80421
# [201]#011train-rmse:4.61593#011validation-rmse:6.80391
# [202]#011train-rmse:4.61516#011validation-rmse:6.80436
# [203]#011train-rmse:4.61481#011validation-rmse:6.80431
# [204]#011train-rmse:4.61415#011validation-rmse:6.80434
# [205]#011train-rmse:4.61358#011validation-rmse:6.80446
# [206]#011train-rmse:4.6134#011validation-rmse:6.80435
# [207]#011train-rmse:4.61254#011validation-rmse:6.80399
# [208]#011train-rmse:4.61167#011validation-rmse:6.80412
# [209]#011train-rmse:4.61145#011validation-rmse:6.8039
# [210]#011train-rmse:4.61111#011validation-rmse:6.80389
# [211]#011train-rmse:4.61007#011validation-rmse:6.80337
# [212]#011train-rmse:4.6088#011validation-rmse:6.80284
# [213]#011train-rmse:4.60848#011validation-rmse:6.80266
# [214]#011train-rmse:4.6049#011validation-rmse:6.80005
# [215]#011train-rmse:4.60444#011validation-rmse:6.79997
# [216]#011train-rmse:4.60407#011validation-rmse:6.79952
# [217]#011train-rmse:4.60358#011validation-rmse:6.79958
# [218]#011train-rmse:4.60334#011validation-rmse:6.79947
# [219]#011train-rmse:4.60311#011validation-rmse:6.79934
# [220]#011train-rmse:4.60285#011validation-rmse:6.79919
# [221]#011train-rmse:4.60271#011validation-rmse:6.79893
# [222]#011train-rmse:4.60094#011validation-rmse:6.79788
# [223]#011train-rmse:4.60059#011validation-rmse:6.79793
# [224]#011train-rmse:4.59979#011validation-rmse:6.79803
# [225]#011train-rmse:4.59927#011validation-rmse:6.79773
# [226]#011train-rmse:4.59866#011validation-rmse:6.79715
# [227]#011train-rmse:4.59796#011validation-rmse:6.79639
# [228]#011train-rmse:4.5964#011validation-rmse:6.79581
# [229]#011train-rmse:4.59517#011validation-rmse:6.7957
# [230]#011train-rmse:4.59469#011validation-rmse:6.79577
# [231]#011train-rmse:4.59424#011validation-rmse:6.79581
# [232]#011train-rmse:4.59393#011validation-rmse:6.79587
# [233]#011train-rmse:4.59316#011validation-rmse:6.79567
# [234]#011train-rmse:4.59273#011validation-rmse:6.7961
# [235]#011train-rmse:4.59215#011validation-rmse:6.79556
# [236]#011train-rmse:4.59135#011validation-rmse:6.79526
# [237]#011train-rmse:4.59#011validation-rmse:6.79426
# [238]#011train-rmse:4.58885#011validation-rmse:6.79385
# [239]#011train-rmse:4.58822#011validation-rmse:6.79362
# [240]#011train-rmse:4.58781#011validation-rmse:6.79367
# [241]#011train-rmse:4.58722#011validation-rmse:6.79392
# [242]#011train-rmse:4.58712#011validation-rmse:6.79413
# [243]#011train-rmse:4.58635#011validation-rmse:6.79358
# [244]#011train-rmse:4.5855#011validation-rmse:6.79327
# [245]#011train-rmse:4.585#011validation-rmse:6.79305
# [246]#011train-rmse:4.5848#011validation-rmse:6.79339
# [247]#011train-rmse:4.58047#011validation-rmse:6.79089
# [248]#011train-rmse:4.57963#011validation-rmse:6.79073
# [249]#011train-rmse:4.57927#011validation-rmse:6.7906
# [250]#011train-rmse:4.57835#011validation-rmse:6.78998
# [251]#011train-rmse:4.57792#011validation-rmse:6.79013
# [252]#011train-rmse:4.57764#011validation-rmse:6.78993
# [253]#011train-rmse:4.57671#011validation-rmse:6.78986
# [254]#011train-rmse:4.5761#011validation-rmse:6.78999
# [255]#011train-rmse:4.57551#011validation-rmse:6.78954
# [256]#011train-rmse:4.57468#011validation-rmse:6.78899
# [257]#011train-rmse:4.57395#011validation-rmse:6.78861
# [258]#011train-rmse:4.57367#011validation-rmse:6.78852
# [259]#011train-rmse:4.57299#011validation-rmse:6.78803
# [260]#011train-rmse:4.57233#011validation-rmse:6.78812
# [261]#011train-rmse:4.57192#011validation-rmse:6.78805
# [262]#011train-rmse:4.57153#011validation-rmse:6.78761
# [263]#011train-rmse:4.57092#011validation-rmse:6.78735
# [264]#011train-rmse:4.57036#011validation-rmse:6.78697
# [265]#011train-rmse:4.56982#011validation-rmse:6.78691
# [266]#011train-rmse:4.56935#011validation-rmse:6.78676
# [267]#011train-rmse:4.56905#011validation-rmse:6.78654
# [268]#011train-rmse:4.56859#011validation-rmse:6.78654
# [269]#011train-rmse:4.56818#011validation-rmse:6.78628
# [270]#011train-rmse:4.56773#011validation-rmse:6.78615
# [271]#011train-rmse:4.56734#011validation-rmse:6.78634
# [272]#011train-rmse:4.56621#011validation-rmse:6.78551
# [273]#011train-rmse:4.5659#011validation-rmse:6.78558
# [274]#011train-rmse:4.56535#011validation-rmse:6.78549
# [275]#011train-rmse:4.56492#011validation-rmse:6.78534
# [276]#011train-rmse:4.56443#011validation-rmse:6.78533
# [277]#011train-rmse:4.56374#011validation-rmse:6.78508
# [278]#011train-rmse:4.56261#011validation-rmse:6.78432
# [279]#011train-rmse:4.56227#011validation-rmse:6.78446
# [280]#011train-rmse:4.56171#011validation-rmse:6.78473
# [281]#011train-rmse:4.56137#011validation-rmse:6.78497
# [282]#011train-rmse:4.5612#011validation-rmse:6.78477
# [283]#011train-rmse:4.55841#011validation-rmse:6.78302
# [284]#011train-rmse:4.55785#011validation-rmse:6.78299
# [285]#011train-rmse:4.55647#011validation-rmse:6.78229
# [286]#011train-rmse:4.55623#011validation-rmse:6.78169
# [287]#011train-rmse:4.55579#011validation-rmse:6.78173
# [288]#011train-rmse:4.55487#011validation-rmse:6.78134
# [289]#011train-rmse:4.5543#011validation-rmse:6.78175
# [290]#011train-rmse:4.5538#011validation-rmse:6.78131
# [291]#011train-rmse:4.55287#011validation-rmse:6.78078
# [292]#011train-rmse:4.55222#011validation-rmse:6.78126
# [293]#011train-rmse:4.55145#011validation-rmse:6.78033
# [294]#011train-rmse:4.55085#011validation-rmse:6.78
# [295]#011train-rmse:4.55077#011validation-rmse:6.77996
# [296]#011train-rmse:4.55033#011validation-rmse:6.78009
# [297]#011train-rmse:4.55006#011validation-rmse:6.7803
# [298]#011train-rmse:4.54956#011validation-rmse:6.78045
# [299]#011train-rmse:4.54934#011validation-rmse:6.78046
# [300]#011train-rmse:4.54903#011validation-rmse:6.78017
# [301]#011train-rmse:4.54846#011validation-rmse:6.78035
# [302]#011train-rmse:4.54801#011validation-rmse:6.7804
# [303]#011train-rmse:4.54771#011validation-rmse:6.78059
# [304]#011train-rmse:4.5474#011validation-rmse:6.7807
# [305]#011train-rmse:4.54685#011validation-rmse:6.78002
#
# 2020-06-07 14:46:54 Uploading - Uploading generated training model
# 2020-06-07 14:46:54 Completed - Training job completed
# Training seconds: 10753
# Billable seconds: 10753

# %%
xgboost_estimator.latest_training_job.rule_job_summary()
# Out:
# [{'RuleConfigurationName': 'LossNotDecreasing',
#   'RuleEvaluationJobArn': 'arn:aws:sagemaker:eu-west-1:282784146513:processing-job/sagemaker-xgboost-2020-06--lossnotdecreasing-775e84c9',
#   'RuleEvaluationStatus': 'IssuesFound',
#   'StatusDetails': 'RuleEvaluationConditionMet: Evaluation of the rule LossNotDecreasing at step 80 resulted in the condition being met\n',
#   'LastModifiedTime': datetime.datetime(2020, 6, 7, 12, 15, 57, 5000, tzinfo=tzlocal())}]

# %%
s3_output_path = xgboost_estimator.latest_job_debugger_artifacts_path()
trial = create_trial(s3_output_path)
# Out:
# [2020-06-07 15:00:55.230 ip-172-16-77-40:31218 INFO s3_trial.py:42] Loading trial debug-output at path s3://aws-worskhop-data/training_jobs/2020-06-07-07-50-43/output/sagemaker-xgboost-2020-06-07-11-45-25-115/debug-output

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import re


def get_data(trial, tname):
    """
    For the given tensor name, walks though all the iterations
    for which you have data and fetches the values.
    Returns the set of steps and the values.
    """
    tensor = trial.tensor(tname)
    steps = tensor.steps()
    vals = [tensor.value(s) for s in steps]
    return steps, vals

def plot_collection(trial, collection_name, regex='.*', figsize=(8, 6)):
    """
    Takes a `trial` and a collection name, and 
    plots all tensors that match the given regex.
    """
    fig, ax = plt.subplots(figsize=figsize)
    sns.despine()

    tensors = trial.collection(collection_name).tensor_names

    for tensor_name in sorted(tensors):
        if re.match(regex, tensor_name):
            steps, data = get_data(trial, tensor_name)
            ax.plot(steps, data, label=tensor_name)

    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    ax.set_xlabel('Iteration')

# %%
plot_collection(trial, "metrics")
# Out:
# [2020-06-07 15:00:59.752 ip-172-16-77-40:31218 INFO trial.py:198] Training has ended, will refresh one final time in 1 sec.
# [2020-06-07 15:01:00.771 ip-172-16-77-40:31218 INFO trial.py:210] Loaded all steps

# %%
def plot_feature_importance(trial, importance_type="weight"):
    SUPPORTED_IMPORTANCE_TYPES = ["weight", "gain", "cover", "total_gain", "total_cover"]
    if importance_type not in SUPPORTED_IMPORTANCE_TYPES:
        raise ValueError(f"{importance_type} is not one of the supported importance types.")
    plot_collection(
        trial,
        "feature_importance",
        regex=f"feature_importance/{importance_type}/.*")

# %%
plot_feature_importance(trial)

# %%
plot_feature_importance(trial, importance_type="cover")

# %%
plot_collection(trial,"average_shap")

# %%
feature_names = list(df_small.columns[1:])

# %%
shap_values = trial.tensor("full_shap/f0").value(trial.last_complete_step)
shap_no_base = shap_values[:, :-1]
shap_base_value = shap_values[0, -1]
shap.summary_plot(shap_no_base, plot_type='bar', feature_names=feature_names)

# %% [markdown]
# ## Deploy the model

# %%
xgb_predictor = xgboost_estimator.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# -------------!

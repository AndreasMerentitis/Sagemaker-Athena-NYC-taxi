# %% [markdown]
# # Building Taxi Fare Prediction using SageMaker

# %% [markdown]
# <p>This demo notebook guides through the steps in creating an AWS Sagemaker predictions service</p>
# <p>To start using Sagemaker go here: <a href="https://aws.amazon.com/sagemaker/">Sagemaker</a></p>

# %%
# !pip install shap
# !pip install smdebug
# Out:
# Requirement already satisfied: shap in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (0.35.0)
# Requirement already satisfied: scikit-learn in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from shap) (0.22.1)
# Requirement already satisfied: tqdm>4.25.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from shap) (4.46.1)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from shap) (0.24.2)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from shap) (1.4.1)
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from shap) (1.16.4)
# Requirement already satisfied: joblib>=0.11 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from scikit-learn->shap) (0.14.1)
# Requirement already satisfied: python-dateutil>=2.5.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from pandas->shap) (2.7.3)
# Requirement already satisfied: pytz>=2011k in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from pandas->shap) (2018.4)
# Requirement already satisfied: six>=1.5 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas->shap) (1.11.0)
# WARNING: You are using pip version 19.3.1; however, version 20.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
# Requirement already satisfied: smdebug in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (0.8.1)
# Requirement already satisfied: boto3>=1.10.32 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from smdebug) (1.12.39)
# Requirement already satisfied: protobuf>=3.6.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from smdebug) (3.8.0)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from smdebug) (1.16.4)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from smdebug) (20.1)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from boto3>=1.10.32->smdebug) (0.9.4)
# Requirement already satisfied: botocore<1.16.0,>=1.15.39 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from boto3>=1.10.32->smdebug) (1.15.39)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from boto3>=1.10.32->smdebug) (0.3.3)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from protobuf>=3.6.0->smdebug) (1.11.0)
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from protobuf>=3.6.0->smdebug) (45.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from packaging->smdebug) (2.2.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from botocore<1.16.0,>=1.15.39->boto3>=1.10.32->smdebug) (2.7.3)
# Requirement already satisfied: urllib3<1.26,>=1.20; python_version != "3.4" in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from botocore<1.16.0,>=1.15.39->boto3>=1.10.32->smdebug) (1.23)
# Requirement already satisfied: docutils<0.16,>=0.10 in /home/ec2-user/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages (from botocore<1.16.0,>=1.15.39->boto3>=1.10.32->smdebug) (0.14)
# WARNING: You are using pip version 19.3.1; however, version 20.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import pandas as pd
import os
from s3fs.core import S3FileSystem
import random

import shap

import boto3
from botocore.client import Config
import json

# %%
from sagemaker import get_execution_role

role = get_execution_role()
print(role)
# Out:
# arn:aws:iam::282784146513:role/service-role/AmazonSageMaker-ExecutionRole-20190604T113688

# %%
def load_model(fname):
    model = xgb.XGBClassifier()
    model.load_model(fname)
    with open(fname.replace('.xgboost', '.json'), encoding='utf-8') as fin:
        params = json.load(fin)
    model.set_params(**params)
    return model

# %% [markdown]
# ## Read the whole data from S3

# %%
S3FileSystem.read_timeout = 3600

# %%
s3 = S3FileSystem(anon=False)
bucket = 'aws-worskhop-data/ZIPCHUNKS'
file_list = s3.ls(bucket)
subs = 'ZIPCHUNKS'
res = [i for i in file_list if subs in i]

# %%
# we remove the folder ZIPCHUNKS if it exists (so later we can merge the files in loop)
if 'aws-worskhop-data/ZIPCHUNKS' in res: res.remove('aws-worskhop-data/ZIPCHUNKS')

# %%
res
# Out:
# ['aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaa',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSab',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSac',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSad',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSae',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaf',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSag',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSah',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSai',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaj',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSak',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSal',
#  'aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSam']

# %%
jj = 0

for filechunk in res:
        print (filechunk)
        if jj == 0:
            with s3.open('aws-worskhop-data/taxinyc_train.csv.zip', 'wb') as f:
                f.write(s3.cat(filechunk))
                jj = jj + 1        
                f.close()
        else:
            with s3.open('aws-worskhop-data/taxinyc_train.csv.zip', 'ab') as f:
                f.write(s3.cat(filechunk))
                jj = jj + 1
                f.close()
# Out:
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaa
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSab
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSac
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSad
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSae
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaf
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSag
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSah
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSai
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSaj
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSak
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSal
# aws-worskhop-data/ZIPCHUNKS/ZIPCHUNKSam

# %%
bucket = 'aws-worskhop-data'
path = ''

filename = 'taxinyc_train.csv.zip'
s3_path = os.path.join('s3://', bucket, path, filename)

df_all = pd.read_csv(s3_path, header=0, skiprows=lambda i: i>0 and random.random() > 0.01)

# %%
df_all
# Out:
#         fare_amount  day  dayofweek  year  month  dayofmonth  hour  minute  \
# 0             15.70   28          4  2011      7          28    10      47
# 1             10.00   20          5  2013     12          20     7      55
# 2              5.70   16          4  2010     12          16     4      46
# 3             20.50   29          7  2009      3          29     8      30
# 4             10.50   10          3  2014     12          10    14      23
# 5              4.50    5          7  2014     10           5    12       9
# 6              6.10   24          4  2011      3          24     3      27
# 7             30.50   22          2  2009     12          22    18      24
# 8             18.10   14          6  2009     11          14    18      50
# 9             11.30   18          3  2011      5          18    19       0
# 10             6.10    7          2  2012      2           7    16       6
# 11             8.10   17          4  2010      6          17     3      35
# 12            13.50   20          4  2012     12          20    14      53
# 13             6.50   28          4  2015      5          28    22      13
# 14             4.90    3          5  2012      2           3     2      11
# 15             5.30   10          1  2011      1          10    16      12
# 16             7.50   18          2  2014      2          18     6      59
# 17             2.50   14          7  2012     10          14     7      32
# 18            52.00    3          4  2014      7           3    14      34
# 19             8.10   28          6  2009      3          28    16       5
# 20             8.00   11          4  2013      4          11    19       5
# 21            33.07   29          2  2010      6          29    14      13
# 22            13.50   26          4  2015      2          26    13      54
# 23             6.50   17          3  2010      3          17    17      56
# 24             5.90   19          4  2009      2          19    13      41
# 25             6.50   31          1  2011     10          31    13      31
# 26             6.50   21          6  2009      2          21    18       5
# 27            12.50   17          1  2014      2          17     4      47
# 28            11.70   15          2  2012      5          15    18      57
# 29            23.00   26          4  2015      2          26    14      53
# ...             ...  ...        ...   ...    ...         ...   ...     ...
# 554048         6.10    6          6  2011      8           6    22       7
# 554049         6.10    3          2  2009      2           3     9      52
# 554050        18.00   16          4  2015      4          16    21       9
# 554051         3.80   15          7  2009      3          15    17      50
# 554052         7.00   21          1  2014      7          21     4      54
# 554053        14.50   16          4  2011      6          16     3      58
# 554054        11.70   12          6  2009      9          12    18      10
# 554055         7.30    8          7  2012      1           8     3      55
# 554056        10.90   18          6  2010      9          18     7      12
# 554057         6.50   21          2  2013      5          21     2      21
# 554058        13.70    8          4  2010      7           8    10      25
# 554059         8.90   30          4  2012      8          30    21      47
# 554060         5.30   14          3  2010      7          14     9       4
# 554061         9.00   31          4  2013     10          31     9      33
# 554062        10.10   10          4  2011     11          10    18      11
# 554063         4.50   29          6  2010      5          29    19      54
# 554064         6.00   29          5  2015      5          29    14      42
# 554065        17.30   12          4  2011      5          12    20      32
# 554066        17.30   28          6  2009      3          28    18      51
# 554067         4.50    3          1  2012      9           3    12      29
# 554068         9.70   19          4  2010      8          19     3      53
# 554069         3.70   18          5  2009     12          18     3      47
# 554070        72.83   23          2  2013      7          23     4       0
# 554071        14.50    1          1  2015      6           1    22      44
# 554072         6.00   15          2  2013     10          15    13      25
# 554073         9.70   28          3  2009      1          28    18      41
# 554074         2.90    7          7  2009      6           7     5      17
# 554075         8.50    7          7  2014     12           7    13      35
# 554076         4.90   29          6  2011      1          29     5      18
# 554077         8.50   11          2  2014      2          11     9      35
#
#          sin_day   cos_day  sin_week  cos_week          pickup_datetime  \
# 0      -0.665882 -0.746057  0.525153  0.851008  2011-07-28 14:47:00 UTC
# 1      -0.237686 -0.971342  0.981982  0.188973  2013-12-20 12:55:00 UTC
# 2       0.548476 -0.836167  0.357757  0.933815  2010-12-16 09:46:57 UTC
# 3      -0.131536 -0.991311 -0.018844 -0.999822  2009-03-29 12:30:14 UTC
# 4      -0.935135  0.354291 -0.171806  0.985131  2014-12-10 19:23:00 UTC
# 5      -0.885495 -0.464649 -0.154741 -0.987955  2014-10-05 16:09:15 UTC
# 6       0.928810 -0.370557  0.275038  0.961433  2011-03-24 07:27:00 UTC
# 7      -0.156434  0.987688 -0.795625  0.605790  2009-12-22 23:24:00 UTC
# 8      -0.040931  0.999162  0.439146 -0.898416  2009-11-14 23:50:37 UTC
# 9      -0.258819  0.965926 -0.037391  0.999301  2011-05-18 23:00:00 UTC
# 10     -0.685236  0.728321 -0.844400  0.535713  2012-02-07 21:06:59 UTC
# 11      0.914519 -0.404543  0.280098  0.959971  2010-06-17 07:35:27 UTC
# 12     -0.880891  0.473320  0.676968  0.736013  2012-12-20 19:53:00 UTC
# 13      0.550420  0.834888  0.830979  0.556304  2015-05-29 02:13:35 UTC
# 14      0.952240 -0.305349  0.919311  0.393531  2012-02-03 07:11:07 UTC
# 15     -0.669131  0.743145 -0.946327 -0.323210  2011-01-10 21:12:00 UTC
# 16      0.001382 -0.999999 -0.974972  0.222328  2014-02-18 11:59:41 UTC
# 17      0.121869 -0.992546  0.017452 -0.999848  2012-10-14 11:32:00 UTC
# 18     -0.989016  0.147809  0.639918  0.768443  2014-07-03 18:34:00 UTC
# 19     -0.854912  0.518773  0.560742 -0.827990  2009-03-28 20:05:00 UTC
# 20     -0.237686  0.971342  0.760001  0.649922  2013-04-11 23:05:00 UTC
# 21     -0.998392  0.056693 -0.897423  0.441170  2010-06-29 18:13:00 UTC
# 22     -0.972336  0.233587  0.649464  0.760392  2015-02-26 18:54:02 UTC
# 23     -0.512293  0.858811 -0.076760  0.997050  2010-03-17 21:56:44 UTC
# 24     -0.983361  0.181663  0.643679  0.765296  2009-02-19 18:41:52 UTC
# 25     -0.992042 -0.125910 -0.892998 -0.450061  2011-10-31 17:31:04 UTC
# 26     -0.237686  0.971342  0.464511 -0.885567  2009-02-21 23:05:00 UTC
# 27      0.548293 -0.836286 -0.727516 -0.686090  2014-02-17 09:47:00 UTC
# 28     -0.271300  0.962495 -0.805695  0.592331  2012-05-15 22:57:02 UTC
# 29     -0.880891  0.473320  0.676968  0.736013  2015-02-26 19:53:00 UTC
# ...          ...       ...       ...       ...                      ...
# 554048  0.526585  0.850123  0.361218 -0.932482  2011-08-07 02:07:06 UTC
# 554049 -0.683486 -0.729963 -0.945424  0.325843  2009-02-03 14:52:28 UTC
# 554050  0.297791  0.954631  0.808027  0.589146  2015-04-17 01:09:18 UTC
# 554051 -0.535090  0.844795 -0.359880 -0.932998  2009-03-15 21:50:36 UTC
# 554052  0.724122 -0.689672 -0.704642 -0.709563  2014-07-21 08:54:25 UTC
# 554053  0.870356 -0.492424  0.293564  0.955940  2011-06-16 07:58:00 UTC
# 554054 -0.458197  0.888851  0.494095 -0.869408  2009-09-12 22:10:55 UTC
# 554055  0.722364 -0.691513  0.115061 -0.993358  2012-01-08 08:55:00 UTC
# 554056  0.207912 -0.978148  0.800134 -0.599822  2010-09-18 11:12:00 UTC
# 554057  0.995738 -0.092226 -0.999913  0.013193  2013-05-21 06:21:10 UTC
# 554058 -0.591427 -0.806359  0.513452  0.858118  2010-07-08 14:25:02 UTC
# 554059  0.452305  0.891863  0.821848  0.569707  2012-08-31 01:47:34 UTC
# 554060 -0.277943 -0.960597 -0.397291  0.917693  2010-07-14 13:04:33 UTC
# 554061 -0.397949 -0.917408  0.485791  0.874075  2013-10-31 13:33:48 UTC
# 554062 -0.212178  0.977231  0.762426  0.647075  2011-11-10 23:11:00 UTC
# 554063 -0.026177  0.999657  0.437250 -0.899340  2010-05-29 23:54:00 UTC
# 554064 -0.982868  0.184309  0.999649 -0.026478  2015-05-29 18:42:29 UTC
# 554065  0.139173  0.990268  0.794112  0.607772  2011-05-13 00:32:00 UTC
# 554066 -0.296542  0.955020  0.472221 -0.881480  2009-03-28 22:51:00 UTC
# 554067 -0.923378 -0.383892 -0.875133 -0.483883  2012-09-03 16:29:42 UTC
# 554068  0.880891 -0.473320  0.290583  0.956850  2010-08-19 07:53:00 UTC
# 554069  0.746057 -0.665882  0.941176  0.337917  2009-12-18 08:47:00 UTC
# 554070  0.866025 -0.500000 -0.997204  0.074730  2013-07-23 08:00:00 UTC
# 554071  0.659072  0.752080 -0.992616 -0.121302  2015-06-02 02:44:55 UTC
# 554072 -0.988843 -0.148960 -0.910030  0.414542  2013-10-15 17:25:44 UTC
# 554073 -0.082808  0.996566 -0.011843  0.999930  2009-01-28 23:41:00 UTC
# 554074  0.649614 -0.760264  0.100839 -0.994903  2009-06-07 09:17:57 UTC
# 554075 -0.987870  0.155285 -0.244179 -0.969730  2014-12-07 18:35:44 UTC
# 554076  0.428081 -0.903740  0.819646 -0.572870  2011-01-29 10:18:37 UTC
# 554077 -0.628925 -0.777466 -0.948741  0.316053  2014-02-11 14:35:53 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -74.000630        40.732170         -73.969190
# 1             -74.004740        40.741920         -73.990560
# 2             -74.001495        40.741184         -73.999916
# 3             -74.004290        40.705418         -73.985240
# 4             -73.975980        40.748530         -73.988785
# 5             -73.960900        40.772434         -73.966920
# 6             -73.961290        40.756542         -73.975815
# 7             -73.782030        40.644726         -73.918020
# 8             -73.983650        40.731766         -73.962500
# 9             -73.971886        40.761710         -73.970856
# 10              0.000000         0.000000           0.000000
# 11            -73.993260        40.734146         -73.974464
# 12            -73.993590        40.753803          -0.130000
# 13            -73.980050        40.765720         -73.964350
# 14            -73.981680        40.740746         -73.980270
# 15            -73.989075        40.742370         -73.987200
# 16            -73.982730        40.761707         -73.991530
# 17              0.000000         0.000000           0.000000
# 18            -73.790750        40.644043         -73.985970
# 19            -73.992775        40.749040         -73.987180
# 20            -73.992584        40.683533         -73.972534
# 21            -73.985490        40.738514         -73.871080
# 22            -73.973130        40.764477         -73.989850
# 23            -73.966830        40.757442         -73.982930
# 24            -73.992880        40.742928         -73.986595
# 25            -74.005590        40.739470         -74.008510
# 26            -73.977875        40.745000         -73.989020
# 27            -73.984825        40.746147         -73.972720
# 28            -73.871180        40.773770         -73.830925
# 29            -73.870860        40.773610         -73.949770
# ...                  ...              ...                ...
# 554048        -73.999200        40.723324         -73.989470
# 554049        -73.974020        40.750860         -73.972740
# 554050        -73.992420        40.743450         -73.924030
# 554051        -73.999176        40.728275         -73.997320
# 554052        -73.960014        40.776016         -73.973060
# 554053        -74.014260        40.704433         -73.975770
# 554054        -73.998290        40.726505         -73.996390
# 554055        -73.997700        40.765987         -73.978770
# 554056        -74.006770        40.744180         -73.954155
# 554057        -73.994320        40.746063         -73.981720
# 554058        -73.953850        40.790596         -73.988670
# 554059        -73.998180        40.717003         -74.003170
# 554060        -73.964800        40.767433         -73.979000
# 554061        -73.980280        40.742695         -73.995150
# 554062        -73.972470        40.753246         -73.986000
# 554063        -73.992280        40.737840         -73.990400
# 554064        -73.963240        40.771620         -73.953980
# 554065        -73.987360        40.733105         -73.959840
# 554066        -73.994100        40.751190         -73.945940
# 554067        -73.983140        40.763737         -73.990210
# 554068        -73.953940        40.790380         -73.978060
# 554069        -73.993850        40.751842         -73.989090
# 554070        -73.782160        40.645008         -73.885430
# 554071        -73.985420        40.753147         -73.925064
# 554072        -73.975250        40.788230         -73.971120
# 554073        -74.003000        40.728188         -73.988290
# 554074        -74.002580        40.728870         -74.001410
# 554075        -73.979935        40.758965         -73.983540
# 554076        -74.001210        40.756990         -73.992370
# 554077        -73.982160        40.772446         -73.975110
#
#         dropoff_latitude  passenger_count
# 0              40.791810                2
# 1              40.755990                4
# 2              40.753292                1
# 3              40.761833                4
# 4              40.731453                5
# 5              40.768290                2
# 6              40.754180                1
# 7              40.736940                1
# 8              40.678196                4
# 9              40.798100                2
# 10              0.000000                1
# 11             40.757202                1
# 12             40.761658                1
# 13             40.763040                1
# 14             40.753384                1
# 15             40.730114                5
# 16             40.749570                1
# 17              0.000000                1
# 18             40.760570                2
# 19             40.736458                3
# 20             40.691647                1
# 21             40.774265                2
# 22             40.751377                1
# 23             40.757057                1
# 24             40.748020                1
# 25             40.719020                1
# 26             40.730705                5
# 27             40.780632                1
# 28             40.760757                1
# 29             40.727250                2
# ...                  ...              ...
# 554048         40.729362                1
# 554049         40.736650                1
# 554050         40.758190                3
# 554051         40.724490                1
# 554052         40.764320                1
# 554053         40.751686                2
# 554054         40.767014                1
# 554055         40.752853                1
# 554056         40.655163                1
# 554057         40.760902                1
# 554058         40.754180                1
# 554059         40.748993                1
# 554060         40.772310                1
# 554061         40.744953                1
# 554062         40.722683                1
# 554063         40.729797                1
# 554064         40.776657                1
# 554065         40.808350                1
# 554066         40.775390                5
# 554067         40.751698                1
# 554068         40.758213                1
# 554069         40.758667                1
# 554070         40.858208                1
# 554071         40.761734                1
# 554072         40.799236                1
# 554073         40.761593                2
# 554074         40.730957                1
# 554075         40.761750                1
# 554076         40.755250                1
# 554077         40.760014                1
#
# [554078 rows x 18 columns]

# %% [markdown]
# ## Start Exploring the data

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-whitegrid')
# %matplotlib inline

# %%
# Sample the data - because it only take a 100K records to feel the data
df_all = df_all.sample(int(1e5))

# %%
df_small = df_all.sample(int(1e2))
df_small
# Out:
#         fare_amount  day  dayofweek  year  month  dayofmonth  hour  minute  \
# 364552        16.90    3          6  2011     12           3    20      10
# 506703        16.10    4          6  2010      9           4    10       0
# 193804         8.00    2          2  2014     12           2    16      10
# 549130        17.50   11          3  2015      3          11    13      23
# 419047         6.00    6          4  2013      6           6    19      45
# 294560         6.50   26          3  2011      1          26     4      30
# 378452        14.50    9          2  2014     12           9    12       7
# 539244        12.50   23          3  2012      5          23    13      51
# 416140         7.00    8          2  2013      1           8    12      49
# 333299         4.90    3          6  2011      9           3    19      26
# 177375         6.50   31          1  2009      8          31    14       2
# 396            5.00    5          4  2015      2           5     4      21
# 269526         7.50   25          2  2014      3          25     9      48
# 74210          7.50   14          2  2014     10          14    22      37
# 64728         12.50   27          6  2010      2          27    17      23
# 16604          8.90   17          6  2010      7          17    15       3
# 242387         8.50   21          2  2010     12          21    18      40
# 178508        11.30   14          2  2012      2          14     7      59
# 428190         4.50   13          4  2011      1          13    14      14
# 7295          14.50   30          4  2013      5          30    15      50
# 374516        12.50   18          5  2014      4          18    15      18
# 542054         4.50   18          3  2015      3          18     5      21
# 363030         5.70   14          6  2009      2          14    14      41
# 15078         14.00   13          2  2014      5          13    15      55
# 131314        17.50   14          4  2015      5          14    21      10
# 274775        10.50    9          5  2012      3           9    13      38
# 387057         6.50   24          7  2012      6          24     8      25
# 351005        14.50   16          2  2015      6          16     5      24
# 195176         7.00    6          1  2013      5           6    15      19
# 32357          8.90   21          5  2011     10          21    22      26
# ...             ...  ...        ...   ...    ...         ...   ...     ...
# 233077        23.30   23          7  2010      5          23     4      46
# 202024         5.70   13          2  2011      9          13     4      59
# 397052         6.00   19          4  2014      6          19     4      49
# 295206         6.00   14          5  2014      3          14     7      14
# 101775        11.30   12          4  2010      8          12    14       8
# 367744        10.90   28          5  2009      8          28     9      44
# 72729          7.00   31          4  2013      1          31    18       2
# 314429         4.50    1          6  2014     11           1    10      40
# 34472          4.50   18          3  2013      9          18    13      41
# 497993         5.30   21          4  2011      4          21    11      18
# 179563        50.33    9          7  2014      2           9     9      57
# 128466        15.00    9          6  2013      3           9    10      29
# 477234         6.00   22          5  2013      3          22     4      59
# 553025         5.50   15          6  2012      9          15     8      52
# 146421         5.00   31          3  2014     12          31    20      43
# 490711        11.00   30          7  2012      9          30    18      26
# 382322        11.50   30          3  2014      4          30     3      17
# 470706         5.00   19          7  2014      1          19    13      47
# 269005         3.70   30          5  2012      3          30    18      55
# 290281        11.70    9          6  2010      1           9     9      53
# 217138        16.50   11          7  2011     12          11     3      47
# 146265         4.50   24          3  2010     11          24    14      16
# 430940        19.70    7          2  2011      6           7    21       2
# 269792         6.90   16          5  2011     12          16     6      50
# 211082         8.50    3          7  2015      5           3    18       0
# 511032        10.50    3          3  2014     12           3    15      28
# 189303        16.50   14          1  2014      4          14    18       3
# 325768         8.50   27          5  2011      5          27    14      42
# 435326         4.50    9          5  2009      1           9    17       3
# 342612        18.00    6          4  2014      2           6    17      21
#
#          sin_day   cos_day  sin_week  cos_week          pickup_datetime  \
# 364552  0.303964  0.952684  0.393722 -0.919229  2011-12-04 01:10:47 UTC
# 506703 -0.500000 -0.866025  0.733052 -0.680173  2010-09-04 14:00:00 UTC
# 193804 -0.672582  0.740023 -0.843079  0.537790  2014-12-02 21:10:56 UTC
# 549130 -0.987597 -0.157009 -0.244421  0.969669  2015-03-11 17:23:52 UTC
# 419047 -0.065403  0.997859  0.775968  0.630773  2013-06-06 23:45:00 UTC
# 294560  0.608761 -0.793353 -0.516106  0.856525  2011-01-26 09:30:00 UTC
# 378452 -0.973379 -0.229200 -0.914809  0.403887  2014-12-09 17:07:00 UTC
# 539244 -0.999285 -0.037806 -0.227784  0.973712  2012-05-23 17:51:20 UTC
# 416140 -0.998934 -0.046162 -0.903812  0.427931  2013-01-08 17:49:25 UTC
# 333299 -0.147809  0.989016  0.452879 -0.891572  2011-09-03 23:26:00 UTC
# 177375 -0.999962  0.008727 -0.901509 -0.432760  2009-08-31 18:02:00 UTC
# 396     0.636583 -0.771208  0.343104  0.939298  2015-02-05 09:21:51 UTC
# 269526 -0.456257 -0.889848 -0.957646  0.287948  2014-03-25 13:48:35 UTC
# 74210   0.635405  0.772179 -0.716824  0.697254  2014-10-15 02:37:48 UTC
# 64728  -0.409326  0.912388  0.487343 -0.873211  2010-02-27 22:23:21 UTC
# 16604  -0.962455  0.271440  0.592315 -0.805707  2010-07-17 19:03:00 UTC
# 242387 -0.087156  0.996195 -0.789543  0.613695  2010-12-21 23:40:00 UTC
# 178508 -0.254602 -0.967046 -0.966087  0.258217  2012-02-14 12:59:00 UTC
# 428190 -0.947629  0.319373  0.659111  0.752045  2011-01-13 19:14:30 UTC
# 7295   -0.887011  0.461749  0.675590  0.737277  2013-05-30 19:50:00 UTC
# 374516 -0.942641  0.333807  0.998818 -0.048601  2014-04-18 19:18:00 UTC
# 542054  0.639383 -0.768888 -0.520894  0.853621  2015-03-18 09:21:01 UTC
# 363030 -0.902898  0.429855  0.572640 -0.819807  2009-02-14 19:41:50 UTC
# 15078  -0.874937  0.484237 -0.867316  0.497758  2014-05-13 19:55:51 UTC
# 131314  0.302439  0.953169  0.808436  0.588583  2015-05-15 01:10:25 UTC
# 274775 -0.986008  0.166697  0.999714 -0.023923  2012-03-09 18:38:23 UTC
# 387057 -0.109156 -0.994025 -0.015624 -0.999878  2012-06-24 12:25:04 UTC
# 351005  0.627567 -0.778563 -0.991885  0.127137  2015-06-16 09:24:31 UTC
# 195176 -0.940486  0.339832 -0.921347 -0.388741  2013-05-06 19:19:28 UTC
# 32357   0.596400  0.802687  0.950583 -0.310469  2011-10-22 02:26:27 UTC
# ...          ...       ...       ...       ...                      ...
# 233077  0.747025 -0.664796  0.120219 -0.992747  2010-05-23 08:46:40 UTC
# 202024  0.709724 -0.704479 -0.993771  0.111438  2011-09-13 08:59:09 UTC
# 397052  0.737818 -0.675000  0.324281  0.945961  2014-06-19 08:49:49 UTC
# 295206  0.199368 -0.979925  0.968148  0.250380  2014-03-14 11:14:00 UTC
# 101775 -0.999299  0.037443  0.627664  0.778484  2010-08-12 18:08:35 UTC
# 367744 -0.439221 -0.898379  0.987317  0.158763  2009-08-28 13:44:13 UTC
# 72729  -0.246929  0.969034  0.759116  0.650956  2013-01-31 23:02:49 UTC
# 314429 -0.643623 -0.765343  0.715758 -0.698348  2014-11-01 14:40:15 UTC
# 34472  -0.996814 -0.079764 -0.233627  0.972326  2013-09-18 17:41:42 UTC
# 497993 -0.761633 -0.648009  0.541726  0.840555  2011-04-21 15:18:26 UTC
# 179563 -0.700287 -0.713862 -0.110602 -0.993865  2014-02-09 14:57:48 UTC
# 128466 -0.791535 -0.611124  0.694068 -0.719910  2013-03-09 15:29:19 UTC
# 477234  0.708853 -0.705356  0.943767  0.330612  2013-03-22 08:59:26 UTC
# 553025 -0.224951 -0.974370  0.761215 -0.648500  2012-09-15 12:52:00 UTC
# 146421  0.437783  0.899081  0.064688  0.997906  2015-01-01 01:43:51 UTC
# 490711 -0.398749  0.917060 -0.380379 -0.924831  2012-09-30 22:26:00 UTC
# 382322  0.944089 -0.329691 -0.585261  0.810845  2014-04-30 07:17:00 UTC
# 470706 -0.979045  0.203642 -0.250983 -0.967991  2014-01-19 18:47:00 UTC
# 269005 -0.279829  0.960050  0.983141 -0.182848  2012-03-30 22:55:00 UTC
# 290281 -0.685183 -0.728371  0.710185 -0.704015  2010-01-09 14:53:00 UTC
# 217138  0.745670 -0.666316  0.119931 -0.992782  2011-12-11 08:47:08 UTC
# 146265 -0.945092  0.326806 -0.175919  0.984405  2010-11-24 19:16:18 UTC
# 430940  0.270180  0.962810 -0.756873  0.653562  2011-06-08 01:02:42 UTC
# 269792  0.040713 -0.999171  0.973617  0.228189  2011-12-16 11:50:40 UTC
# 211082 -0.498866  0.866679 -0.365515 -0.930805  2015-05-03 22:00:18 UTC
# 511032 -0.797672  0.603092 -0.131536  0.991311  2014-12-03 20:28:22 UTC
# 189303 -0.485191  0.874408 -0.956287 -0.292431  2014-04-14 22:03:54 UTC
# 325768 -0.983255  0.182236  0.999657 -0.026177  2011-05-27 18:42:00 UTC
# 435326 -0.488621  0.872496  0.988550 -0.150891  2009-01-09 22:03:00 UTC
# 342612 -0.418660  0.908143  0.741892  0.670519  2014-02-06 22:21:00 UTC
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 364552        -73.964080        40.709020         -73.957825
# 506703        -73.933395        40.795322         -73.987280
# 193804        -73.984890        40.742250         -73.983000
# 549130        -73.988910        40.757915         -73.951935
# 419047        -73.989990        40.732853         -73.999710
# 294560        -74.006740        40.730427         -74.004250
# 378452        -73.951990        40.766056         -73.975230
# 539244        -73.983820        40.755188         -73.988800
# 416140        -73.980970        40.744633         -73.982506
# 333299        -73.962560        40.710020         -73.957000
# 177375        -73.976130        40.744427         -73.997160
# 396           -74.012140        40.714150         -74.009920
# 269526        -73.996600        40.727080         -73.979080
# 74210         -73.987830        40.721035         -74.006330
# 64728         -74.005350        40.720040         -73.958570
# 16604         -73.995440        40.744183         -73.981380
# 242387        -73.976640        40.775350         -73.951520
# 178508        -74.000400        40.727337         -73.989716
# 428190        -74.007050        40.746456         -73.998620
# 7295          -73.953255        40.766890         -73.987274
# 374516          0.000000         0.000000           0.000000
# 542054        -73.992250        40.715200         -73.990970
# 363030        -73.994550        40.728527         -73.983864
# 15078         -73.963490        40.774574         -73.991860
# 131314        -73.989340        40.756900         -74.013670
# 274775        -73.990715        40.755272         -73.973210
# 387057        -73.981680        40.746540         -73.975960
# 351005        -73.993630        40.767050         -73.991890
# 195176        -74.006670        40.744780         -73.990010
# 32357         -74.002640        40.751095         -73.964800
# ...                  ...              ...                ...
# 233077        -73.948290        40.782257         -73.995990
# 202024        -73.992140        40.749508         -74.004684
# 397052        -73.967620        40.787903         -73.979220
# 295206        -73.977900        40.788727         -73.968110
# 101775        -74.001100        40.729267         -74.000590
# 367744        -74.001015        40.747110         -74.017450
# 72729         -73.988250        40.737640         -74.007860
# 314429        -73.983130        40.750763         -73.979750
# 34472         -73.970360        40.764626         -73.963080
# 497993        -73.976685        40.750565         -73.984740
# 179563        -74.016400        40.714775         -73.871124
# 128466        -73.995750        40.768238         -73.958725
# 477234        -74.004616        40.723700         -73.995450
# 553025        -73.980220        40.726210         -73.987290
# 146421        -73.995940        40.748640         -73.998590
# 490711        -73.970370        40.764935         -73.939260
# 382322        -73.985510        40.727337         -73.972420
# 470706        -73.975860        40.781376         -73.982300
# 269005        -73.974780        40.714466         -73.974780
# 290281        -73.977950        40.773600         -73.978940
# 217138        -73.984370        40.745052         -73.971504
# 146265        -73.951430        40.785282         -73.946610
# 430940        -73.982170        40.764835         -73.975350
# 269792        -73.977300        40.764200         -73.966700
# 211082        -73.993920        40.750630         -73.990470
# 511032        -73.985920        40.757458         -73.972534
# 189303        -73.966180        40.745758         -73.966180
# 325768          0.000000         0.000000           0.000000
# 435326        -73.980810        40.756824         -73.978700
# 342612        -73.972650        40.758960         -74.008630
#
#         dropoff_latitude  passenger_count
# 364552         40.774635                1
# 506703         40.759407                1
# 193804         40.725120                1
# 549130         40.808830                1
# 419047         40.730280                3
# 294560         40.740578                1
# 378452         40.755646                1
# 539244         40.724228                1
# 416140         40.724808                1
# 333299         40.718582                1
# 177375         40.741737                5
# 396            40.721073                3
# 269526         40.731240                1
# 74210          40.714233                1
# 64728          40.685310                2
# 16604          40.768190                1
# 242387         40.770077                1
# 178508         40.762627                4
# 428190         40.744938                1
# 7295           40.729187                5
# 374516          0.000000                1
# 542054         40.722282                1
# 363030         40.723858                1
# 15078          40.755320                3
# 131314         40.702290                1
# 274775         40.789970                1
# 387057         40.730537                1
# 351005         40.740505                1
# 195176         40.748300                1
# 32357          40.767925                1
# ...                  ...              ...
# 233077         40.685870                1
# 202024         40.742043                1
# 397052         40.777610                1
# 295206         40.799683                1
# 101775         40.742577                3
# 367744         40.710873                1
# 72729          40.738140                2
# 314429         40.752094                1
# 34472          40.775208                1
# 497993         40.750990                2
# 179563         40.774242                1
# 128466         40.783848                2
# 477234         40.727203                1
# 553025         40.727623                1
# 146421         40.756866                5
# 490711         40.807590                2
# 382322         40.759243                5
# 470706         40.772070                4
# 269005         40.714466                5
# 290281         40.736250                1
# 217138         40.781815                1
# 146265         40.779037                1
# 430940         40.670780                1
# 269792         40.765700                1
# 211082         40.772710                1
# 511032         40.755670                2
# 189303         40.745758                1
# 325768          0.000000                1
# 435326         40.748010                5
# 342612         40.705383                1
#
# [100 rows x 18 columns]

# %%
df_all.describe()
# Out:
#          fare_amount           day      dayofweek           year  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       11.394261      15.66747       3.981280    2011.734710
# std         9.820031       8.68193       1.905861       1.860765
# min       -19.700000       1.00000       1.000000    2008.000000
# 25%         6.000000       8.00000       2.000000    2010.000000
# 50%         8.500000      16.00000       4.000000    2012.000000
# 75%        12.500000      23.00000       6.000000    2013.000000
# max       386.080000      31.00000       7.000000    2015.000000
#
#                month    dayofmonth           hour         minute  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean        6.259700      15.66747      11.846400      29.545320
# std         3.447671       8.68193       5.826059      17.344077
# min         1.000000       1.00000       0.000000       0.000000
# 25%         3.000000       8.00000       7.000000      14.000000
# 50%         6.000000      16.00000      12.000000      30.000000
# 75%         9.000000      23.00000      17.000000      45.000000
# max        12.000000      31.00000      23.000000      59.000000
#
#              sin_day        cos_day       sin_week       cos_week  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean       -0.207170      -0.041111       0.042881       0.028388
# std         0.649918       0.730073       0.711148       0.701166
# min        -1.000000      -1.000000      -1.000000      -1.000000
# 25%        -0.816642      -0.774393      -0.712682      -0.670617
# 50%        -0.342430      -0.100514       0.028181       0.079080
# 75%         0.351740       0.719340       0.718049       0.732905
# max         1.000000       1.000000       1.000000       1.000000
#
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# count     100000.000000    100000.000000       99999.000000      99999.000000
# mean         -72.465784        39.894721         -72.472190         39.948270
# std           11.535382         6.246870          11.295578         13.174066
# min        -1131.730000       -74.013280       -1131.730000        -74.015816
# 25%          -73.992120        40.734817         -73.991480         40.734104
# 50%          -73.981820        40.752535         -73.980160         40.753166
# 75%          -73.967080        40.766872         -73.963524         40.768093
# max           40.801373       405.150000          40.798573       3210.367200
#
#        passenger_count
# count    100000.000000
# mean          1.689760
# std           1.311826
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max           6.000000

# %% [markdown]
# ### Date-Time Features

# %%
df_all['ts'] = df_all['pickup_datetime'].apply(pd.Timestamp)
df_all['weekday'] = df_all['ts'].dt.weekday
df_all['day'] = df_all['ts'].dt.day
df_all['month'] = df_all['ts'].dt.month
df_all['year'] = df_all['ts'].dt.year
df_all['hour'] = df_all['ts'].dt.hour

# %%
time_features = ['day', 'month', 'weekday', 'year', 'hour']

fig = plt.figure(figsize=(20,12))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(len(time_features)):
    ax = fig.add_subplot(2, 3, i+1)
    sns.boxplot(x=time_features[i], y="fare_amount", data=df_all[df_all['year'] >= 2013], showfliers=False)

plt.show()

# %% [markdown]
# ### Geographic

# %% [markdown]
# https://www.kaggle.com/breemen/nyc-taxi-fare-data-exploration

# %%
nyc_box = (-74.1, -73.7, 40.6, 40.9)

# %%
def filter_coordinates(df, box):
    return (df.pickup_longitude >= box[0]) & (df.pickup_longitude <= box[1]) & \
           (df.pickup_latitude >= box[2]) & (df.pickup_latitude <=box[3]) & \
           (df.dropoff_longitude >= box[0]) & (df.dropoff_longitude <= box[1]) & \
           (df.dropoff_latitude >= box[2]) & (df.dropoff_latitude <= box[3])

# %%
def plot_hires(df, box, figsize=(12, 12), ax=None, c=sns.color_palette("husl", 2)):
    if ax == None:
        fig, ax = plt.subplots(1, 1, figsize=figsize)

    idx = filter_coordinates(df, box)
    ax.scatter(df[idx].pickup_longitude, df[idx].pickup_latitude, c=c[0], s=0.1, lw=0.1, alpha=0.5)
    ax.scatter(df[idx].dropoff_longitude, df[idx].dropoff_latitude, c=c[1], s=0.1, lw=0.1, alpha=0.5)

# %%
plot_hires(df_all, nyc_box)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# <p>In the scatter plot above, the two major NYC airports are easily observed, indicating that it may be informative to "tell" our algorithm whether the ride starts or ends in an airport.</p>
# <p>To do so I use the airports.csv, available <a href="http://ourairports.com/data/">here</a> in the following way:</p>
# <ul>
# <li>from this file I extract the location of 3 of the listed NYC airports</li>
# <li>I than calculate the distance of dropoff and pickup points from every record to each airport, Assuming it will provide additional information to our model.</li>
# </ul>
# <p>Further details are in the feature extraction below</p>

# %% [markdown]
# ## Ride distance

# %%
df_all['air_distance'] = (df_all.pickup_longitude - df_all.dropoff_longitude)**2 +\
                     (df_all.pickup_latitude - df_all.dropoff_latitude)**2
df_all['air_distance'] = np.sqrt(df_all['air_distance'])

# %%
df_all['price_per_distance'] = df_all['fare_amount'] / df_all['air_distance']

# %%
time_features = ['weekday', 'year', 'hour']
fig = plt.figure(figsize=(18,5))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(len(time_features)):
    ax = fig.add_subplot(1, 3, i+1)
    sns.boxplot(x=time_features[i], y="price_per_distance", data=df_all[df_all['year'] >= 2013], showfliers=False)

plt.show()

# %%
time_features = ['weekday', 'year', 'hour']
fig = plt.figure(figsize=(18,5))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(len(time_features)):
    ax = fig.add_subplot(1, 3, i+1)
    sns.boxplot(x=time_features[i], y="air_distance", data=df_all[df_all['year'] >= 2013], showfliers=False)

plt.show()

# %% [markdown]
# ## Split train test

# %% [markdown]
# <p>If you managed to create the dataset using Athena, you have two options on how to create train and validation sets files.&nbsp;</p>
# <ol>
# <li>Create a seperate query, using a WHERE on the year clause to split the train and validation by time (e.g. year, month)</li>
# <li>Create a single query, partition the results by time, and use aws-cli to mv the directories to different train/validation directotires</li>
# </ol>

# %% [markdown]
# ## Train model

# %%
from sagemaker.amazon.amazon_estimator import get_image_uri
import sagemaker
from sagemaker import get_execution_role
import boto3
from datetime import datetime
import os
import pandas as pd
import random
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
bucket = 'aws-worskhop-data'

path_train = 'taxinyc-query-results/train/78a6a6df-267a-4783-bef4-fd6eb4f082fa.csv'
path_validate = 'taxinyc-query-results/validate/60c4073e-00bc-4e80-a9aa-d93e53687a28.csv' 

s3_path_2014 = os.path.join('s3://', bucket, path_train)
s3_path_2015 = os.path.join('s3://', bucket, path_validate)

# %%
df_2014 = pd.read_csv(s3_path_2014, header=0, skiprows=lambda i: i>0 and random.random() > 0.1)

#n = 10  # every 100th line = 1% of the lines
#df_2014 = pd.read_csv(s3_path_2014, header=0, skiprows=lambda i: i % n != 0)

df_2014
df_2014.to_csv('train_small_2014.csv', header=False, index=False)
df_2014_final = pd.read_csv('./train_small_2014.csv')
df_2014_final
# Out:
#           6.5   4  5  2014  4.1  4.2  23   1  0.7126895338497109  \
# 0       17.50   4  5  2014    4    4   4  49            0.740218
# 1        5.00   4  4  2014    9    4  17  48           -0.542380
# 2        8.50  23  7  2014    3   23   8  35           -0.153058
# 3       12.00  25  4  2014    9   25   5   1            0.701894
# 4        6.00   6  1  2014    1    6  12  44           -0.997584
# 5        7.50  28  2  2014    1   28  10  19           -0.763232
# 6        8.50   3  2  2014    6    3  10   6           -0.523738
# 7        6.50  23  5  2014    5   23   7  58            0.007999
# 8       52.00   4  2  2014   11    4   9   2           -0.507538
# 9        6.50   8  1  2014    9    8   7  25            0.152123
# 10       6.00  17  2  2014    6   17   6  19            0.426042
# 11       6.50  24  1  2014   11   24  14  55           -0.876727
# 12      18.50   6  4  2014    3    6   8  18           -0.333807
# 13       9.00  28  3  2014    5   28  16  51           -0.734323
# 14      15.00   8  6  2014    2    8  15  52           -0.731354
# 15      43.50  29  7  2014    6   29  13  42           -0.996917
# 16       7.50   6  5  2014    6    6   8   7           -0.030539
# 17       3.50  12  6  2014    4   12   3  19            0.940040
# 18       6.00  18  5  2014    4   18  17  45           -0.555207
# 19       5.50   7  5  2014   11    7  15  50           -0.737130
# 20      12.50   5  5  2014    9    5   5  21            0.639439
# 21      13.00   6  2  2014    5    6  14  53           -0.973379
# 22       7.00  30  6  2014    8   30  22  33            0.620692
# 23      16.50  28  7  2014   12   28  19  14            0.064677
# 24       7.50   5  7  2014   10    5   9  51           -0.465615
# 25       5.00   5  3  2014    3    5   8  39           -0.421959
# 26      30.00  18  5  2014    7   18  16  26           -0.803208
# 27       9.00  18  6  2014    1   18  19  22            0.097004
# 28      13.50  12  6  2014    4   12  15   4           -0.960436
# 29      21.50   4  6  2014   10    4   8  22           -0.095846
# ...       ...  .. ..   ...  ...  ...  ..  ..                 ...
# 824232   6.00  24  4  2014    4   24  16  28           -0.797057
# 824233  44.33   6  5  2014    6    6  11  52           -0.850199
# 824234   8.00  29  4  2014    5   29  21  15            0.322059
# 824235  13.50  27  7  2014    7   27  19  32           -0.121869
# 824236   8.00  22  6  2014   11   22  18  38           -0.092515
# 824237  19.50  28  2  2014   10   28  17  19           -0.645791
# 824238  16.00   2  7  2014   11    2  14  14           -0.948324
# 824239  13.50  29  3  2014    1   29  11  34           -0.930418
# 824240  26.50  29  1  2014    9   29   7  22            0.165048
# 824241  10.00   3  4  2014    4    3  14  44           -0.981446
# 824242  19.00  18  4  2014    9   18  22  53            0.687035
# 824243  24.50   6  4  2014    2    6   4  48            0.544639
# 824244  13.00  20  4  2014   11   20   6  28            0.139173
# 824245  10.00   3  5  2014   10    3  20  43            0.189667
# 824246  12.00  10  2  2014    6   10  18  55           -0.277385
# 824247   9.50  18  5  2014    4   18  17  46           -0.551937
# 824248   8.50  14  1  2014    4   14  18   7           -0.472871
# 824249   7.50  29  6  2014    3   29   5  32            0.600304
# 824250  20.50  11  4  2014    9   11   3  57            0.870427
# 824251  34.83  17  1  2014    2   17  13  23           -0.994762
# 824252   7.50  18  2  2014   11   18   4  56            0.515038
# 824253   6.00   4  2  2014    3    4  15  16           -0.829038
# 824254   6.50  29  3  2014    1   29   3   5            0.854912
# 824255  44.00  28  2  2014    1   28  12  14           -0.979925
# 824256  13.50  25  6  2014   10   25  15  11           -0.952396
# 824257   9.00   2  6  2014    8    2   6  25            0.402614
# 824258   6.00  21  5  2014   11   21   8  12           -0.309017
# 824259   8.00  28  5  2014   11   28   9  38           -0.636078
# 824260   4.00  26  3  2014   11   26   3  12            0.837043
# 824261   6.50  18  4  2014   12   18   7  11           -0.047978
#
#         0.7014795993762626  0.9435087217527214  -0.3313476904650851  \
# 0                -0.672367            0.941597             0.336743
# 1                 0.840133            0.728207             0.685357
# 2                -0.988217           -0.021950            -0.999759
# 3                -0.712281            0.331269             0.943536
# 4                -0.069466           -0.896615            -0.442810
# 5                -0.646124           -0.939906             0.341434
# 6                -0.851879           -0.954402             0.298525
# 7                -0.999968            0.974673             0.223635
# 8                -0.861629           -0.955205             0.295946
# 9                -0.988362           -0.768044            -0.640397
# 10               -0.904703           -0.986983             0.160825
# 11                0.480989           -0.929731            -0.368240
# 12               -0.942641            0.477159             0.878817
# 13                0.678801           -0.117537             0.993068
# 14                0.681998            0.536248            -0.844061
# 15               -0.078459           -0.211568            -0.977363
# 16               -0.999534            0.975890             0.218265
# 17               -0.341063            0.878291            -0.478126
# 18                0.831712            0.990172            -0.139852
# 19                0.675751            0.994388            -0.105799
# 20               -0.768842            0.948126             0.317896
# 21                0.229200           -0.886146             0.463407
# 22                0.784055            0.345844            -0.938292
# 23                0.997906           -0.442196            -0.896919
# 24               -0.884988           -0.069135            -0.997607
# 25               -0.906615           -0.377013             0.926208
# 26                0.595699            0.995848            -0.091036
# 27                0.995284            0.421337            -0.906904
# 28                0.278502            0.591469            -0.806328
# 29               -0.995396            0.773208            -0.634152
# ...                    ...                 ...                  ...
# 824232            0.603904            0.693132             0.720810
# 824233           -0.526461            0.996865             0.079122
# 824234            0.946720            0.810170             0.586196
# 824235            0.992546           -0.418094            -0.908404
# 824236            0.995711            0.445770            -0.895147
# 824237            0.763514           -0.840330             0.542075
# 824238            0.317305           -0.267238            -0.963630
# 824239           -0.366501           -0.274439             0.961605
# 824240           -0.986286           -0.766845            -0.641832
# 824241            0.191737            0.644799             0.764352
# 824242            0.726625            0.844589             0.535414
# 824243           -0.838671            0.358368             0.933580
# 824244           -0.990268            0.415827             0.909444
# 824245            0.981849            0.968500            -0.249012
# 824246            0.960759           -0.806230             0.591603
# 824247            0.833886            0.990094            -0.140408
# 824248            0.881132           -0.956871            -0.290513
# 824249           -0.799772            0.835796            -0.549040
# 824250           -0.492297            0.293544             0.955946
# 824251            0.102214           -0.907219            -0.420659
# 824252           -0.857167           -0.989199             0.146576
# 824253            0.559193           -0.860996             0.508612
# 824254           -0.518773           -0.560742             0.827990
# 824255           -0.199368           -0.913038             0.407875
# 824256            0.304864            0.588289            -0.808650
# 824257           -0.915370            0.817348            -0.576144
# 824258           -0.951057            0.983930             0.178557
# 824259           -0.771625            0.992083             0.125581
# 824260           -0.547137           -0.556770             0.830666
# 824261           -0.998848            0.440051             0.897973
#
#         -73.95233  40.718338  -73.957504  40.729607  3
# 0      -73.984620  40.739613  -73.969510  40.785180  1
# 1      -73.988556  40.754570  -73.988990  40.745580  1
# 2        0.000000   0.000000    0.000000   0.000000  1
# 3      -73.994980  40.728302  -73.989440  40.740314  1
# 4      -73.978850  40.761906  -73.990900  40.750550  1
# 5      -73.964676  40.764202  -73.960260  40.768833  1
# 6      -73.967230  40.788277  -73.951280  40.810000  1
# 7      -73.969154  40.761066  -73.977530  40.764893  1
# 8      -74.003200  40.727740  -73.782310  40.648754  2
# 9      -73.985245  40.728360  -73.992424  40.724860  2
# 10     -73.992160  40.758310  -73.983290  40.754017  1
# 11     -73.982300  40.748520  -73.990170  40.756830  5
# 12     -73.964740  40.796700  -73.916830  40.815662  2
# 13     -73.968740  40.764410  -73.945564  40.775387  1
# 14     -73.994896  40.746320  -73.992340  40.721287  1
# 15     -73.964010  40.797764  -73.978970  40.662323  3
# 16       0.000000   0.000000    0.000000   0.000000  5
# 17     -73.917060  40.780334  -73.915380  40.776110  1
# 18     -73.966156  40.758350  -73.980354  40.742650  1
# 19     -74.005700  40.741196  -74.001800  40.751620  1
# 20     -73.992720  40.748400  -73.971890  40.754112  2
# 21     -73.957726  40.765278  -73.975190  40.792503  2
# 22     -73.984610  40.763954  -73.988840  40.748146  1
# 23     -73.987110  40.719770  -73.979770  40.764534  1
# 24     -74.010310  40.711357  -73.999306  40.733986  1
# 25     -73.983284  40.750366  -73.991930  40.749447  2
# 26     -73.787950  40.641720  -73.908300  40.685430  1
# 27     -73.994110  40.759410  -74.006610  40.744060  3
# 28     -73.966290  40.761658  -73.986590  40.750927  3
# 29     -73.985855  40.759747  -73.961660  40.710950  1
# ...           ...        ...         ...        ... ..
# 824232 -73.964100  40.773678  -73.972270  40.765156  1
# 824233 -73.988630  40.768806  -73.923410  40.792645  3
# 824234 -73.957016  40.770714  -73.976390  40.744240  1
# 824235 -73.968930  40.764460  -74.006730  40.736008  1
# 824236 -73.958910  40.767840  -73.978010  40.759830  1
# 824237 -73.937080  40.855095  -73.973290  40.785250  3
# 824238 -73.984260  40.770557  -73.986120  40.730705  3
# 824239 -73.958930  40.769054  -73.967950  40.798912  1
# 824240 -73.863230  40.769920  -73.912636  40.702286  6
# 824241 -73.959090  40.774998  -73.970560  40.758670  1
# 824242 -73.986660  40.718174  -73.970024  40.789320  1
# 824243 -74.008250  40.704660  -73.972300  40.760754  1
# 824244 -73.994340  40.750810  -73.969660  40.757320  1
# 824245 -74.008090  40.714684  -74.007760  40.705490  1
# 824246 -74.004380  40.742370  -73.969050  40.755950  1
# 824247 -73.982380  40.739810  -73.977940  40.763170  1
# 824248 -73.979430  40.766308  -73.999040  40.760840  1
# 824249 -74.000720  40.732193  -74.003490  40.747463  1
# 824250 -73.978584  40.752480  -74.011140  40.707977  1
# 824251 -73.864170  40.770100  -73.992670  40.756706  1
# 824252 -73.982290  40.757660  -73.971930  40.763080  1
# 824253 -73.993675  40.746662  -73.990814  40.756110  1
# 824254 -73.991570  40.750330  -73.985580  40.742420  1
# 824255 -73.973015  40.752895  -73.955414  40.718353  3
# 824256 -73.975740  40.749100  -73.985890  40.722202  1
# 824257 -73.991340  40.739162  -74.008240  40.716652  1
# 824258 -73.976260  40.788930  -73.982940  40.782060  1
# 824259 -73.988160  40.756020  -74.002846  40.760586  1
# 824260 -73.995926  40.753025  -74.002860  40.755287  1
# 824261 -73.989190  40.736572  -74.003240  40.733192  1
#
# [824262 rows x 17 columns]

# %%
df_2015 = pd.read_csv(s3_path_2015, header=0, skiprows=lambda i: i>0 and random.random() > 0.1)

#n = 10  # every 100th line = 1% of the lines
#df_2015 = pd.read_csv(s3_path_2015, header=0, skiprows=lambda i: i % n != 0)

df_2015
df_2015.to_csv('validate_small_2015.csv', header=False, index=False)
df_2015_final = pd.read_csv('./validate_small_2015.csv')
df_2015_final
# Out:
#         41.04   9  2  2015  6  9.1  18  11  -0.4559332924768926  \
# 0        6.50   3  3  2015  6    3  17  43            -0.559916
# 1       44.54   8  5  2015  5    8   7  21             0.168848
# 2        6.00  16  2  2015  6   16  21   4             0.277245
# 3        6.00   5  1  2015  1    5   3  44             0.752559
# 4       14.50   4  6  2015  4    4   5  39             0.576492
# 5       10.50  27  5  2015  3   27  20   8             0.038170
# 6       57.33   5  1  2015  1    5   7  20            -0.089112
# 7        4.00  17  6  2015  1   17  10  19            -0.764875
# 8       11.00  26  2  2015  5   26   8  47            -0.203713
# 9        9.50  26  1  2015  1   26   4  16             0.653366
# 10      36.33  23  5  2015  1   23   4  26             0.621091
# 11      18.50   6  2  2015  1    6  22  36             0.811191
# 12      14.00  10  6  2015  1   10  16  14            -0.661421
# 13      57.33  12  4  2015  2   12   2   0             0.965302
# 14       6.50  10  7  2015  5   10   9  19            -0.340858
# 15       4.50  24  2  2015  2   24   2   5             0.959417
# 16      18.50   6  6  2015  6    6  14  52            -0.973413
# 17      10.50  26  7  2015  4   26  10   8            -0.530659
# 18       6.50  24  2  2015  2   24   6  52             0.031847
# 19       6.50  17  3  2015  6   17   9  55            -0.482964
# 20       7.50  20  5  2015  3   20  18  37            -0.352726
# 21      10.00  29  1  2015  6   29   4  11             0.840685
# 22      18.00  22  4  2015  1   22   8  17            -0.332093
# 23       6.00  24  2  2015  2   24   5  16             0.437848
# 24       7.00  16  5  2015  1   16  17  54            -0.281783
# 25      14.00  31  2  2015  3   31   7  15             0.192165
# 26       8.50   6  5  2015  3    6  10  18            -0.760642
# 27      14.00  11  3  2015  2   11   4  46             0.548476
# 28       8.50   9  6  2015  5    9  21  18             0.336958
# 29       5.50  16  2  2015  6   16  12  27            -0.919850
# ...       ...  .. ..   ... ..  ...  ..  ..                  ...
# 385320  14.50  10  3  2015  6   10  10  26            -0.596050
# 385321  13.50  27  5  2015  3   27  18  25            -0.401948
# 385322  10.00   8  7  2015  3    8   8  20            -0.091429
# 385323   4.50  25  6  2015  4   25   9  36            -0.410520
# 385324   8.50  19  5  2015  6   19  17   6            -0.685765
# 385325   9.50  20  1  2015  4   20  16  15            -0.829850
# 385326  33.83   3  6  2015  1    3  14   4            -0.960759
# 385327  55.00  14  7  2015  6   14   5  54             0.521568
# 385328  11.50  24  3  2015  6   24  18  30            -0.382213
# 385329  32.83   1  4  2015  1    1   8  37            -0.413171
# 385330   4.00  15  7  2015  2   15   8   9            -0.299041
# 385331   5.00  23  5  2015  1   23  16  49            -0.539138
# 385332  10.00  27  5  2015  3   27  13  13            -0.979119
# 385333   8.00   7  6  2015  2    7  12  38            -0.995637
# 385334  12.00  17  6  2015  1   17   9  53            -0.685289
# 385335  11.50   1  5  2015  5    1   4  23             0.811021
# 385336  12.50  23  2  2015  6   23  18  52            -0.288684
# 385337   6.50   8  4  2015  1    8  12  33            -0.993473
# 385338  52.00   2  6  2015  5    2   3  34             0.915955
# 385339  14.50  25  4  2015  6   25   2  35             0.987949
# 385340   6.00   7  6  2015  3    7   6  21             0.165908
# 385341  11.50   7  3  2015  1    7   5   9             0.462587
# 385342  21.50  18  7  2015  1   18  19  25             0.110457
# 385343  11.50  19  5  2015  6   19  17  44            -0.559193
# 385344   6.50  20  5  2015  2   20   4  57             0.509417
# 385345   9.00  11  3  2015  3   11   6  27             0.393808
# 385346  16.00  30  2  2015  6   30   1  48             0.998637
# 385347   4.50  25  7  2015  1   25   4  57             0.510355
# 385348  12.50  22  5  2015  5   22  10  28            -0.601989
# 385349  13.00  18  3  2015  2   18  10  55            -0.855741
#
#         0.8900139509081756  -0.8221795244412983  0.569228275465547  -73.98833  \
# 0                 0.828549            -0.084796           0.996398 -73.989930
# 1                -0.985642             0.969249           0.246083 -73.872940
# 2                 0.960799            -0.756187           0.654356 -73.950840
# 3                -0.658525            -0.700353          -0.713796 -73.976580
# 4                -0.817103             0.833478          -0.552552 -73.960640
# 5                 0.999271             0.973700          -0.227835 -73.988740
# 6                -0.996022            -0.789715          -0.613473 -73.776726
# 7                -0.644179             0.698423          -0.715685 -73.986580
# 8                -0.979031            -0.967989           0.250993 -74.001976
# 9                -0.757043            -0.714480          -0.699656 -73.955990
# 10               -0.783739             0.949194           0.314693 -73.988930
# 11                0.584781            -0.690680           0.723161 -73.995865
# 12                0.750015             0.524428          -0.851455 -73.984710
# 13               -0.261136             0.259150           0.965837 -73.957250
# 14               -0.940115            -0.049669          -0.998766 -74.000330
# 15               -0.281993            -0.999166           0.040827 -73.973260
# 16                0.229059             0.597342          -0.801987 -73.921580
# 17               -0.847585            -0.079826          -0.996809 -73.967020
# 18               -0.999493            -0.975930           0.218082 -73.996290
# 19               -0.875640            -0.367941           0.929849 -73.991920
# 20                0.935726             0.985090          -0.172042 -73.981860
# 21               -0.541525            -0.685251          -0.728307 -73.959220
# 22               -0.943247             0.476930           0.878941 -73.993530
# 23               -0.899049            -0.987282           0.158979 -73.995240
# 24                0.959478             0.983194          -0.182562 -73.991710
# 25               -0.981363            -0.980702           0.195508 -73.975440
# 26               -0.649172             0.994911           0.100757 -73.985290
# 27               -0.836167            -0.507028           0.861930 -73.991760
# 28                0.941520             0.389143          -0.921177   0.000000
# 29               -0.392270            -0.924447           0.381310 -74.003360
# ...                    ...                  ...                ...        ...
# 385320           -0.802948            -0.350003           0.936749 -73.969110
# 385321            0.915663             0.986368          -0.164556 -73.972660
# 385322           -0.995812            -0.013079          -0.999914 -73.974150
# 385323           -0.911852             0.742748          -0.669571 -74.000950
# 385324            0.727823             0.993227          -0.116186 -73.977430
# 385325            0.557987            -0.934397          -0.356233 -73.982800
# 385326            0.277385             0.591603          -0.806230 -73.875160
# 385327           -0.853210             0.078304          -0.996930 -74.003740
# 385328            0.924074            -0.055998           0.998431 -74.008190
# 385329           -0.910654             0.487869           0.872917 -73.967710
# 385330           -0.954240            -0.043370          -0.999059 -73.984710
# 385331            0.842217             0.989785          -0.142567 -74.007570
# 385332           -0.203286             0.999572           0.029240 -73.989700
# 385333           -0.093312             0.633871          -0.773439 -73.978540
# 385334           -0.728271             0.710171          -0.704029 -73.966910
# 385335           -0.585017             0.936063           0.351832 -73.990776
# 385336            0.957425            -0.807224           0.590245 -74.005810
# 385337           -0.114070             0.610639           0.791909 -73.954720
# 385338           -0.401282             0.873823          -0.486245 -74.004520
# 385339           -0.154782             0.244109           0.969748 -73.965990
# 385340           -0.986141             0.796455          -0.604698 -73.970860
# 385341           -0.886574            -0.494709           0.869058 -73.960460
# 385342            0.993881            -0.448075          -0.893996 -74.008150
# 385343            0.829038             0.990268          -0.139173 -73.982185
# 385344           -0.860520             0.955112           0.296244 -73.968796
# 385345           -0.919193            -0.485228           0.874388 -73.979490
# 385346            0.052191            -0.999972          -0.007459 -73.911010
# 385347           -0.859964             0.076439          -0.997074 -73.998930
# 385348           -0.798504             0.991285           0.131731 -73.952420
# 385349           -0.517405            -0.297514           0.954718 -73.964980
#
#         40.755276  -73.98015  40.614887  1
# 0       40.735172 -73.974850  40.741707  5
# 1       40.774094 -73.974884  40.758920  1
# 2       40.779030 -73.963930  40.761420  5
# 3       40.788265 -73.980290  40.781500  1
# 4       40.769627 -73.993640  40.728043  6
# 5       40.745760 -73.977615  40.725796  3
# 6       40.645573 -73.987590  40.760360  1
# 7       40.755100 -73.978290  40.751640  5
# 8       40.740326 -73.978714  40.750748  1
# 9       40.776047 -73.966500  40.793423  1
# 10      40.730800 -73.864800  40.770270  6
# 11      40.767250 -73.947910  40.779022  1
# 12      40.763424 -74.008780  40.716133  1
# 13      40.770157 -73.782170  40.648746  2
# 14      40.722140 -74.002240  40.732980  5
# 15      40.792910 -73.974600  40.785810  1
# 16      40.763966 -73.957130  40.722626  5
# 17      40.761050 -73.979770  40.771090  2
# 18      40.723630 -73.992690  40.734050  1
# 19      40.764614 -73.979940  40.781060  1
# 20      40.728360 -73.993430  40.742260  1
# 21      40.780262 -73.938965  40.804817  2
# 22      40.741486 -73.953530  40.764590  1
# 23      40.683660 -74.000310  40.692776  1
# 24      40.764870 -73.983770  40.760110  1
# 25      40.745613 -73.982800  40.767014  1
# 26      40.754272 -73.976830  40.760757  1
# 27      40.748867 -73.971760  40.759308  1
# 28       0.000000   0.000000   0.000000  1
# 29      40.726840 -73.993220  40.742070  6
# ...           ...        ...        ... ..
# 385320  40.754215 -73.987780  40.763813  1
# 385321  40.755943 -74.004210  40.742620  2
# 385322  40.743076 -74.003410  40.738220  1
# 385323  40.736584 -74.007050  40.740864  1
# 385324  40.758575 -73.957794  40.775246  1
# 385325  40.748100 -73.959190  40.763306  1
# 385326  40.774036 -73.974110  40.758220  1
# 385327  40.732670 -73.913990  40.600525  1
# 385328  40.722570 -73.991070  40.755657  2
# 385329  40.802853 -73.864876  40.770355  1
# 385330  40.768300 -73.986940  40.766247  3
# 385331  40.716244 -74.012730  40.706444  5
# 385332  40.701360 -74.001595  40.680950  4
# 385333  40.759740 -73.995540  40.760580  1
# 385334  40.767220 -73.981710  40.736840  5
# 385335  40.730230 -74.014670  40.713940  1
# 385336  40.750908 -73.971800  40.750440  1
# 385337  40.780888 -73.957090  40.769890  2
# 385338  40.751150 -73.781790  40.644400  1
# 385339  40.768238 -73.990944  40.723460  6
# 385340  40.751640 -73.980710  40.742220  1
# 385341  40.770607 -73.975950  40.751484  5
# 385342  40.716120 -73.958340  40.762220  3
# 385343  40.727950 -73.993286  40.749817  1
# 385344  40.763840 -73.959520  40.759080  1
# 385345  40.742203 -73.991490  40.749855  4
# 385346  40.775967 -73.944460  40.784756  1
# 385347  40.739872 -73.993180  40.734120  1
# 385348  40.778270 -73.970300  40.796580  6
# 385349  40.759926 -73.993270  40.751470  1
#
# [385350 rows x 17 columns]

# %%
# !aws s3 cp train_small_2014.csv s3://aws-worskhop-data/taxinyc-query-results/train2/train_small_2014.csv
# Out:
# upload: ./train_small_2014.csv to s3://aws-worskhop-data/taxinyc-query-results/train2/train_small_2014.csv

# %%
# !aws s3 cp validate_small_2015.csv s3://aws-worskhop-data/taxinyc-query-results/validate2/validate_small_2015.csv
# Out:
# upload: ./validate_small_2015.csv to s3://aws-worskhop-data/taxinyc-query-results/validate2/validate_small_2015.csv

# %%
path_train = os.path.join('taxinyc-query-results','train2')
path_val = os.path.join('taxinyc-query-results','validate2')
bucket = 'aws-worskhop-data'

# %%
container = get_image_uri(boto3.Session().region_name, 'xgboost', repo_version="0.90-2")

# %%
's3://{}/{}'.format(bucket, path_train)
# Out:
# 's3://aws-worskhop-data/taxinyc-query-results/train2'

# %%
s3_input_trains3_inpu  = sagemaker.s3_input(s3_data='s3://{}/{}'.format(bucket, path_train),
                                            content_type='csv',
                                            distribution='ShardedByS3Key')
s3_input_validation = sagemaker.s3_input(s3_data='s3://{}/{}'.format(bucket, path_val),
                                         content_type='csv', 
                                         distribution='ShardedByS3Key')

# %%
sess = sagemaker.Session()
role = get_execution_role()

# %%
training_job_path = os.path.join('training_jobs', datetime.now().strftime('%Y-%m-%d-%H-%M-%S'))

# %%
's3://{}/{}/output'.format(bucket,training_job_path)
# Out:
# 's3://aws-worskhop-data/training_jobs/2020-06-12-16-46-58/output'

# %% [markdown]
# ## Train and debug the model

# %%
from smdebug.trials import create_trial
from sagemaker.debugger import rule_configs, Rule, DebuggerHookConfig, CollectionConfig

# %%
hyperparameters = {
    "max_depth": "9",
    "eta": "0.2",
    "gamma": "4",
    "min_child_weight": "300",
    "subsample": "0.8",
    "silent": "0",
    "objective": "reg:linear",
    "early_stopping_rounds": "10",
    "num_round": "300"
}

save_interval = 5

# %%
xgboost_estimator = sagemaker.estimator.Estimator(
    role=role,
    train_instance_count=1,
    train_instance_type='ml.m5.4xlarge',
    output_path='s3://{}/{}/output'.format(bucket,training_job_path),
    image_name=container,
    hyperparameters=hyperparameters,
    train_max_run=10800,
    sagemaker_session=sess,

    debugger_hook_config=DebuggerHookConfig(
        s3_output_path='s3://{}/{}/output'.format(bucket,training_job_path),  # Required
        collection_configs=[
            CollectionConfig(
                name="metrics",
                parameters={
                    "save_interval": str(save_interval)
                }
            ),
            CollectionConfig(
                name="feature_importance",
                parameters={
                    "save_interval": str(save_interval)
                }
            ),
            CollectionConfig(
                name="full_shap",
                parameters={
                    "save_interval": str(save_interval)
                }
            ),
            CollectionConfig(
                name="average_shap",
                parameters={
                    "save_interval": str(save_interval)
                }
            ),
        ],
    ),

    rules=[
        Rule.sagemaker(
            rule_configs.loss_not_decreasing(),
            rule_parameters={
                "collection_names": "metrics",
                "num_steps": str(save_interval * 2),
            },
        ),
    ],
)

# %%
xgboost_estimator.fit({'train': s3_input_trains3_inpu, 'validation': s3_input_validation})
# Out:
# 2020-06-12 16:46:58 Starting - Starting the training job...
# 2020-06-12 16:47:21 Starting - Launching requested ML instances
# ********* Debugger Rule Status *********
# *
# *  LossNotDecreasing: InProgress
# *
# ****************************************
# .........
# 2020-06-12 16:48:42 Starting - Preparing the instances for training...
# 2020-06-12 16:49:27 Downloading - Downloading input data
# 2020-06-12 16:49:27 Training - Downloading the training image...
# 2020-06-12 16:49:44 Training - Training image download completed. Training in progress...INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value reg:linear to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# [16:49:46] 824263x16 matrix with 13188208 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# INFO:root:Determined delimiter of CSV input is ','
# [16:49:46] 385351x16 matrix with 6165616 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# INFO:root:Single node training.
# [2020-06-12 16:49:46.169 ip-10-0-243-41.eu-west-1.compute.internal:1 INFO json_config.py:90] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2020-06-12 16:49:46.170 ip-10-0-243-41.eu-west-1.compute.internal:1 INFO hook.py:151] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2020-06-12 16:49:46.170 ip-10-0-243-41.eu-west-1.compute.internal:1 INFO hook.py:196] Saving to /opt/ml/output/tensors
# INFO:root:Debug hook created from config
# INFO:root:Train matrix has 824263 rows
# INFO:root:Validation matrix has 385351 rows
# [16:49:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [0]#011train-rmse:13.9271#011validation-rmse:14.9525
# [2020-06-12 16:49:46.951 ip-10-0-243-41.eu-west-1.compute.internal:1 INFO hook.py:325] Monitoring the collections: feature_importance, full_shap, metrics, average_shap, losses
# [1]#011train-rmse:11.7307#011validation-rmse:12.9071
# [2]#011train-rmse:10.0769#011validation-rmse:11.404
# [3]#011train-rmse:8.81009#011validation-rmse:10.2844
# [4]#011train-rmse:7.88661#011validation-rmse:9.48521
# [5]#011train-rmse:7.18772#011validation-rmse:8.89658
# [6]#011train-rmse:6.69822#011validation-rmse:8.49191
# [7]#011train-rmse:6.37549#011validation-rmse:8.22994
# [8]#011train-rmse:6.07227#011validation-rmse:7.99024
# [9]#011train-rmse:5.86326#011validation-rmse:7.82415
# [10]#011train-rmse:5.70528#011validation-rmse:7.69792
# [11]#011train-rmse:5.62553#011validation-rmse:7.63139
# [12]#011train-rmse:5.54382#011validation-rmse:7.56525
# [13]#011train-rmse:5.43729#011validation-rmse:7.48056
# [14]#011train-rmse:5.35801#011validation-rmse:7.41718
# [15]#011train-rmse:5.31473#011validation-rmse:7.38319
# [16]#011train-rmse:5.27393#011validation-rmse:7.35221
# [17]#011train-rmse:5.23503#011validation-rmse:7.32468
# [18]#011train-rmse:5.21771#011validation-rmse:7.31112
# [19]#011train-rmse:5.20188#011validation-rmse:7.29842
# [20]#011train-rmse:5.18984#011validation-rmse:7.29297
# [21]#011train-rmse:5.15336#011validation-rmse:7.26481
# [22]#011train-rmse:5.13915#011validation-rmse:7.25286
# [23]#011train-rmse:5.12043#011validation-rmse:7.24031
# [24]#011train-rmse:5.09336#011validation-rmse:7.21953
# [25]#011train-rmse:5.08597#011validation-rmse:7.21779
# [26]#011train-rmse:5.0632#011validation-rmse:7.20003
# [27]#011train-rmse:5.04385#011validation-rmse:7.18606
# [28]#011train-rmse:5.03802#011validation-rmse:7.18087
# [29]#011train-rmse:5.03335#011validation-rmse:7.17696
# [30]#011train-rmse:5.02227#011validation-rmse:7.16788
# [31]#011train-rmse:5.0155#011validation-rmse:7.16659
# [32]#011train-rmse:5.01227#011validation-rmse:7.16558
# [33]#011train-rmse:5.00681#011validation-rmse:7.16169
# [34]#011train-rmse:5.00169#011validation-rmse:7.16118
# [35]#011train-rmse:4.99889#011validation-rmse:7.16144
# [36]#011train-rmse:4.99486#011validation-rmse:7.1606
# [37]#011train-rmse:4.98971#011validation-rmse:7.15674
# [38]#011train-rmse:4.98127#011validation-rmse:7.15145
# [39]#011train-rmse:4.97817#011validation-rmse:7.15165
# [40]#011train-rmse:4.97332#011validation-rmse:7.14782
# [41]#011train-rmse:4.96985#011validation-rmse:7.1456
# [42]#011train-rmse:4.96644#011validation-rmse:7.14561
# [43]#011train-rmse:4.96132#011validation-rmse:7.14139
# [44]#011train-rmse:4.95426#011validation-rmse:7.13744
# [45]#011train-rmse:4.9445#011validation-rmse:7.13149
# [46]#011train-rmse:4.93528#011validation-rmse:7.12509
# [47]#011train-rmse:4.92243#011validation-rmse:7.11582
# [48]#011train-rmse:4.91569#011validation-rmse:7.10944
# [49]#011train-rmse:4.90706#011validation-rmse:7.10384
# [50]#011train-rmse:4.90161#011validation-rmse:7.10392
# [51]#011train-rmse:4.89865#011validation-rmse:7.10362
# [52]#011train-rmse:4.89581#011validation-rmse:7.10208
# [53]#011train-rmse:4.89126#011validation-rmse:7.09883
# [54]#011train-rmse:4.88196#011validation-rmse:7.09264
# [55]#011train-rmse:4.88033#011validation-rmse:7.09267
# [56]#011train-rmse:4.8784#011validation-rmse:7.09146
# [57]#011train-rmse:4.87436#011validation-rmse:7.08795
# [58]#011train-rmse:4.87234#011validation-rmse:7.08838
# [59]#011train-rmse:4.87034#011validation-rmse:7.08897
# [60]#011train-rmse:4.86627#011validation-rmse:7.08693
# [61]#011train-rmse:4.86425#011validation-rmse:7.08603
# [62]#011train-rmse:4.85789#011validation-rmse:7.08152
# [63]#011train-rmse:4.85667#011validation-rmse:7.08052
# [64]#011train-rmse:4.85457#011validation-rmse:7.07907
# [65]#011train-rmse:4.85148#011validation-rmse:7.07876
# [66]#011train-rmse:4.84696#011validation-rmse:7.0744
# [67]#011train-rmse:4.84502#011validation-rmse:7.074
# [68]#011train-rmse:4.84365#011validation-rmse:7.07372
# [69]#011train-rmse:4.84266#011validation-rmse:7.07295
# [70]#011train-rmse:4.84083#011validation-rmse:7.07124
# [71]#011train-rmse:4.83863#011validation-rmse:7.0713
# [72]#011train-rmse:4.83611#011validation-rmse:7.06938
# [73]#011train-rmse:4.83581#011validation-rmse:7.06928
# [74]#011train-rmse:4.83384#011validation-rmse:7.06707
# [75]#011train-rmse:4.83187#011validation-rmse:7.06602
# [76]#011train-rmse:4.82942#011validation-rmse:7.0654
# [77]#011train-rmse:4.82827#011validation-rmse:7.0643
# [78]#011train-rmse:4.82607#011validation-rmse:7.06427
# [79]#011train-rmse:4.82464#011validation-rmse:7.06482
# [80]#011train-rmse:4.82377#011validation-rmse:7.06459
# [81]#011train-rmse:4.82287#011validation-rmse:7.06366
# [82]#011train-rmse:4.8211#011validation-rmse:7.06272
# [83]#011train-rmse:4.81988#011validation-rmse:7.06267
# [84]#011train-rmse:4.81698#011validation-rmse:7.061
# [85]#011train-rmse:4.81512#011validation-rmse:7.05977
#
# ********* Debugger Rule Status *********
# *
# *  LossNotDecreasing: IssuesFound
# *
# ****************************************
# [86]#011train-rmse:4.81278#011validation-rmse:7.05903
# [87]#011train-rmse:4.81071#011validation-rmse:7.05872
# [88]#011train-rmse:4.80859#011validation-rmse:7.05712
# [89]#011train-rmse:4.80742#011validation-rmse:7.05661
# [90]#011train-rmse:4.80655#011validation-rmse:7.05667
# [91]#011train-rmse:4.80609#011validation-rmse:7.05621
# [92]#011train-rmse:4.80418#011validation-rmse:7.05506
# [93]#011train-rmse:4.80128#011validation-rmse:7.05332
# [94]#011train-rmse:4.79777#011validation-rmse:7.05134
# [95]#011train-rmse:4.79537#011validation-rmse:7.04934
# [96]#011train-rmse:4.79261#011validation-rmse:7.04762
# [97]#011train-rmse:4.79232#011validation-rmse:7.0479
# [98]#011train-rmse:4.79197#011validation-rmse:7.04776
# [99]#011train-rmse:4.7915#011validation-rmse:7.04751
# [100]#011train-rmse:4.78931#011validation-rmse:7.04655
# [101]#011train-rmse:4.7881#011validation-rmse:7.04664
# [102]#011train-rmse:4.78618#011validation-rmse:7.04554
# [103]#011train-rmse:4.78494#011validation-rmse:7.04477
# [104]#011train-rmse:4.78434#011validation-rmse:7.04488
# [105]#011train-rmse:4.78057#011validation-rmse:7.04294
# [106]#011train-rmse:4.77889#011validation-rmse:7.04299
# [107]#011train-rmse:4.77782#011validation-rmse:7.04243
# [108]#011train-rmse:4.77675#011validation-rmse:7.04201
# [109]#011train-rmse:4.77581#011validation-rmse:7.04076
# [110]#011train-rmse:4.77483#011validation-rmse:7.04024
# [111]#011train-rmse:4.77419#011validation-rmse:7.03992
# [112]#011train-rmse:4.77362#011validation-rmse:7.03995
# [113]#011train-rmse:4.77257#011validation-rmse:7.0404
# [114]#011train-rmse:4.7716#011validation-rmse:7.03984
# [115]#011train-rmse:4.77053#011validation-rmse:7.03875
# [116]#011train-rmse:4.76855#011validation-rmse:7.03852
# [117]#011train-rmse:4.76801#011validation-rmse:7.03921
# [118]#011train-rmse:4.76571#011validation-rmse:7.03813
# [119]#011train-rmse:4.74989#011validation-rmse:7.02645
# [120]#011train-rmse:4.74788#011validation-rmse:7.02466
# [121]#011train-rmse:4.74707#011validation-rmse:7.02394
# [122]#011train-rmse:4.74599#011validation-rmse:7.02403
# [123]#011train-rmse:4.74531#011validation-rmse:7.02411
# [124]#011train-rmse:4.74275#011validation-rmse:7.0222
# [125]#011train-rmse:4.74177#011validation-rmse:7.02325
# [126]#011train-rmse:4.74107#011validation-rmse:7.02313
# [127]#011train-rmse:4.73898#011validation-rmse:7.02218
# [128]#011train-rmse:4.73814#011validation-rmse:7.02268
# [129]#011train-rmse:4.7364#011validation-rmse:7.02156
# [130]#011train-rmse:4.73326#011validation-rmse:7.01979
# [131]#011train-rmse:4.73146#011validation-rmse:7.01831
# [132]#011train-rmse:4.72949#011validation-rmse:7.01749
# [133]#011train-rmse:4.72791#011validation-rmse:7.01672
# [134]#011train-rmse:4.72682#011validation-rmse:7.01736
# [135]#011train-rmse:4.72467#011validation-rmse:7.0164
# [136]#011train-rmse:4.72353#011validation-rmse:7.01557
# [137]#011train-rmse:4.72146#011validation-rmse:7.01414
# [138]#011train-rmse:4.71969#011validation-rmse:7.01322
# [139]#011train-rmse:4.71903#011validation-rmse:7.01345
# [140]#011train-rmse:4.71818#011validation-rmse:7.0132
# [141]#011train-rmse:4.71753#011validation-rmse:7.01274
# [142]#011train-rmse:4.71517#011validation-rmse:7.01168
# [143]#011train-rmse:4.71426#011validation-rmse:7.0115
# [144]#011train-rmse:4.71357#011validation-rmse:7.01132
# [145]#011train-rmse:4.71285#011validation-rmse:7.01151
# [146]#011train-rmse:4.7104#011validation-rmse:7.00984
# [147]#011train-rmse:4.70476#011validation-rmse:7.00593
# [148]#011train-rmse:4.70287#011validation-rmse:7.00451
# [149]#011train-rmse:4.69864#011validation-rmse:7.00096
# [150]#011train-rmse:4.69729#011validation-rmse:7.0006
# [151]#011train-rmse:4.69662#011validation-rmse:7.00053
# [152]#011train-rmse:4.69622#011validation-rmse:7.00006
# [153]#011train-rmse:4.69535#011validation-rmse:6.99997
# [154]#011train-rmse:4.69354#011validation-rmse:6.99863
# [155]#011train-rmse:4.69235#011validation-rmse:6.99869
# [156]#011train-rmse:4.69147#011validation-rmse:6.99849
# [157]#011train-rmse:4.69032#011validation-rmse:6.99803
# [158]#011train-rmse:4.68913#011validation-rmse:6.99875
# [159]#011train-rmse:4.68787#011validation-rmse:6.99803
# [160]#011train-rmse:4.68699#011validation-rmse:6.99745
# [161]#011train-rmse:4.68625#011validation-rmse:6.997
# [162]#011train-rmse:4.68502#011validation-rmse:6.99738
# [163]#011train-rmse:4.68469#011validation-rmse:6.9974
# [164]#011train-rmse:4.68394#011validation-rmse:6.99764
# [165]#011train-rmse:4.68309#011validation-rmse:6.99754
# [166]#011train-rmse:4.68164#011validation-rmse:6.99649
# [167]#011train-rmse:4.68082#011validation-rmse:6.99612
# [168]#011train-rmse:4.67924#011validation-rmse:6.99513
# [169]#011train-rmse:4.678#011validation-rmse:6.99506
# [170]#011train-rmse:4.67374#011validation-rmse:6.99186
# [171]#011train-rmse:4.67298#011validation-rmse:6.99152
# [172]#011train-rmse:4.66157#011validation-rmse:6.98471
# [173]#011train-rmse:4.66032#011validation-rmse:6.98447
# [174]#011train-rmse:4.65981#011validation-rmse:6.98449
# [175]#011train-rmse:4.6592#011validation-rmse:6.98419
# [176]#011train-rmse:4.65831#011validation-rmse:6.98345
# [177]#011train-rmse:4.65755#011validation-rmse:6.9836
# [178]#011train-rmse:4.65681#011validation-rmse:6.98324
# [179]#011train-rmse:4.6554#011validation-rmse:6.98233
# [180]#011train-rmse:4.65474#011validation-rmse:6.98197
# [181]#011train-rmse:4.65373#011validation-rmse:6.98198
# [182]#011train-rmse:4.65303#011validation-rmse:6.98155
# [183]#011train-rmse:4.6525#011validation-rmse:6.98116
# [184]#011train-rmse:4.65225#011validation-rmse:6.9815
# [185]#011train-rmse:4.65091#011validation-rmse:6.97991
# [186]#011train-rmse:4.65028#011validation-rmse:6.97941
# [187]#011train-rmse:4.64992#011validation-rmse:6.97898
# [188]#011train-rmse:4.64907#011validation-rmse:6.9797
# [189]#011train-rmse:4.64824#011validation-rmse:6.97952
# [190]#011train-rmse:4.64755#011validation-rmse:6.97924
# [191]#011train-rmse:4.64733#011validation-rmse:6.97876
# [192]#011train-rmse:4.64529#011validation-rmse:6.97816
# [193]#011train-rmse:4.64492#011validation-rmse:6.97808
# [194]#011train-rmse:4.64436#011validation-rmse:6.97801
# [195]#011train-rmse:4.64402#011validation-rmse:6.97818
# [196]#011train-rmse:4.64335#011validation-rmse:6.97795
# [197]#011train-rmse:4.64246#011validation-rmse:6.97751
# [198]#011train-rmse:4.64216#011validation-rmse:6.97743
# [199]#011train-rmse:4.64145#011validation-rmse:6.97732
# [200]#011train-rmse:4.64065#011validation-rmse:6.97672
# [201]#011train-rmse:4.64004#011validation-rmse:6.97683
# [202]#011train-rmse:4.63936#011validation-rmse:6.97659
# [203]#011train-rmse:4.63845#011validation-rmse:6.97682
# [204]#011train-rmse:4.63831#011validation-rmse:6.97682
# [205]#011train-rmse:4.63775#011validation-rmse:6.97663
# [206]#011train-rmse:4.63572#011validation-rmse:6.97506
# [207]#011train-rmse:4.63523#011validation-rmse:6.97455
# [208]#011train-rmse:4.63485#011validation-rmse:6.97449
# [209]#011train-rmse:4.63417#011validation-rmse:6.97429
# [210]#011train-rmse:4.63374#011validation-rmse:6.97449
# [211]#011train-rmse:4.63344#011validation-rmse:6.97458
# [212]#011train-rmse:4.63309#011validation-rmse:6.97468
# [213]#011train-rmse:4.63037#011validation-rmse:6.97264
# [214]#011train-rmse:4.62986#011validation-rmse:6.97214
# [215]#011train-rmse:4.62919#011validation-rmse:6.97222
# [216]#011train-rmse:4.62872#011validation-rmse:6.97209
# [217]#011train-rmse:4.62812#011validation-rmse:6.97191
# [218]#011train-rmse:4.62742#011validation-rmse:6.97139
# [219]#011train-rmse:4.62677#011validation-rmse:6.97103
# [220]#011train-rmse:4.62611#011validation-rmse:6.97097
# [221]#011train-rmse:4.62581#011validation-rmse:6.97047
# [222]#011train-rmse:4.62469#011validation-rmse:6.96991
# [223]#011train-rmse:4.62359#011validation-rmse:6.96972
# [224]#011train-rmse:4.62322#011validation-rmse:6.96968
# [225]#011train-rmse:4.62296#011validation-rmse:6.96968
# [226]#011train-rmse:4.62254#011validation-rmse:6.96935
# [227]#011train-rmse:4.62228#011validation-rmse:6.96964
# [228]#011train-rmse:4.62175#011validation-rmse:6.96995
# [229]#011train-rmse:4.62165#011validation-rmse:6.97004
# [230]#011train-rmse:4.62134#011validation-rmse:6.96999
# [231]#011train-rmse:4.62127#011validation-rmse:6.96983
# [232]#011train-rmse:4.62078#011validation-rmse:6.96971
# [233]#011train-rmse:4.62024#011validation-rmse:6.96964
# [234]#011train-rmse:4.61949#011validation-rmse:6.96958
# [235]#011train-rmse:4.61911#011validation-rmse:6.96969
#
# 2020-06-12 18:48:15 Uploading - Uploading generated training model[236]#011train-rmse:4.61896#011validation-rmse:6.96965
#
# 2020-06-12 18:48:23 Completed - Training job completed
# Training seconds: 7155
# Billable seconds: 7155

# %%
xgboost_estimator.latest_training_job.rule_job_summary()
# Out:
# [{'RuleConfigurationName': 'LossNotDecreasing',
#   'RuleEvaluationJobArn': 'arn:aws:sagemaker:eu-west-1:282784146513:processing-job/sagemaker-xgboost-2020-06--lossnotdecreasing-b13b2686',
#   'RuleEvaluationStatus': 'IssuesFound',
#   'StatusDetails': 'RuleEvaluationConditionMet: Evaluation of the rule LossNotDecreasing at step 80 resulted in the condition being met\n',
#   'LastModifiedTime': datetime.datetime(2020, 6, 12, 17, 16, 4, 158000, tzinfo=tzlocal())}]

# %%
s3_output_path = xgboost_estimator.latest_job_debugger_artifacts_path()
trial = create_trial(s3_output_path)
# Out:
# [2020-06-12 18:49:00.716 ip-172-16-77-40:15829 INFO s3_trial.py:42] Loading trial debug-output at path s3://aws-worskhop-data/training_jobs/2020-06-12-16-46-58/output/sagemaker-xgboost-2020-06-12-16-46-58-588/debug-output

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import re


def get_data(trial, tname):
    """
    For the given tensor name, walks though all the iterations
    for which you have data and fetches the values.
    Returns the set of steps and the values.
    """
    tensor = trial.tensor(tname)
    steps = tensor.steps()
    vals = [tensor.value(s) for s in steps]
    return steps, vals

def plot_collection(trial, collection_name, regex='.*', figsize=(8, 6)):
    """
    Takes a `trial` and a collection name, and 
    plots all tensors that match the given regex.
    """
    fig, ax = plt.subplots(figsize=figsize)
    sns.despine()

    tensors = trial.collection(collection_name).tensor_names

    for tensor_name in sorted(tensors):
        if re.match(regex, tensor_name):
            steps, data = get_data(trial, tensor_name)
            ax.plot(steps, data, label=tensor_name)

    ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
    ax.set_xlabel('Iteration')

# %%
plot_collection(trial, "metrics")
# Out:
# [2020-06-12 18:49:04.080 ip-172-16-77-40:15829 INFO trial.py:198] Training has ended, will refresh one final time in 1 sec.
# [2020-06-12 18:49:05.103 ip-172-16-77-40:15829 INFO trial.py:210] Loaded all steps

# %%
def plot_feature_importance(trial, importance_type="weight"):
    SUPPORTED_IMPORTANCE_TYPES = ["weight", "gain", "cover", "total_gain", "total_cover"]
    if importance_type not in SUPPORTED_IMPORTANCE_TYPES:
        raise ValueError(f"{importance_type} is not one of the supported importance types.")
    plot_collection(
        trial,
        "feature_importance",
        regex=f"feature_importance/{importance_type}/.*")

# %%
plot_feature_importance(trial)

# %%
plot_feature_importance(trial, importance_type="cover")

# %%
plot_collection(trial,"average_shap")

# %%
feature_names = list(df_small.columns[1:])

# %%
shap_values = trial.tensor("full_shap/f0").value(trial.last_complete_step)
shap_no_base = shap_values[:, :-1]
shap_base_value = shap_values[0, -1]
shap.summary_plot(shap_no_base, plot_type='bar', feature_names=feature_names)

# %% [markdown]
# ## Deploy the model

# %%
xgb_predictor = xgboost_estimator.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# ---------------!

# %% [markdown]
# ## Explain the model (Kernel SHAP)

# %%
df_sample = df_2015.sample(n = 300)

# %%
df_sample = df_sample.iloc[:, 1:]

# %%
from sagemaker.predictor import csv_serializer

xgb_predictor.content_type = 'text/csv'
xgb_predictor.serializer = csv_serializer
xgb_predictor.deserializer = None

def predict(data, rows=500):
    split_array = np.array_split(data, int(data.shape[0] / float(rows) + 1))
    predictions = ''
    for array in split_array:
        predictions = ','.join([predictions, xgb_predictor.predict(array).decode('utf-8')])

    return np.fromstring(predictions[1:], sep=',')

predictions = predict(df_sample.as_matrix()[:, 1:])
predictions
# Out:
# Method .as_matrix will be removed in a future version. Use .values instead.
# array([12.51346302, 14.0758276 , 19.2107029 , 17.0618    , 16.40022278,
#        17.23485565, 16.51889229, 15.95446301, 16.8911171 , 15.10645866,
#        14.00473785, 15.12139988, 14.61327934, 14.06839561, 18.6913414 ,
#        12.54294968, 12.40966702, 18.81490898, 16.6968708 , 18.29474831,
#        15.80234146, 14.16066647, 15.5344038 , 14.87459469, 19.79860306,
#        16.35907745, 16.80527687, 16.6433506 , 17.30153275, 18.95120621,
#        17.94505119, 16.57624435, 13.51863766, 16.96554947, 16.89538193,
#        19.47810555, 17.81176186, 16.74007034, 17.37823868, 16.28246307,
#        13.87065506, 12.78065777, 16.01036453, 14.04374027, 16.48784637,
#        17.22853851, 18.27655411, 15.97445297, 17.75627708, 16.1236515 ,
#        17.31808853, 15.2670908 , 15.7823    , 17.17079544, 18.92664909,
#        14.98924446, 17.33908081, 18.13776588, 14.08788109, 16.94026375,
#        12.70679092, 17.81221581, 17.68329239, 16.94127464, 14.74430466,
#        19.52431297, 19.55604553, 17.68280029, 15.83738327, 15.48940849,
#        12.98383808, 17.80068398, 16.18510056, 13.22857189, 13.23740196,
#        13.95016861, 15.65193748, 15.2972126 , 14.35201359, 14.73042202,
#        15.32552719, 10.69772434, 21.38072395, 19.64656258, 13.77626228,
#        15.85925198, 14.89554691, 17.62490273, 14.31750965, 18.65174866,
#        15.05578613, 13.18144608, 14.94581127, 16.88015556, 13.8740139 ,
#        16.69580841, 12.99556255, 17.64497375, 15.60679722, 18.32789421,
#        15.86782265, 17.57967186, 18.78092003, 14.00473785, 16.85804939,
#        18.74357224, 13.54028988, 12.52520847, 15.43622303, 14.30760956,
#        17.27213287, 17.84367752, 12.94945526, 17.71027374, 16.04411697,
#        12.2542305 , 11.957551  , 20.73429108, 14.88365746, 15.91156197,
#        14.58552647, 17.88588715, 17.49729729, 16.99591446, 16.73043442,
#        13.40000725, 14.05071068, 18.29938889, 15.84030247, 13.91678333,
#        15.97103691, 17.64052582, 16.47974396, 18.16245842, 17.80068398,
#        16.95682716, 11.96446228, 12.78065777, 17.04187965, 15.98249435,
#        17.18573761, 12.23186016, 14.03973293, 17.68556786, 15.35109043,
#        17.22579384, 18.45805359, 14.5080452 , 15.99464893, 15.45015144,
#        19.69042778, 15.4358778 , 15.64802742, 15.9487257 , 15.89962101,
#        15.04840565, 18.64562035, 17.80068398, 13.87302399, 17.96665192,
#        18.47986221, 15.72996426, 18.62571907, 11.97999287, 16.62665558,
#        16.95351791, 17.07384109, 17.0210247 , 13.26376343, 13.77626228,
#        18.92413712, 16.41922379, 14.55049419, 18.50261879, 11.09998608,
#        17.10978889, 14.18960285, 15.17880821, 13.96573353, 14.74246502,
#        13.62266254, 16.23831177, 16.92176819, 14.86764908, 18.14915466,
#        13.53673363, 19.2298336 , 18.81840897, 13.38969707, 13.36593437,
#        15.09199715, 17.59403801, 14.7389679 , 13.88874817, 13.98707771,
#        16.08590698, 15.86324501, 16.03097916, 17.74133301, 16.68005371,
#        15.38045883, 14.90313721, 18.03211784, 15.96706486, 20.41039467,
#        18.08642006, 11.81202984, 16.86637878, 16.27416039, 18.72753525,
#        16.57469749, 17.65969086, 14.35565948, 17.59403801, 15.47214127,
#        16.4656105 , 18.0745697 , 16.03944778, 15.62084579, 14.30237103,
#        11.40895557, 15.23146152, 15.19923019, 16.9369278 , 16.99140358,
#        12.24293327, 16.89198303, 17.20491982, 19.45732689, 19.79697227,
#        17.7121067 , 11.62867737, 11.07019329, 14.76655293, 15.78414536,
#        19.75600052, 13.40740108, 15.11044693, 18.00320625, 16.04822922,
#        14.6711483 , 16.57594681, 12.87438965, 17.32520485, 16.00855446,
#        18.08501625, 15.72126102, 12.98710155, 16.79073334, 13.57055759,
#        16.39063644, 12.57703114, 14.31750965, 12.08260632, 20.02437401,
#        15.10905838, 16.80643654, 15.7706871 , 13.75873566, 12.57518578,
#        14.67120552, 19.52244186, 14.50207043, 15.00496769, 16.43300247,
#        16.57023811, 18.76433372, 16.11162949, 13.30117989, 15.51389027,
#        14.71417904, 12.77354431, 11.8599205 , 16.21921539, 14.17258358,
#        16.76584244, 16.77834129, 19.93929672, 18.54501343, 15.26564026,
#        18.08642006, 18.75688362, 17.41773796, 14.7260828 , 17.75459099,
#        14.20661831, 14.63345432, 15.9119072 , 11.82896614, 15.18000126,
#        14.86143875, 14.0758276 , 14.26807594, 11.96989918, 16.17850113,
#        15.88743973, 16.7721386 , 16.7515049 , 18.61660194, 16.50581169])

# %%
explainer = shap.KernelExplainer(predict,df_sample.as_matrix())
# Out:
# Method .as_matrix will be removed in a future version. Use .values instead.
# Using 300 background data samples could cause slower run times. Consider using shap.sample(data, K) or shap.kmeans(data, K) to summarize the background as K samples.

# %%
shap_values = explainer.shap_values(df_sample.as_matrix(), nsamples=100)
# Out:
# Method .as_matrix will be removed in a future version. Use .values instead.
# HBox(children=(FloatProgress(value=0.0, max=300.0), HTML(value='')))
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!
# l1_reg="auto" is deprecated and in the next version (v0.29) the behavior will change from a conditional use of AIC to simply "num_features(10)"!

# %%
feature_names
# Out:
# ['day',
#  'dayofweek',
#  'year',
#  'month',
#  'dayofmonth',
#  'hour',
#  'minute',
#  'sin_day',
#  'cos_day',
#  'sin_week',
#  'cos_week',
#  'pickup_datetime',
#  'pickup_longitude',
#  'pickup_latitude',
#  'dropoff_longitude',
#  'dropoff_latitude',
#  'passenger_count']

# %%
shap_no_base = shap_values[:, :-1]
shap_base_value = shap_values[0, -1]
shap.summary_plot(shap_no_base, plot_type='bar', feature_names=feature_names)

# %%
shap.summary_plot(shap_values, df_sample)

# %%
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
shap.force_plot(shap_base_value, shap_values[90, :], df_sample.iloc[90, :], link="identity", matplotlib=True)

# %%
shap.force_plot(shap_base_value, shap_values[120, :], df_sample.iloc[120, :], link="identity", matplotlib=True)
# Out:
# divide by zero encountered in double_scalars
